# %%
import json

with open('errors3.json') as f:
    errors = json.load(f)

# %%
df = pd.DataFrame(errors)
df.index = ['error', 'error_corrupted', 'normalized_error_corrupted_imp', 'normalized_error_corrupted_recon',
            'error_corrupted_imp', 'error_corrupted_recon', 'error_gp_imputation']
df
# Out:
#                                   p_dataset_0.1-a_1_b_1_gamma_1e-10  \
# error                                                      0.050899
# error_corrupted                                            0.122914
# normalized_error_corrupted_imp                             3.248043
# normalized_error_corrupted_recon                           1.053633
# error_corrupted_imp                                        0.620723
# error_corrupted_recon                                      0.122914
# error_gp_imputation                                        0.084848
#
#                                   p_dataset_0.2-a_1_b_1_gamma_1e-10  \
# error                                                      0.048566
# error_corrupted                                            0.094455
# normalized_error_corrupted_imp                             3.526643
# normalized_error_corrupted_recon                           0.816837
# error_corrupted_imp                                        0.720185
# error_corrupted_recon                                      0.094455
# error_gp_imputation                                       77.395851
#
#                                   p_dataset_0.3-a_1_b_1_gamma_1e-10  \
# error                                                      0.029589
# error_corrupted                                            0.075422
# normalized_error_corrupted_imp                             3.214039
# normalized_error_corrupted_recon                           0.687264
# error_corrupted_imp                                        0.800442
# error_corrupted_recon                                      0.075422
# error_gp_imputation                                       73.817070
#
#                                   p_dataset_0.4-a_1_b_1_gamma_1e-10  \
# error                                                      0.023062
# error_corrupted                                            0.068627
# normalized_error_corrupted_imp                             3.117740
# normalized_error_corrupted_recon                           0.603200
# error_corrupted_imp                                        0.781411
# error_corrupted_recon                                      0.068627
# error_gp_imputation                                       32.147064
#
#                                   p_dataset_0.5-a_1_b_1_gamma_1e-10  \
# error                                                      0.011427
# error_corrupted                                            0.037389
# normalized_error_corrupted_imp                             1.825219
# normalized_error_corrupted_recon                           0.324566
# error_corrupted_imp                                        0.803011
# error_corrupted_recon                                      0.037389
# error_gp_imputation                                        0.285200
#
#                                   p_dataset_0.1-a_1_b_1_gamma_1e-05  \
# error                                                      0.057314
# error_corrupted                                            0.141842
# normalized_error_corrupted_imp                             3.084918
# normalized_error_corrupted_recon                           1.199988
# error_corrupted_imp                                        0.738808
# error_corrupted_recon                                      0.141842
# error_gp_imputation                                        0.455011
#
#                                   p_dataset_0.2-a_1_b_1_gamma_1e-05  \
# error                                                      0.044862
# error_corrupted                                            0.103020
# normalized_error_corrupted_imp                             3.210460
# normalized_error_corrupted_recon                           0.915046
# error_corrupted_imp                                        0.761950
# error_corrupted_recon                                      0.103020
# error_gp_imputation                                        0.525199
#
#                                   p_dataset_0.3-a_1_b_1_gamma_1e-05  \
# error                                                      0.034081
# error_corrupted                                            0.111596
# normalized_error_corrupted_imp                             3.380572
# normalized_error_corrupted_recon                           0.776874
# error_corrupted_imp                                        0.663984
# error_corrupted_recon                                      0.111596
# error_gp_imputation                                        0.074365
#
#                                   p_dataset_0.4-a_1_b_1_gamma_1e-05  \
# error                                                      0.024807
# error_corrupted                                            0.075683
# normalized_error_corrupted_imp                             3.035150
# normalized_error_corrupted_recon                           0.639404
# error_corrupted_imp                                        0.747455
# error_corrupted_recon                                      0.075683
# error_gp_imputation                                        0.264817
#
#                                   p_dataset_0.5-a_1_b_1_gamma_1e-05  \
# error                                                      0.019169
# error_corrupted                                            0.057026
# normalized_error_corrupted_imp                             2.605669
# normalized_error_corrupted_recon                           0.466572
# error_corrupted_imp                                        0.761098
# error_corrupted_recon                                      0.057026
# error_gp_imputation                                        6.365082
#
#                                   p_dataset_0.1-a_1_b_1_gamma_0.1  \
# error                                                    0.073136
# error_corrupted                                          0.200395
# normalized_error_corrupted_imp                           3.056160
# normalized_error_corrupted_recon                         1.401934
# error_corrupted_imp                                      0.447927
# error_corrupted_recon                                    0.200395
# error_gp_imputation                                    233.368622
#
#                                   p_dataset_0.2-a_1_b_1_gamma_0.1  \
# error                                                    0.070747
# error_corrupted                                          0.193858
# normalized_error_corrupted_imp                           3.966236
# normalized_error_corrupted_recon                         1.424884
# error_corrupted_imp                                      0.558074
# error_corrupted_recon                                    0.193858
# error_gp_imputation                                      0.288432
#
#                                   p_dataset_0.3-a_1_b_1_gamma_0.1  \
# error                                                    0.067316
# error_corrupted                                          0.185656
# normalized_error_corrupted_imp                           4.612830
# normalized_error_corrupted_recon                         1.413157
# error_corrupted_imp                                      0.638622
# error_corrupted_recon                                    0.185656
# error_gp_imputation                                      2.388389
#
#                                   p_dataset_0.4-a_1_b_1_gamma_0.1
# error                                                    0.066815
# error_corrupted                                          0.184793
# normalized_error_corrupted_imp                           4.869113
# normalized_error_corrupted_recon                         1.470154
# error_corrupted_imp                                      0.666448
# error_corrupted_recon                                    0.184793
# error_gp_imputation                                     11.202954

# %%
df_errors = df.T
df_errors['gamma'] = [text.split('_')[7] for text in df_errors.index]
df_errors['beta'] = [text.split('_')[5] for text in df_errors.index]
df_errors['alpha'] = [text.split('_')[3] for text in df_errors.index]
df_errors['p_dataset'] = [text.split('-')[0].split('_')[2] for text in df_errors.index]

# %%
df_errors
# Out:
#                                       error  error_corrupted  \
# p_dataset_0.1-a_1_b_1_gamma_1e-10  0.050899         0.122914
# p_dataset_0.2-a_1_b_1_gamma_1e-10  0.048566         0.094455
# p_dataset_0.3-a_1_b_1_gamma_1e-10  0.029589         0.075422
# p_dataset_0.4-a_1_b_1_gamma_1e-10  0.023062         0.068627
# p_dataset_0.5-a_1_b_1_gamma_1e-10  0.011427         0.037389
# p_dataset_0.1-a_1_b_1_gamma_1e-05  0.057314         0.141842
# p_dataset_0.2-a_1_b_1_gamma_1e-05  0.044862         0.103020
# p_dataset_0.3-a_1_b_1_gamma_1e-05  0.034081         0.111596
# p_dataset_0.4-a_1_b_1_gamma_1e-05  0.024807         0.075683
# p_dataset_0.5-a_1_b_1_gamma_1e-05  0.019169         0.057026
# p_dataset_0.1-a_1_b_1_gamma_0.1    0.073136         0.200395
# p_dataset_0.2-a_1_b_1_gamma_0.1    0.070747         0.193858
# p_dataset_0.3-a_1_b_1_gamma_0.1    0.067316         0.185656
# p_dataset_0.4-a_1_b_1_gamma_0.1    0.066815         0.184793
#
#                                    normalized_error_corrupted_imp  \
# p_dataset_0.1-a_1_b_1_gamma_1e-10                        3.248043
# p_dataset_0.2-a_1_b_1_gamma_1e-10                        3.526643
# p_dataset_0.3-a_1_b_1_gamma_1e-10                        3.214039
# p_dataset_0.4-a_1_b_1_gamma_1e-10                        3.117740
# p_dataset_0.5-a_1_b_1_gamma_1e-10                        1.825219
# p_dataset_0.1-a_1_b_1_gamma_1e-05                        3.084918
# p_dataset_0.2-a_1_b_1_gamma_1e-05                        3.210460
# p_dataset_0.3-a_1_b_1_gamma_1e-05                        3.380572
# p_dataset_0.4-a_1_b_1_gamma_1e-05                        3.035150
# p_dataset_0.5-a_1_b_1_gamma_1e-05                        2.605669
# p_dataset_0.1-a_1_b_1_gamma_0.1                          3.056160
# p_dataset_0.2-a_1_b_1_gamma_0.1                          3.966236
# p_dataset_0.3-a_1_b_1_gamma_0.1                          4.612830
# p_dataset_0.4-a_1_b_1_gamma_0.1                          4.869113
#
#                                    normalized_error_corrupted_recon  \
# p_dataset_0.1-a_1_b_1_gamma_1e-10                          1.053633
# p_dataset_0.2-a_1_b_1_gamma_1e-10                          0.816837
# p_dataset_0.3-a_1_b_1_gamma_1e-10                          0.687264
# p_dataset_0.4-a_1_b_1_gamma_1e-10                          0.603200
# p_dataset_0.5-a_1_b_1_gamma_1e-10                          0.324566
# p_dataset_0.1-a_1_b_1_gamma_1e-05                          1.199988
# p_dataset_0.2-a_1_b_1_gamma_1e-05                          0.915046
# p_dataset_0.3-a_1_b_1_gamma_1e-05                          0.776874
# p_dataset_0.4-a_1_b_1_gamma_1e-05                          0.639404
# p_dataset_0.5-a_1_b_1_gamma_1e-05                          0.466572
# p_dataset_0.1-a_1_b_1_gamma_0.1                            1.401934
# p_dataset_0.2-a_1_b_1_gamma_0.1                            1.424884
# p_dataset_0.3-a_1_b_1_gamma_0.1                            1.413157
# p_dataset_0.4-a_1_b_1_gamma_0.1                            1.470154
#
#                                    error_corrupted_imp  error_corrupted_recon  \
# p_dataset_0.1-a_1_b_1_gamma_1e-10             0.620723               0.122914
# p_dataset_0.2-a_1_b_1_gamma_1e-10             0.720185               0.094455
# p_dataset_0.3-a_1_b_1_gamma_1e-10             0.800442               0.075422
# p_dataset_0.4-a_1_b_1_gamma_1e-10             0.781411               0.068627
# p_dataset_0.5-a_1_b_1_gamma_1e-10             0.803011               0.037389
# p_dataset_0.1-a_1_b_1_gamma_1e-05             0.738808               0.141842
# p_dataset_0.2-a_1_b_1_gamma_1e-05             0.761950               0.103020
# p_dataset_0.3-a_1_b_1_gamma_1e-05             0.663984               0.111596
# p_dataset_0.4-a_1_b_1_gamma_1e-05             0.747455               0.075683
# p_dataset_0.5-a_1_b_1_gamma_1e-05             0.761098               0.057026
# p_dataset_0.1-a_1_b_1_gamma_0.1               0.447927               0.200395
# p_dataset_0.2-a_1_b_1_gamma_0.1               0.558074               0.193858
# p_dataset_0.3-a_1_b_1_gamma_0.1               0.638622               0.185656
# p_dataset_0.4-a_1_b_1_gamma_0.1               0.666448               0.184793
#
#                                    error_gp_imputation  gamma beta alpha  \
# p_dataset_0.1-a_1_b_1_gamma_1e-10             0.084848  1e-10    1     1
# p_dataset_0.2-a_1_b_1_gamma_1e-10            77.395851  1e-10    1     1
# p_dataset_0.3-a_1_b_1_gamma_1e-10            73.817070  1e-10    1     1
# p_dataset_0.4-a_1_b_1_gamma_1e-10            32.147064  1e-10    1     1
# p_dataset_0.5-a_1_b_1_gamma_1e-10             0.285200  1e-10    1     1
# p_dataset_0.1-a_1_b_1_gamma_1e-05             0.455011  1e-05    1     1
# p_dataset_0.2-a_1_b_1_gamma_1e-05             0.525199  1e-05    1     1
# p_dataset_0.3-a_1_b_1_gamma_1e-05             0.074365  1e-05    1     1
# p_dataset_0.4-a_1_b_1_gamma_1e-05             0.264817  1e-05    1     1
# p_dataset_0.5-a_1_b_1_gamma_1e-05             6.365082  1e-05    1     1
# p_dataset_0.1-a_1_b_1_gamma_0.1             233.368622    0.1    1     1
# p_dataset_0.2-a_1_b_1_gamma_0.1               0.288432    0.1    1     1
# p_dataset_0.3-a_1_b_1_gamma_0.1               2.388389    0.1    1     1
# p_dataset_0.4-a_1_b_1_gamma_0.1              11.202954    0.1    1     1
#
#                                   p_dataset
# p_dataset_0.1-a_1_b_1_gamma_1e-10       0.1
# p_dataset_0.2-a_1_b_1_gamma_1e-10       0.2
# p_dataset_0.3-a_1_b_1_gamma_1e-10       0.3
# p_dataset_0.4-a_1_b_1_gamma_1e-10       0.4
# p_dataset_0.5-a_1_b_1_gamma_1e-10       0.5
# p_dataset_0.1-a_1_b_1_gamma_1e-05       0.1
# p_dataset_0.2-a_1_b_1_gamma_1e-05       0.2
# p_dataset_0.3-a_1_b_1_gamma_1e-05       0.3
# p_dataset_0.4-a_1_b_1_gamma_1e-05       0.4
# p_dataset_0.5-a_1_b_1_gamma_1e-05       0.5
# p_dataset_0.1-a_1_b_1_gamma_0.1         0.1
# p_dataset_0.2-a_1_b_1_gamma_0.1         0.2
# p_dataset_0.3-a_1_b_1_gamma_0.1         0.3
# p_dataset_0.4-a_1_b_1_gamma_0.1         0.4

# %%
sns.barplot(data = df_errors, x = df_errors.index, y = err, hue = 'alpha')
plt.xticks(rotation = 90);

# %%
import numpy as np
fig, ax = plt.subplots(3,3,figsize=(18,15), sharex=True)
#plt.xticks(rotation=90)
for i,err in enumerate(df_errors.columns[:7].values):
    sns.barplot(data = df_errors, x = df_errors.index, y = err, hue = 'p_dataset', ax = ax[i//3,i%3])
    ax[i//3,i%3].set_xticklabels(df_errors.index, rotation = 90);
    ax[i//3,i%3].set_yscale('log')
# Out:
# /var/folders/7s/75p3d4f145qfrrzfq5vskssc0000gn/T/ipykernel_8767/2783144640.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i//3,i%3].set_xticklabels(df_errors.index, rotation = 90);
# /var/folders/7s/75p3d4f145qfrrzfq5vskssc0000gn/T/ipykernel_8767/2783144640.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i//3,i%3].set_xticklabels(df_errors.index, rotation = 90);
# /var/folders/7s/75p3d4f145qfrrzfq5vskssc0000gn/T/ipykernel_8767/2783144640.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i//3,i%3].set_xticklabels(df_errors.index, rotation = 90);
# /var/folders/7s/75p3d4f145qfrrzfq5vskssc0000gn/T/ipykernel_8767/2783144640.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i//3,i%3].set_xticklabels(df_errors.index, rotation = 90);
# /var/folders/7s/75p3d4f145qfrrzfq5vskssc0000gn/T/ipykernel_8767/2783144640.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i//3,i%3].set_xticklabels(df_errors.index, rotation = 90);
# /var/folders/7s/75p3d4f145qfrrzfq5vskssc0000gn/T/ipykernel_8767/2783144640.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i//3,i%3].set_xticklabels(df_errors.index, rotation = 90);
# /var/folders/7s/75p3d4f145qfrrzfq5vskssc0000gn/T/ipykernel_8767/2783144640.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i//3,i%3].set_xticklabels(df_errors.index, rotation = 90);

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df.plot(kind = "bar", legend=False, logy = True);

# %%
import seaborn as sns
sns.barplot(df_errors, y = 'error', x= df_errors.index, hue = 'p_dataset')
plt.xticks(rotation = 90);

# %%
[text.split('-')[0].split('_')[2] for text in df_errors.index]
# Out:
# ['0.5', '0.5', '0.5', '0.5', '0.4', '0.4']
