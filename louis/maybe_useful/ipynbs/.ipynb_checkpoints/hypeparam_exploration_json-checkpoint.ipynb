# %%
import pandas as pd
import json

# File path to your JSON data
file_path = "intermediate_results.jsonl"  # Update with the actual file path

# Read the JSON file line by line and store each JSON object in a list
data_list = []
with open(file_path, "r") as file:
    for line in file:
        data_list.append(json.loads(line.strip()))

# Normalize JSON data to a Pandas DataFrame
df = pd.json_normalize(data_list, sep='_')

# Display the DataFrame
#import ace_tools as tools
#tools.display_dataframe_to_user(name="Hyperparameter Search Results", dataframe=df)

import numpy as np

# Deal with runs that haven't converged
df.loc[df["metrics_observed_rmse"] == 0, df.columns[df.columns.str.startswith("metrics_")]] = np.nan
df['Converged'] = (df.metrics_observed_rmse==df.metrics_observed_rmse)

metrics_mask = [('metrics' in elt) for elt in df.columns]
metrics = df.columns[metrics_mask]

df = df[df.training_time > 50]

df
# Out:
#       training_time  hyperparameters_run_nb  hyperparameters_alpha  \
# 0        331.694705                       1                    0.1
# 1        209.263873                       1                    0.1
# 6        158.650641                       1                    1.0
# 7        158.486320                       1                    1.0
# 8        167.715503                       1                    1.0
# ...             ...                     ...                    ...
# 1434     220.530927                       2                    0.1
# 1435     140.631762                       2                    0.1
# 1436     182.740669                       2                    0.1
# 1437     114.504040                       2                    0.1
# 1438     465.170254                       2                    0.1
#
#       hyperparameters_beta  hyperparameters_noise_sigma  \
# 0                      0.1                        0.001
# 1                      0.1                        0.001
# 6                      1.0                        0.001
# 7                      1.0                        0.001
# 8                      1.0                        0.001
# ...                    ...                          ...
# 1434                   0.1                        0.100
# 1435                   0.1                        0.100
# 1436                   0.1                        0.100
# 1437                   0.1                        0.100
# 1438                   0.1                        0.001
#
#       hyperparameters_noise_std  hyperparameters_use_mean_z  \
# 0                          0.05                        True
# 1                          0.10                        True
# 6                          0.05                        True
# 7                          0.10                        True
# 8                          0.20                        True
# ...                         ...                         ...
# 1434                       0.50                        True
# 1435                       0.50                        True
# 1436                       0.50                        True
# 1437                       0.50                        True
# 1438                       0.05                        True
#
#       hyperparameters_detach_flag  hyperparameters_lr  metrics_observed_rmse  \
# 0                            True              0.0010               0.061698
# 1                            True              0.0010               0.065414
# 6                            True              0.0010               0.074984
# 7                            True              0.0010               0.072573
# 8                            True              0.0010               0.075122
# ...                           ...                 ...                    ...
# 1434                         True              0.0010               0.187094
# 1435                         True              0.0010               0.171099
# 1436                         True              0.0010               0.153568
# 1437                         True              0.0010               0.180749
# 1438                         True              0.0001               0.111224
#
#       ...  metrics_observed_uncertainty_error_corr  metrics_missing_rmse  \
# 0     ...                                -0.088452              0.673546
# 1     ...                                -0.089328              0.719001
# 6     ...                                 0.010083              0.732706
# 7     ...                                -0.103044              0.645639
# 8     ...                                -0.028056              0.602393
# ...   ...                                      ...                   ...
# 1434  ...                                -0.048154              0.573668
# 1435  ...                                -0.311715              0.570082
# 1436  ...                                -0.262203              0.733624
# 1437  ...                                -0.437136              0.813067
# 1438  ...                                -0.084718              0.741932
#
#       metrics_missing_nll  metrics_missing_elbo  metrics_missing_coverage  \
# 0            23814.958054         -3.248360e+05                  0.195006
# 1            27442.989832         -1.231793e+06                  0.182323
# 6            34169.732503         -2.137429e+05                  0.451226
# 7            23111.864853         -4.363063e+05                  0.347058
# 8            20543.075577         -2.541744e+05                  0.381282
# ...                   ...                   ...                       ...
# 1434          6067.095891         -1.865042e+05                  0.479212
# 1435         21993.002021         -1.142441e+05                  0.514132
# 1436         76278.634920         -1.400573e+05                  0.602720
# 1437        139581.595958         -1.723924e+05                  0.633622
# 1438          9607.955815         -2.512502e+05                  0.097690
#
#       metrics_missing_uncertainty_error_corr  metrics_latent_latent_ks  \
# 0                                   0.045487                  0.464482
# 1                                   0.164430                  0.631829
# 6                                   0.176125                  0.500732
# 7                                   0.141279                  0.521245
# 8                                   0.083250                  0.589585
# ...                                      ...                       ...
# 1434                                0.066262                  0.465532
# 1435                                0.117672                  0.409375
# 1436                                0.122811                  0.634040
# 1437                                0.217031                  0.523369
# 1438                                0.159057                  0.493933
#
#       metrics_reconstruction_overall_coverage  hyperparameters_p_dataset  \
# 0                                    0.541481                        NaN
# 1                                    0.584894                        NaN
# 6                                    0.640053                        NaN
# 7                                    0.667354                        NaN
# 8                                    0.653651                        NaN
# ...                                       ...                        ...
# 1434                                 0.654683                        0.1
# 1435                                 0.707804                        0.3
# 1436                                 0.682937                        0.5
# 1437                                 0.661058                        0.7
# 1438                                 0.384153                        0.1
#
#       Converged
# 0          True
# 1          True
# 6          True
# 7          True
# 8          True
# ...         ...
# 1434       True
# 1435       True
# 1436       True
# 1437       True
# 1438       True
#
# [1253 rows x 23 columns]

# %%
df.loc[df.hyperparameters_p_dataset!=df.hyperparameters_p_dataset,'hyperparameters_p_dataset'] = 0.3

# %%
import matplotlib.pyplot as plt
import seaborn as sns

metrics_use_mean_z = ['metrics_observed_rmse', 'metrics_observed_coverage', 'metrics_missing_elbo',
                     'metrics_missing_rmse','metrics_missing_coverage','metrics_reconstruction_overall_coverage']

hyperparams = df.keys()[1:9].values

for hyperparam in hyperparams:
       print(hyperparam)
       fig, ax = plt.subplots(2,3, figsize=(20,10))
       for i,metric in enumerate(metrics_use_mean_z):
              sns.boxplot(df, y = metric,     
                            x = 'hyperparameters_p_dataset', 
                            hue = hyperparam, 
                            ax = ax[i//3, i%3]);
       plt.show();
       #ax[0, 0].set_yscale('log')
       #ax[1, 0].set_yscale('log')
# Out:
# hyperparameters_run_nb
# hyperparameters_alpha
# hyperparameters_beta
# hyperparameters_noise_sigma
# hyperparameters_noise_std
# hyperparameters_use_mean_z
# hyperparameters_detach_flag
# hyperparameters_lr

# %%
p = 0.5

metrics_use_mean_z = ['metrics_observed_rmse', 'metrics_observed_coverage', 'metrics_observed_uncertainty_error_corr','metrics_latent_latent_ks', 
       'metrics_missing_rmse', 'metrics_missing_coverage', 'metrics_missing_uncertainty_error_corr', 'metrics_reconstruction_overall_coverage']
fig, ax = plt.subplots(2,4, figsize=(20,10))
for i,metric in enumerate(metrics_use_mean_z):
    sns.boxplot(df[df.hyperparameters_p_dataset==p], y = metric, x = 'hyperparameters_noise_sigma', hue = 'hyperparameters_lr', ax = ax[i//4, i%4]);
#ax[0, 0].set_yscale('log')
#ax[1, 0].set_yscale('log')

# %%
metrics_use_mean_z = ['metrics_observed_rmse', 'metrics_observed_coverage', 'metrics_observed_uncertainty_error_corr','metrics_latent_latent_ks', 
       'metrics_missing_rmse', 'metrics_missing_coverage', 'metrics_missing_uncertainty_error_corr', 'metrics_reconstruction_overall_coverage']
fig, ax = plt.subplots(2,4, figsize=(20,10))
for i,metric in enumerate(metrics_use_mean_z):
    sns.boxplot(df, y = metric, 
                x = 'hyperparameters_p_dataset', 
                hue = "hyperparameters_noise_sigma", 
                ax = ax[i//4, i%4]);
#ax[0, 0].set_yscale('log')
#ax[1, 0].set_yscale('log')

# %%
metrics_use_mean_z = ['metrics_observed_rmse', 'metrics_observed_coverage', 'metrics_observed_uncertainty_error_corr','metrics_latent_latent_ks', 
       'metrics_missing_rmse', 'metrics_missing_coverage', 'metrics_missing_uncertainty_error_corr', 'metrics_reconstruction_overall_coverage']
fig, ax = plt.subplots(2,4, figsize=(20,10))
for i,metric in enumerate(metrics_use_mean_z):
    sns.boxplot(df, y = metric, 
                x = 'hyperparameters_p_dataset', 
                hue = "hyperparameters_noise_std", 
                ax = ax[i//4, i%4]);
#ax[0, 0].set_yscale('log')
#ax[1, 0].set_yscale('log')

# %%
metrics_use_mean_z = ['metrics_observed_rmse', 'metrics_observed_coverage', 'metrics_observed_uncertainty_error_corr','metrics_latent_latent_ks', 
       'metrics_missing_rmse', 'metrics_missing_coverage', 'metrics_missing_uncertainty_error_corr', 'metrics_reconstruction_overall_coverage']
fig, ax = plt.subplots(2,4, figsize=(20,10))
for i,metric in enumerate(metrics_use_mean_z):
    sns.boxplot(df, y = metric, x = 'hyperparameters_noise_sigma', hue = 'hyperparameters_lr', ax = ax[i//4, i%4]);
#ax[0, 0].set_yscale('log')
#ax[1, 0].set_yscale('log')

# %%
metrics_use_mean_z = ['metrics_observed_rmse', 'metrics_observed_coverage', 'metrics_observed_uncertainty_error_corr','metrics_latent_latent_ks', 
       'metrics_missing_rmse', 'metrics_missing_coverage', 'metrics_missing_uncertainty_error_corr', 'metrics_reconstruction_overall_coverage']
fig, ax = plt.subplots(2,4, figsize=(20,10))
for i,metric in enumerate(metrics_use_mean_z):
    sns.boxplot(df, y = metric, x = 'hyperparameters_beta', hue = 'hyperparameters_alpha', ax = ax[i//4, i%4]);
#ax[0, 0].set_yscale('log')
#ax[1, 0].set_yscale('log')

# %%
metrics_use_mean_z = ['metrics_observed_rmse', 'metrics_observed_coverage', 'metrics_observed_uncertainty_error_corr','metrics_latent_latent_ks', 
       'metrics_missing_rmse', 'metrics_missing_coverage', 'metrics_missing_uncertainty_error_corr', 'metrics_reconstruction_overall_coverage']
fig, ax = plt.subplots(2,4, figsize=(20,10))
for i,metric in enumerate(metrics_use_mean_z):
    sns.boxplot(df_restricted, y = metric, x = 'hyperparameters_noise_std', hue = 'hyperparameters_noise_sigma', ax = ax[i//4, i%4]);
#ax[0, 0].set_yscale('log')
#ax[1, 0].set_yscale('log')

# %%
mask = (df.hyperparameters_lr<0.01) & (df.hyperparameters_alpha == 1.)
df_restricted = df[mask]

# %%
mask = (df.hyperparameters_lr<0.01) & (df.hyperparameters_alpha == 1.) & (df.hyperparameters_beta == 0.1) & (df.hyperparameters_lr == 0.0001)
df_restricted = df[mask]

metrics_use_mean_z = ['metrics_observed_rmse', 'metrics_observed_coverage', 'metrics_observed_uncertainty_error_corr', 
       'metrics_missing_rmse', 'metrics_missing_coverage', 'metrics_missing_uncertainty_error_corr']

fig, ax = plt.subplots(3, 2, figsize=(15, 15))
handles, labels = None, None

for i, metric in enumerate(metrics_use_mean_z):
    boxplot = sns.boxplot(
        data=df_restricted, 
        y=metric, 
        x='hyperparameters_noise_sigma', 
        hue='hyperparameters_noise_std', 
        ax=ax[i % 3, i // 3]
    )
    
    if handles is None or labels is None:
        handles, labels = boxplot.get_legend_handles_labels()
    ax[i % 3, i // 3].legend_.remove()  # Remove individual legends

# Add a single legend on the side
fig.legend(handles, labels, loc='center right', title='Hyperparameters Noise Std')
plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust layout to fit legend
plt.show()

# %%
df_restricted = df[df.metrics_observed_rmse < 0.1]

# %%
import seaborn as sns

sns.scatterplot(df_restricted, x = 'metrics_observed_coverage', y = 'metrics_missing_coverage', hue = 'hyperparameters_p_dataset')
# Out:
# <Axes: xlabel='metrics_observed_coverage', ylabel='metrics_missing_coverage'>

# %%
fig, ax = plt.subplots(2,2, figsize = (18,8), sharex = True, sharey = True)
cmap = "colorblind"  # Alternative: "cividis", "plasma", "magma"
for i,p in enumerate([0.1, 0.3, 0.5, 0.7]):
    mask = (df.hyperparameters_p_dataset == p) #& (df.hyperparameters_beta == .1) & (df.hyperparameters_lr == 0.001)
    sns.scatterplot(df[mask], 
                    x = 'metrics_observed_coverage', 
                    y = 'metrics_observed_rmse', 
                    hue = 'hyperparameters_noise_sigma',
                    style = 'hyperparameters_alpha',
                    ax = ax[i//2,i%2],
                    palette = cmap)
    ax[i//2,i%2].set_title(f'p = {p}')

# %%
fig, ax = plt.subplots(2,2, figsize = (18,8), sharex = True, sharey = True)
cmap = "colorblind"  # Alternative: "cividis", "plasma", "magma"
for i,p in enumerate([0.1, 0.3, 0.5, 0.7]):
    sns.scatterplot(df_restricted[df_restricted.hyperparameters_p_dataset==p], 
                    x = 'metrics_missing_coverage', 
                    y = 'metrics_missing_rmse', 
                    hue = 'hyperparameters_noise_sigma', 
                    ax = ax[i//2,i%2],
                    palette = cmap)
    ax[i//2,i%2].set_title(f'p = {p}')

# %%
fig, ax = plt.subplots(2,2, figsize = (18,8), sharex = True, sharey = True)
for i,p in enumerate([0.1, 0.3, 0.5, 0.7]):
    sns.scatterplot(df[df.hyperparameters_p_dataset==p], 
                    x = 'metrics_observed_rmse', 
                    y = 'metrics_missing_rmse', 
                    hue = 'hyperparameters_noise_sigma', 
                    palette = cmap,
                    ax = ax[i//2,i%2])

# %%
import seaborn as sns

#for p in [0.1, ]
sns.scatterplot(df, x = 'metrics_observed_rmse', y = 'metrics_missing_rmse', hue = 'hyperparameters_p_dataset')
# Out:
# <Axes: xlabel='metrics_observed_rmse', ylabel='metrics_missing_rmse'>

# %%
import seaborn as sns

sns.scatterplot(df, x = 'metrics_observed_coverage', y = 'metrics_missing_coverage', hue = 'hyperparameters_noise_std')
# Out:
# <Axes: xlabel='metrics_observed_coverage', ylabel='metrics_missing_coverage'>

# %%
sns.scatterplot(df, x = 'metrics_observed_coverage', y = 'metrics_observed_uncertainty_error_corr', hue = 'hyperparameters_lr')
# Out:
# <Axes: xlabel='metrics_observed_coverage', ylabel='metrics_observed_uncertainty_error_corr'>

# %%
sns.scatterplot(df, x = 'metrics_missing_coverage', y = 'metrics_missing_rmse', hue = 'hyperparameters_noise_sigma')
plt.title('Missing coverage vs Missing RMSE')
# Out:
# Text(0.5, 1.0, 'Missing coverage vs Missing RMSE')

# %%
sns.scatterplot(df, x = 'metrics_missing_coverage', y = 'metrics_missing_rmse', hue = 'hyperparameters_beta')
plt.title('Missing coverage vs Missing RMSE')
# Out:
# Text(0.5, 1.0, 'Missing coverage vs Missing RMSE')

# %%
sns.scatterplot(df, x = 'metrics_missing_coverage', y = 'metrics_missing_rmse', hue = 'hyperparameters_noise_std')
plt.title('Missing coverage vs Missing RMSE')
# Out:
# Text(0.5, 1.0, 'Missing coverage vs Missing RMSE')

# %%
sns.scatterplot(df, x = 'metrics_observed_rmse', y = 'metrics_missing_rmse', hue = 'hyperparameters_lr')
# Out:
# <Axes: xlabel='metrics_observed_rmse', ylabel='metrics_missing_rmse'>

# %%
sns.scatterplot(df, x = 'metrics_observed_rmse', y = 'metrics_missing_rmse', hue = 'hyperparameters_noise_std')
# Out:
# <Axes: xlabel='metrics_observed_rmse', ylabel='metrics_missing_rmse'>

# %%
sns.scatterplot(df, x = 'metrics_observed_rmse', y = 'metrics_missing_rmse', hue = 'hyperparameters_noise_sigma')
# Out:
# <Axes: xlabel='metrics_observed_rmse', ylabel='metrics_missing_rmse'>

# %%
sns.boxplot(df, x = 'hyperparameters_noise_sigma', y = 'metrics_missing_rmse', hue = 'hyperparameters_beta')
# Out:
# <Axes: xlabel='hyperparameters_noise_sigma', ylabel='metrics_missing_rmse'>

# %%
hp1, hp2 = 'hyperparameters_alpha','hyperparameters_beta'
sns.scatterplot(df, x = 'metrics_observed_rmse', y = 'metrics_missing_rmse', 
                hue = df[[hp1, hp2, 'hyperparameters_use_mean_z']].apply(tuple, axis=1))
# Out:
# <Axes: xlabel='metrics_observed_rmse', ylabel='metrics_missing_rmse'>

# %%
sns.scatterplot(df, x = 'metrics_observed_rmse', y = 'metrics_missing_rmse', hue = df[['hyperparameters_noise_sigma','hyperparameters_noise_std']].apply(tuple, axis=1))
# Out:
# <Axes: xlabel='metrics_observed_rmse', ylabel='metrics_missing_rmse'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

x = 'hyperparameters_noise_sigma'
y = 'rmse'

y_0 = f'metrics_missing_{y}'
y_1 = f'metrics_observed_{y}'
hue = 'hyperparameters_noise_std'
hue = 'hyperparameters_use_mean_z'

fig, ax = plt.subplots(1, 2, figsize=(18,5))
sns.boxplot(df, x = x, y = y_0, hue = hue, ax = ax[0])
sns.boxplot(df, x = x, y = y_1, hue = hue, ax = ax[1])
# Out:
# <Axes: xlabel='hyperparameters_noise_sigma', ylabel='metrics_observed_rmse'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

x = 'hyperparameters_noise_std'
y = 'rmse'

y_0 = f'metrics_missing_{y}'
y_1 = f'metrics_observed_{y}'
hue = 'hyperparameters_noise_std'
hue = 'hyperparameters_use_mean_z'
#hue = None

fig, ax = plt.subplots(1, 2, figsize=(18,5))
sns.boxplot(df, x = x, y = y_0, hue = hue, ax = ax[0])
sns.boxplot(df, x = x, y = y_1, hue = hue, ax = ax[1])
# Out:
# <Axes: xlabel='hyperparameters_noise_std', ylabel='metrics_observed_rmse'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

x = 'hyperparameters_beta'
y = 'rmse'

y_0 = f'metrics_missing_{y}'
y_1 = f'metrics_observed_{y}'
hue = 'hyperparameters_beta'
#hue = 'hyperparameters_use_mean_z'
hue = None

fig, ax = plt.subplots(1, 2, figsize=(18,5))
sns.boxplot(df, x = x, y = y_0, hue = hue, ax = ax[0])
sns.boxplot(df, x = x, y = y_1, hue = hue, ax = ax[1])
# Out:
# <Axes: xlabel='hyperparameters_beta', ylabel='metrics_observed_rmse'>

# %%
sns.boxplot(df, x = 'hyperparameters_noise_sigma', y = 'metrics_missing_rmse', hue = 'hyperparameters_noise_std')
# Out:
# <Axes: xlabel='hyperparameters_noise_sigma', ylabel='metrics_missing_rmse'>

# %%
df['Converged'] = (df.metrics_observed_rmse!=df.metrics_observed_rmse)

# %%
sns.boxplot(df, x = 'Converged', y = 'hyperparameters_beta')
# Out:
# <Axes: xlabel='Converged', ylabel='hyperparameters_beta'>

# %%
df[df.Converged]
# Out:
#     training_time  hyperparameters_alpha  hyperparameters_beta  \
# 0       19.485421                   0.01                   0.5
# 4       25.464081                   0.01                   0.5
# 6       33.323633                   0.01                   0.5
# 13      28.204585                   0.01                   0.5
# 14      51.028997                   0.01                   0.5
# 15      20.278499                   0.01                   0.5
# 20      74.546689                   0.01                   0.5
# 21      12.816927                   0.01                   0.5
# 23      42.778055                   0.01                   0.5
# 25      15.628214                   0.01                   0.5
# 26      28.844880                   0.01                   0.5
# 27      16.909429                   0.01                   0.5
# 28       3.182013                   0.01                   0.5
# 29      46.933837                   0.01                   0.5
# 30      42.212021                   0.01                   0.5
# 31      21.249747                   0.01                   0.5
# 32      70.868757                   0.01                   0.5
# 34       0.221145                   0.01                   0.5
# 35      73.154594                   0.01                   0.5
# 37      34.515887                   0.01                   1.0
# 39      76.893675                   0.01                   1.0
# 42      38.095650                   0.01                   0.5
# 44      14.237448                   0.01                   0.5
# 52      12.690436                   0.01                   0.5
# 53      82.447814                   0.01                   0.5
# 55      43.709382                   0.01                   0.5
# 56      23.943283                   0.01                   0.5
# 57      23.720792                   0.01                   0.5
# 58      33.999367                   0.01                   0.5
# 62      31.929328                   0.01                   0.5
# 69      19.821758                   0.01                   0.5
# 72      12.760337                   0.01                   0.5
# 73      52.343861                   0.01                   0.5
# 75      14.241681                   0.01                   0.5
# 76       9.744329                   0.01                   0.5
# 78      41.686611                   0.01                   1.0
# 79      37.501535                   0.01                   1.0
# 81      48.940202                   0.01                   1.0
# 84       9.454810                   0.01                   1.0
# 85       6.355741                   0.01                   1.0
# 86      37.279649                   0.01                   1.0
#
#     hyperparameters_noise_sigma  hyperparameters_noise_std  \
# 0                         0.005                       0.05
# 4                         0.005                       0.05
# 6                         0.005                       0.10
# 13                        0.010                       0.05
# 14                        0.010                       0.05
# 15                        0.010                       0.05
# 20                        0.010                       0.10
# 21                        0.010                       0.20
# 23                        0.010                       0.20
# 25                        0.020                       0.05
# 26                        0.020                       0.05
# 27                        0.020                       0.05
# 28                        0.020                       0.05
# 29                        0.020                       0.10
# 30                        0.020                       0.10
# 31                        0.020                       0.10
# 32                        0.020                       0.10
# 34                        0.020                       0.20
# 35                        0.020                       0.20
# 37                        0.005                       0.05
# 39                        0.005                       0.05
# 42                        0.005                       0.05
# 44                        0.005                       0.10
# 52                        0.010                       0.05
# 53                        0.010                       0.05
# 55                        0.010                       0.05
# 56                        0.010                       0.10
# 57                        0.010                       0.10
# 58                        0.010                       0.10
# 62                        0.010                       0.20
# 69                        0.005                       0.05
# 72                        0.010                       0.05
# 73                        0.010                       0.10
# 75                        0.020                       0.05
# 76                        0.020                       0.10
# 78                        0.005                       0.05
# 79                        0.005                       0.10
# 81                        0.010                       0.05
# 84                        0.020                       0.05
# 85                        0.020                       0.10
# 86                        0.020                       0.20
#
#     hyperparameters_use_mean_z  hyperparameters_detach_flag  \
# 0                         True                         True
# 4                        False                        False
# 6                         True                        False
# 13                        True                         True
# 14                        True                        False
# 15                       False                         True
# 20                       False                        False
# 21                        True                         True
# 23                       False                         True
# 25                        True                         True
# 26                        True                        False
# 27                       False                         True
# 28                       False                        False
# 29                        True                         True
# 30                        True                        False
# 31                       False                         True
# 32                       False                        False
# 34                        True                        False
# 35                       False                         True
# 37                        True                         True
# 39                       False                         True
# 42                       False                         True
# 44                        True                         True
# 52                        True                         True
# 53                        True                        False
# 55                       False                        False
# 56                        True                         True
# 57                        True                        False
# 58                       False                         True
# 62                       False                         True
# 69                        True                         True
# 72                        True                         True
# 73                        True                         True
# 75                        True                         True
# 76                        True                         True
# 78                        True                         True
# 79                        True                         True
# 81                        True                         True
# 84                        True                         True
# 85                        True                         True
# 86                        True                         True
#
#     metrics_observed_rmse  metrics_observed_nll  metrics_observed_elbo  \
# 0                     NaN                   NaN                    NaN
# 4                     NaN                   NaN                    NaN
# 6                     NaN                   NaN                    NaN
# 13                    NaN                   NaN                    NaN
# 14                    NaN                   NaN                    NaN
# 15                    NaN                   NaN                    NaN
# 20                    NaN                   NaN                    NaN
# 21                    NaN                   NaN                    NaN
# 23                    NaN                   NaN                    NaN
# 25                    NaN                   NaN                    NaN
# 26                    NaN                   NaN                    NaN
# 27                    NaN                   NaN                    NaN
# 28                    NaN                   NaN                    NaN
# 29                    NaN                   NaN                    NaN
# 30                    NaN                   NaN                    NaN
# 31                    NaN                   NaN                    NaN
# 32                    NaN                   NaN                    NaN
# 34                    NaN                   NaN                    NaN
# 35                    NaN                   NaN                    NaN
# 37                    NaN                   NaN                    NaN
# 39                    NaN                   NaN                    NaN
# 42                    NaN                   NaN                    NaN
# 44                    NaN                   NaN                    NaN
# 52                    NaN                   NaN                    NaN
# 53                    NaN                   NaN                    NaN
# 55                    NaN                   NaN                    NaN
# 56                    NaN                   NaN                    NaN
# 57                    NaN                   NaN                    NaN
# 58                    NaN                   NaN                    NaN
# 62                    NaN                   NaN                    NaN
# 69                    NaN                   NaN                    NaN
# 72                    NaN                   NaN                    NaN
# 73                    NaN                   NaN                    NaN
# 75                    NaN                   NaN                    NaN
# 76                    NaN                   NaN                    NaN
# 78                    NaN                   NaN                    NaN
# 79                    NaN                   NaN                    NaN
# 81                    NaN                   NaN                    NaN
# 84                    NaN                   NaN                    NaN
# 85                    NaN                   NaN                    NaN
# 86                    NaN                   NaN                    NaN
#
#     metrics_observed_coverage  metrics_observed_uncertainty_error_corr  \
# 0                         NaN                                      NaN
# 4                         NaN                                      NaN
# 6                         NaN                                      NaN
# 13                        NaN                                      NaN
# 14                        NaN                                      NaN
# 15                        NaN                                      NaN
# 20                        NaN                                      NaN
# 21                        NaN                                      NaN
# 23                        NaN                                      NaN
# 25                        NaN                                      NaN
# 26                        NaN                                      NaN
# 27                        NaN                                      NaN
# 28                        NaN                                      NaN
# 29                        NaN                                      NaN
# 30                        NaN                                      NaN
# 31                        NaN                                      NaN
# 32                        NaN                                      NaN
# 34                        NaN                                      NaN
# 35                        NaN                                      NaN
# 37                        NaN                                      NaN
# 39                        NaN                                      NaN
# 42                        NaN                                      NaN
# 44                        NaN                                      NaN
# 52                        NaN                                      NaN
# 53                        NaN                                      NaN
# 55                        NaN                                      NaN
# 56                        NaN                                      NaN
# 57                        NaN                                      NaN
# 58                        NaN                                      NaN
# 62                        NaN                                      NaN
# 69                        NaN                                      NaN
# 72                        NaN                                      NaN
# 73                        NaN                                      NaN
# 75                        NaN                                      NaN
# 76                        NaN                                      NaN
# 78                        NaN                                      NaN
# 79                        NaN                                      NaN
# 81                        NaN                                      NaN
# 84                        NaN                                      NaN
# 85                        NaN                                      NaN
# 86                        NaN                                      NaN
#
#     metrics_missing_rmse  metrics_missing_nll  metrics_missing_elbo  \
# 0                    NaN                  NaN                   NaN
# 4                    NaN                  NaN                   NaN
# 6                    NaN                  NaN                   NaN
# 13                   NaN                  NaN                   NaN
# 14                   NaN                  NaN                   NaN
# 15                   NaN                  NaN                   NaN
# 20                   NaN                  NaN                   NaN
# 21                   NaN                  NaN                   NaN
# 23                   NaN                  NaN                   NaN
# 25                   NaN                  NaN                   NaN
# 26                   NaN                  NaN                   NaN
# 27                   NaN                  NaN                   NaN
# 28                   NaN                  NaN                   NaN
# 29                   NaN                  NaN                   NaN
# 30                   NaN                  NaN                   NaN
# 31                   NaN                  NaN                   NaN
# 32                   NaN                  NaN                   NaN
# 34                   NaN                  NaN                   NaN
# 35                   NaN                  NaN                   NaN
# 37                   NaN                  NaN                   NaN
# 39                   NaN                  NaN                   NaN
# 42                   NaN                  NaN                   NaN
# 44                   NaN                  NaN                   NaN
# 52                   NaN                  NaN                   NaN
# 53                   NaN                  NaN                   NaN
# 55                   NaN                  NaN                   NaN
# 56                   NaN                  NaN                   NaN
# 57                   NaN                  NaN                   NaN
# 58                   NaN                  NaN                   NaN
# 62                   NaN                  NaN                   NaN
# 69                   NaN                  NaN                   NaN
# 72                   NaN                  NaN                   NaN
# 73                   NaN                  NaN                   NaN
# 75                   NaN                  NaN                   NaN
# 76                   NaN                  NaN                   NaN
# 78                   NaN                  NaN                   NaN
# 79                   NaN                  NaN                   NaN
# 81                   NaN                  NaN                   NaN
# 84                   NaN                  NaN                   NaN
# 85                   NaN                  NaN                   NaN
# 86                   NaN                  NaN                   NaN
#
#     metrics_missing_coverage  metrics_missing_uncertainty_error_corr  \
# 0                        NaN                                     NaN
# 4                        NaN                                     NaN
# 6                        NaN                                     NaN
# 13                       NaN                                     NaN
# 14                       NaN                                     NaN
# 15                       NaN                                     NaN
# 20                       NaN                                     NaN
# 21                       NaN                                     NaN
# 23                       NaN                                     NaN
# 25                       NaN                                     NaN
# 26                       NaN                                     NaN
# 27                       NaN                                     NaN
# 28                       NaN                                     NaN
# 29                       NaN                                     NaN
# 30                       NaN                                     NaN
# 31                       NaN                                     NaN
# 32                       NaN                                     NaN
# 34                       NaN                                     NaN
# 35                       NaN                                     NaN
# 37                       NaN                                     NaN
# 39                       NaN                                     NaN
# 42                       NaN                                     NaN
# 44                       NaN                                     NaN
# 52                       NaN                                     NaN
# 53                       NaN                                     NaN
# 55                       NaN                                     NaN
# 56                       NaN                                     NaN
# 57                       NaN                                     NaN
# 58                       NaN                                     NaN
# 62                       NaN                                     NaN
# 69                       NaN                                     NaN
# 72                       NaN                                     NaN
# 73                       NaN                                     NaN
# 75                       NaN                                     NaN
# 76                       NaN                                     NaN
# 78                       NaN                                     NaN
# 79                       NaN                                     NaN
# 81                       NaN                                     NaN
# 84                       NaN                                     NaN
# 85                       NaN                                     NaN
# 86                       NaN                                     NaN
#
#     metrics_latent_latent_ks  metrics_reconstruction_overall_coverage  \
# 0                        NaN                                      NaN
# 4                        NaN                                      NaN
# 6                        NaN                                      NaN
# 13                       NaN                                      NaN
# 14                       NaN                                      NaN
# 15                       NaN                                      NaN
# 20                       NaN                                      NaN
# 21                       NaN                                      NaN
# 23                       NaN                                      NaN
# 25                       NaN                                      NaN
# 26                       NaN                                      NaN
# 27                       NaN                                      NaN
# 28                       NaN                                      NaN
# 29                       NaN                                      NaN
# 30                       NaN                                      NaN
# 31                       NaN                                      NaN
# 32                       NaN                                      NaN
# 34                       NaN                                      NaN
# 35                       NaN                                      NaN
# 37                       NaN                                      NaN
# 39                       NaN                                      NaN
# 42                       NaN                                      NaN
# 44                       NaN                                      NaN
# 52                       NaN                                      NaN
# 53                       NaN                                      NaN
# 55                       NaN                                      NaN
# 56                       NaN                                      NaN
# 57                       NaN                                      NaN
# 58                       NaN                                      NaN
# 62                       NaN                                      NaN
# 69                       NaN                                      NaN
# 72                       NaN                                      NaN
# 73                       NaN                                      NaN
# 75                       NaN                                      NaN
# 76                       NaN                                      NaN
# 78                       NaN                                      NaN
# 79                       NaN                                      NaN
# 81                       NaN                                      NaN
# 84                       NaN                                      NaN
# 85                       NaN                                      NaN
# 86                       NaN                                      NaN
#
#     Converged
# 0        True
# 4        True
# 6        True
# 13       True
# 14       True
# 15       True
# 20       True
# 21       True
# 23       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
# 30       True
# 31       True
# 32       True
# 34       True
# 35       True
# 37       True
# 39       True
# 42       True
# 44       True
# 52       True
# 53       True
# 55       True
# 56       True
# 57       True
# 58       True
# 62       True
# 69       True
# 72       True
# 73       True
# 75       True
# 76       True
# 78       True
# 79       True
# 81       True
# 84       True
# 85       True
# 86       True
