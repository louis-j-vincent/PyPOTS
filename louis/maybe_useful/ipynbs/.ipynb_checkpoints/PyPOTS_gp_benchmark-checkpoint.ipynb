# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from PyPOTS_gp_benchmark_helpers import artifical_GP_generation

dataset_train_nan, dataset_val_nan, dataset_train, dataset_val, X_normalized, X = artifical_GP_generation(n_observations_per_group = 500,
                                                n_dimensions = 3,
                                                n_time_points = 30,
                                                n_new_dims = 3,
                                                p_dataset = 0.7)
# Out:
# 100%|███████████████████████████████████████| 500/500 [00:00<00:00, 2660.07it/s]

# %%
import sys
sys.path.append("..")

# %%
# Model training. This is PyPOTS showtime.
from pypots.imputation import GP_UAE
from pypots.utils.metrics import calc_mae
from pypots.optim.adam import Adam
from torch.optim.lr_scheduler import LRScheduler

gpuae = GP_UAE(n_steps = dataset_train['X'].shape[1], 
            n_features = dataset_train['X'].shape[2], 
            latent_size = 6, 
            epochs = 300, 
            batch_size = 64,
            beta = 1., 
            K = 5,  
            encoder_sizes = (256,128,), 
            decoder_sizes = (128,128,),
            optimizer = Adam(weight_decay=0.001), #lr = 1e-4
            patience = 30,
            p = 0.1
            )

gpuae.model.backbone.alpha = 1e0
gpuae.model.backbone.beta = 1e-10
gpuae.model.backbone.gamma = 1e-10
gpuae.model.backbone.sigma1 = 1e-3
gpuae.model.backbone.sigma2 = 1e-1

gpuae.model.backbone.sampling = True
gpuae.model.backbone.use_mean = True
gpuae.model.backbone.noise_std = 1e-2
gpuae.model.backbone.detach = True
gpuae.model.backbone.compensate = False
gpuae.use_gp = False
gpuae.train_gp = False
gpuae.gp.plot_while_training = True

gpuae.model.backbone.p = 0.3
gpuae.model.backbone.device = 'cpu'

import torch
with torch.autograd.set_detect_anomaly(True):
    gpuae.fit(dataset_train_nan, dataset_val_nan)  # train the model on the dataset
# Out:
# 2025-03-15 22:28:11 [INFO]: No given device, using default device: cpu
# 2025-03-15 22:28:11 [WARNING]: ‼️ saving_path not given. Model files and tensorboard file will not be saved.
# 2025-03-15 22:28:11 [INFO]: GP_UAE initialized with the given hyperparameters, the number of trainable parameters: 54,031
# Model dimensions is:
# GpvaeEncoder(
#   (net): Sequential(
#     (0): Linear(in_features=6, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=128, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#   )
#   (mu_layer): Linear(in_features=128, out_features=6, bias=True)
#   (logvar_layer): Linear(in_features=128, out_features=6, bias=True)
# )
# GpvaeDecoder(
#   (net): Sequential(
#     (0): Linear(in_features=6, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=3, bias=True)
#   )
# )
# 2025-03-15 22:28:12 [INFO]: Epoch 001 - training loss: 299.7868, validation loss: 258.1092
# 2025-03-15 22:28:12 [INFO]: Epoch 002 - training loss: 192.5550, validation loss: 117.0968
# 2025-03-15 22:28:12 [WARNING]: ‼️ Training got interrupted by the user. Exist now ...
# 2025-03-15 22:28:12 [INFO]: Finished training. The best model is from epoch#2.
# training kernel

# %%
gpuae_no_sampling = gpuae

# %%
import numpy as np
import torch
import torch.distributions as dist
import matplotlib.pyplot as plt

# ==========================
# 🚀 Utility Functions
# ==========================

def compute_rmse(true_data, imputed_data, missing_mask):
    """
    Compute RMSE between imputed and true values, considering only missing values.
    """
    missing_values = missing_mask.astype(bool)
    mse = np.mean((true_data[missing_values] - imputed_data[missing_values]) ** 2)
    return np.sqrt(mse)

def compute_nll(recon_mu, recon_var, true_data, missing_mask):
    """
    Compute the Negative Log-Likelihood (NLL) for missing values.
    """
    missing_values = missing_mask.astype(bool)
    recon_var = np.clip(recon_var, 1e-6, None)  # Avoid division by zero
    nll = 0.5 * np.sum(
        (true_data[missing_values] - recon_mu[missing_values])**2 / recon_var[missing_values]
        + np.log(recon_var[missing_values]) + np.log(2 * np.pi)
    )
    return nll

def compute_kl_divergence(q_mu, q_var, p_mu=0, p_var=1):
    """
    Compute KL divergence between approximate posterior q(z|x) and prior p(z).
    """
    q_dist = dist.Normal(q_mu, torch.sqrt(q_var))
    p_dist = dist.Normal(p_mu, torch.sqrt(torch.tensor(p_var)))
    kl_div = torch.distributions.kl_divergence(q_dist, p_dist)
    return kl_div.sum().item()

def compute_information_curve(X_true, X_imputed, missing_mask):
    """
    Compute the Information Curve (IC) by iteratively adding the most informative feature.
    """
    n_features = X_true.shape[1]
    observed_mask = np.zeros_like(missing_mask, dtype=bool)
    info_curve = []

    for _ in range(n_features):
        best_feature = None
        best_rmse = float('inf')

        for feature in range(n_features):
            if observed_mask[:, feature].any():  # Skip if already observed
                continue

            temp_mask = observed_mask.copy()
            temp_mask[:, feature] = True

            rmse = compute_rmse(X_true, X_imputed, temp_mask)
            if rmse < best_rmse:
                best_rmse = rmse
                best_feature = feature

        observed_mask[:, best_feature] = True
        info_curve.append(best_rmse)

    return info_curve

# ==========================
# 🚀 Benchmarking Function
# ==========================

def benchmark_models(models, model_names, X, missing_mask):
    """
    Compare two models on RMSE, NLL, ELBO, and IC.
    
    Parameters:
    - models (list): List containing two trained models [gpvae, gpvae2].
    - model_names (list): List of model names for display.
    - X (numpy array): Input data (ground truth).
    - missing_mask (numpy array): Binary mask (1 = missing, 0 = observed).
    
    Returns:
    - Dictionary with evaluation results.
    """
    results = {}

    for i, model in enumerate(models):
        print(f"\n=== Evaluating {model_names[i]} ===\n")

        # Encode & Decode
        qz_x = model.model.backbone.encode(torch.tensor(X).float())
        z = qz_x.rsample()
        z = qz_x.mean
        X_recon = np.array(model.model.backbone.decode(z).mean.detach().numpy())

        # Compute Metrics
        rmse = compute_rmse(X, X_recon, missing_mask)
        nll = compute_nll(X_recon, np.ones_like(X_recon) * 0.1, X, missing_mask)
        kl_div = compute_kl_divergence(qz_x.mean.detach(), qz_x.variance.detach())
        elbo = -nll - kl_div
        info_curve = compute_information_curve(X, X_recon, missing_mask)

        # Store Results
        results[model_names[i]] = {
            "RMSE": rmse,
            "NLL": nll,
            "ELBO": elbo,
            "Information Curve": info_curve
        }

        # Print Results
        print(f"RMSE: {rmse:.4f}")
        print(f"NLL: {nll:.4f}")
        print(f"ELBO: {elbo:.4f}")

    # ==========================
    # 🚀 Plot Information Curves
    # ==========================
    plt.figure(figsize=(8,6))
    for i, model_name in enumerate(model_names):
        plt.plot(results[model_name]["Information Curve"], label=f"{model_name} IC")
    
    plt.xlabel("Number of Observed Features")
    plt.ylabel("RMSE")
    plt.legend()
    plt.title("Information Curve Comparison")
    plt.show()

    return results

# ==========================
# 🚀 Run Benchmarking
# ==========================

# Define models and names
models = [gpuae, gpuae_no_sampling]
model_names = ["GPUAE_sampling", "GPUAE_no_sampling"]

# Identify missing values
missing_mask = (X == 0)

# Run Benchmark
results = benchmark_models(models, model_names, X, missing_mask)
# Out:
# === Evaluating GPUAE_sampling ===
#
# RMSE: 0.2068
# NLL: -581.8248
# ELBO: -155776.8627
#
# === Evaluating GPUAE_no_sampling ===
#
# RMSE: 0.2326
# NLL: 1195.1642
# ELBO: -255886.0079

# %%
torch.save(gpuae.model.backbone.encoder.state_dict().copy(), 'encoder_uae')
torch.save(gpuae.model.backbone.decoder.state_dict().copy(), 'decoder_uae')

# %%
state_dict = torch.load('encoder_uae');
gpuae.model.backbone.encoder.load_state_dict(state_dict);
state_dict = torch.load('decoder_uae');
gpuae.model.backbone.decoder.load_state_dict(state_dict);
# Out:
# /var/folders/7s/75p3d4f145qfrrzfq5vskssc0000gn/T/ipykernel_42907/1864936539.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load('encoder_uae');
# /var/folders/7s/75p3d4f145qfrrzfq5vskssc0000gn/T/ipykernel_42907/1864936539.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load('decoder_uae');

# %%
gpuae.fit(dataset_train_nan, dataset_val_nan)  # train the model on the dataset
# Out:
# 2025-03-09 19:51:15 [INFO]: Epoch 001 - training loss: -0.2463, validation loss: -0.6238
# 2025-03-09 19:51:15 [INFO]: Epoch 002 - training loss: -0.4533, validation loss: -0.4693
# 2025-03-09 19:51:16 [INFO]: Epoch 003 - training loss: -0.5672, validation loss: -0.4798
# 2025-03-09 19:51:16 [INFO]: Epoch 004 - training loss: -0.6706, validation loss: -0.6882
# 2025-03-09 19:51:17 [INFO]: Epoch 005 - training loss: -0.7398, validation loss: -0.7934
# 2025-03-09 19:51:17 [INFO]: Epoch 006 - training loss: -0.8156, validation loss: -0.7724
# 2025-03-09 19:51:18 [INFO]: Epoch 007 - training loss: -0.8279, validation loss: -0.8100
# 2025-03-09 19:51:18 [INFO]: Epoch 008 - training loss: -0.8584, validation loss: -0.8087
# 2025-03-09 19:51:19 [INFO]: Epoch 009 - training loss: -0.8604, validation loss: -0.8504
# 2025-03-09 19:51:19 [INFO]: Epoch 010 - training loss: -0.8669, validation loss: -0.8419
# 2025-03-09 19:51:19 [INFO]: Epoch 011 - training loss: -0.8896, validation loss: -0.8436
# 2025-03-09 19:51:20 [INFO]: Epoch 012 - training loss: -0.8717, validation loss: -0.8495
# 2025-03-09 19:51:20 [INFO]: Epoch 013 - training loss: -0.8790, validation loss: -0.8547
# 2025-03-09 19:51:21 [INFO]: Epoch 014 - training loss: -0.8834, validation loss: -0.8573
# 2025-03-09 19:51:21 [INFO]: Epoch 015 - training loss: -0.8861, validation loss: -0.8454
# 2025-03-09 19:51:22 [INFO]: Epoch 016 - training loss: -0.8745, validation loss: -0.8519
# 2025-03-09 19:51:22 [INFO]: Epoch 017 - training loss: -0.8820, validation loss: -0.8634
# 2025-03-09 19:51:22 [INFO]: Epoch 018 - training loss: -0.8908, validation loss: -0.8449
# 2025-03-09 19:51:23 [INFO]: Epoch 019 - training loss: -0.8788, validation loss: -0.8383
# 2025-03-09 19:51:24 [INFO]: Epoch 020 - training loss: -0.8619, validation loss: -0.8595
# 2025-03-09 19:51:24 [INFO]: Epoch 021 - training loss: -0.8679, validation loss: -0.8618
# 2025-03-09 19:51:24 [INFO]: Epoch 022 - training loss: -0.8562, validation loss: -0.8594
# 2025-03-09 19:51:25 [INFO]: Epoch 023 - training loss: -0.8963, validation loss: -0.8259
# 2025-03-09 19:51:25 [INFO]: Epoch 024 - training loss: -0.8856, validation loss: -0.8665
# 2025-03-09 19:51:25 [INFO]: Epoch 025 - training loss: -0.8970, validation loss: -0.8727
# 2025-03-09 19:51:26 [INFO]: Epoch 026 - training loss: -0.8682, validation loss: -0.8145
# 2025-03-09 19:51:26 [INFO]: Epoch 027 - training loss: -0.8245, validation loss: -0.7873
# 2025-03-09 19:51:27 [INFO]: Epoch 028 - training loss: -0.8733, validation loss: -0.8580
# 2025-03-09 19:51:27 [INFO]: Epoch 029 - training loss: -0.8808, validation loss: -0.8058
# 2025-03-09 19:51:27 [INFO]: Epoch 030 - training loss: -0.8538, validation loss: -0.8633
# 2025-03-09 19:51:28 [INFO]: Epoch 031 - training loss: -0.9004, validation loss: -0.8613
# 2025-03-09 19:51:28 [INFO]: Epoch 032 - training loss: -0.8952, validation loss: -0.8573
# 2025-03-09 19:51:29 [INFO]: Epoch 033 - training loss: -0.9025, validation loss: -0.8608
# 2025-03-09 19:51:29 [INFO]: Epoch 034 - training loss: -0.8716, validation loss: -0.6996
# 2025-03-09 19:51:30 [INFO]: Epoch 035 - training loss: -0.6367, validation loss: -0.7014
# 2025-03-09 19:51:30 [INFO]: Epoch 036 - training loss: -0.7324, validation loss: -0.6322
# 2025-03-09 19:51:31 [INFO]: Epoch 037 - training loss: -0.7521, validation loss: -0.7873
# 2025-03-09 19:51:31 [INFO]: Epoch 038 - training loss: -0.7643, validation loss: -0.8172
# 2025-03-09 19:51:31 [INFO]: Epoch 039 - training loss: -0.8112, validation loss: -0.8484
# 2025-03-09 19:51:32 [INFO]: Epoch 040 - training loss: -0.8539, validation loss: -0.8394
# 2025-03-09 19:51:32 [INFO]: Epoch 041 - training loss: -0.8629, validation loss: -0.8534
# 2025-03-09 19:51:32 [INFO]: Epoch 042 - training loss: -0.8777, validation loss: -0.8266
# 2025-03-09 19:51:33 [INFO]: Epoch 043 - training loss: -0.8565, validation loss: -0.8523
# 2025-03-09 19:51:33 [INFO]: Epoch 044 - training loss: -0.8813, validation loss: -0.8514
# 2025-03-09 19:51:34 [INFO]: Epoch 045 - training loss: -0.8902, validation loss: -0.8612
# 2025-03-09 19:51:34 [INFO]: Epoch 046 - training loss: -0.8942, validation loss: -0.8562
# 2025-03-09 19:51:35 [INFO]: Epoch 047 - training loss: -0.8944, validation loss: -0.8671
# 2025-03-09 19:51:35 [INFO]: Epoch 048 - training loss: -0.8950, validation loss: -0.8731
# 2025-03-09 19:51:36 [INFO]: Epoch 049 - training loss: -0.9010, validation loss: -0.8763
# 2025-03-09 19:51:36 [INFO]: Epoch 050 - training loss: -0.8959, validation loss: -0.8824
# 2025-03-09 19:51:36 [INFO]: Epoch 051 - training loss: -0.8998, validation loss: -0.8649
# 2025-03-09 19:51:37 [INFO]: Epoch 052 - training loss: -0.9112, validation loss: -0.8878
# 2025-03-09 19:51:37 [INFO]: Epoch 053 - training loss: -0.9019, validation loss: -0.8613
# Plotting latent series and reconstruction...
# 2025-03-09 19:51:38 [INFO]: Epoch 054 - training loss: -0.8988, validation loss: -0.8676
# 2025-03-09 19:51:39 [INFO]: Epoch 055 - training loss: -0.8910, validation loss: -0.8566
# 2025-03-09 19:51:39 [INFO]: Epoch 056 - training loss: -0.9054, validation loss: -0.8708
# 2025-03-09 19:51:39 [INFO]: Epoch 057 - training loss: -0.8972, validation loss: -0.8641
# 2025-03-09 19:51:40 [INFO]: Epoch 058 - training loss: -0.9013, validation loss: -0.8787
# 2025-03-09 19:51:40 [INFO]: Epoch 059 - training loss: -0.9058, validation loss: -0.8629
# 2025-03-09 19:51:41 [INFO]: Epoch 060 - training loss: -0.9059, validation loss: -0.8865
# 2025-03-09 19:51:41 [INFO]: Epoch 061 - training loss: -0.8863, validation loss: -0.7643
# 2025-03-09 19:51:42 [INFO]: Epoch 062 - training loss: -0.6543, validation loss: -0.8270
# 2025-03-09 19:51:42 [INFO]: Epoch 063 - training loss: -0.8195, validation loss: -0.8039
# 2025-03-09 19:51:42 [INFO]: Epoch 064 - training loss: -0.8824, validation loss: -0.8432
# 2025-03-09 19:51:43 [INFO]: Epoch 065 - training loss: -0.8979, validation loss: -0.8690
# 2025-03-09 19:51:43 [INFO]: Epoch 066 - training loss: -0.9044, validation loss: -0.8904
# 2025-03-09 19:51:44 [INFO]: Epoch 067 - training loss: -0.9004, validation loss: -0.8971
# 2025-03-09 19:51:44 [INFO]: Epoch 068 - training loss: -0.9124, validation loss: -0.8584
# 2025-03-09 19:51:44 [INFO]: Epoch 069 - training loss: -0.8705, validation loss: -0.8681
# 2025-03-09 19:51:45 [INFO]: Epoch 070 - training loss: -0.8708, validation loss: -0.8671
# 2025-03-09 19:51:46 [INFO]: Epoch 071 - training loss: -0.8721, validation loss: -0.8794
# 2025-03-09 19:51:46 [INFO]: Epoch 072 - training loss: -0.8570, validation loss: -0.8457
# 2025-03-09 19:51:46 [INFO]: Epoch 073 - training loss: -0.8690, validation loss: -0.8506
# 2025-03-09 19:51:47 [INFO]: Epoch 074 - training loss: -0.8636, validation loss: -0.7451
# 2025-03-09 19:51:47 [INFO]: Epoch 075 - training loss: -0.8511, validation loss: -0.8134
# 2025-03-09 19:51:48 [INFO]: Epoch 076 - training loss: -0.8418, validation loss: -0.7075
# 2025-03-09 19:51:48 [INFO]: Epoch 077 - training loss: -0.7587, validation loss: -0.7677
# 2025-03-09 19:51:48 [INFO]: Epoch 078 - training loss: -0.8087, validation loss: -0.7357
# 2025-03-09 19:51:48 [INFO]: Epoch 079 - training loss: -0.7763, validation loss: -0.7103
# 2025-03-09 19:51:49 [INFO]: Epoch 080 - training loss: -0.7900, validation loss: -0.7577
# 2025-03-09 19:51:49 [INFO]: Epoch 081 - training loss: -0.7950, validation loss: -0.8269
# 2025-03-09 19:51:50 [INFO]: Epoch 082 - training loss: -0.8366, validation loss: -0.8681
# 2025-03-09 19:51:50 [INFO]: Epoch 083 - training loss: -0.8602, validation loss: -0.8441
# 2025-03-09 19:51:50 [INFO]: Epoch 084 - training loss: -0.8657, validation loss: -0.8580
# 2025-03-09 19:51:51 [INFO]: Epoch 085 - training loss: -0.8833, validation loss: -0.8533
# 2025-03-09 19:51:51 [INFO]: Epoch 086 - training loss: -0.8967, validation loss: -0.8683
# 2025-03-09 19:51:52 [INFO]: Epoch 087 - training loss: -0.9101, validation loss: -0.8819
# 2025-03-09 19:51:52 [INFO]: Epoch 088 - training loss: -0.8970, validation loss: -0.8712
# 2025-03-09 19:51:53 [INFO]: Epoch 089 - training loss: -0.8821, validation loss: -0.8706
# 2025-03-09 19:51:53 [INFO]: Epoch 090 - training loss: -0.8909, validation loss: -0.8554
# 2025-03-09 19:51:54 [INFO]: Epoch 091 - training loss: -0.8655, validation loss: -0.7570
# 2025-03-09 19:51:54 [INFO]: Epoch 092 - training loss: -0.8281, validation loss: -0.8474
# 2025-03-09 19:51:55 [WARNING]: ‼️ Training got interrupted by the user. Exist now ...
# 2025-03-09 19:51:55 [INFO]: Finished training. The best model is from epoch#67.
# training kernel
# 1it [00:00,  7.22it/s]
# 182.25558471679688 8.624776840209961
# 2it [00:00,  7.31it/s]
# 168.09808349609375 6.413421154022217
# 3it [00:00,  7.37it/s]
# 176.8299560546875 10.366097450256348
# 191.63116455078125 10.795670509338379
# 4it [00:00,  7.31it/s]
# 197.70278930664062 11.20081901550293
# 6it [00:00,  8.01it/s]
# 188.4116668701172 9.198936462402344
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([22, 30, 3]) torch.Size([22, 30, 3])
# 2025-03-09 19:51:56 [WARNING]: ‼️ Training got interrupted by the user. Exist now ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 gpuae.fit(dataset_train_nan, dataset_val_nan)
#
# File ~/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/imputation/gpuae/model.py:570, in GP_UAE.fit(self, train_set, val_set, file_type, train_kernel_only)
#     568 # Step 2bis: learn the kernel
#     569 print('training kernel')
# --> 570 self._train_kernel(training_loader, val_loader)
#
# File ~/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/imputation/gpuae/model.py:530, in GP_UAE._train_kernel(self, training_loader, val_loader)
#     527 if np.isnan(self.best_kernel_loss):
#     528     raise ValueError("Something is wrong. best_loss is Nan after training.")
# --> 530 logger.info(f"Finished training. The best model is from epoch#{self.best_kernel_epoch}.")
#
# AttributeError: 'GP_UAE' object has no attribute 'best_kernel_epoch'

# %%
#gpuae.model.backbone.alpha = 1e0
gpuae_no_sampling.gp.p = 0.1

gpuae_no_sampling.fit(dataset_train_nan, dataset_val_nan, train_kernel_only = True)  # train the model on the dataset
# Out:
# training kernel
# 1it [00:00,  5.25it/s]
# 2.0724685192108154 0.4864848852157593
# 1.3781441450119019 0.4013628363609314
# 2it [00:00,  5.15it/s]
# 1.2569091320037842 0.4286653995513916
# 3it [00:00,  5.10it/s]
# 1.3334468603134155 0.32715821266174316
# 4it [00:00,  5.14it/s]
# 1.2976843118667603 0.4241858720779419
# 6it [00:01,  5.63it/s]
# 1.137542963027954 0.31895512342453003
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([22, 30, 3]) torch.Size([22, 30, 3])
# Epoch 2/300: Training Loss = 0.388949, Validation Loss = 0.302253
# 1it [00:00,  5.34it/s]
# 1.4663591384887695 0.4093620479106903
# 1.2187052965164185 0.3359096944332123
# 2it [00:00,  5.19it/s]
# 0.960283637046814 0.3307633101940155
# 3it [00:00,  5.17it/s]
# 1.6682157516479492 0.44232144951820374
# 6it [00:01,  5.64it/s]
# 1.539111614227295 0.4344683587551117
# 0.8649991750717163 0.35313186049461365
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([22, 30, 3]) torch.Size([22, 30, 3])
# Epoch
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([22, 30, 3]) torch.Size([22, 30, 3])
# Epoch 23/300: Training Loss = 0.305620, Validation Loss = 0.287570
# 1it [00:00,  5.25it/s]
# 0.9513933062553406 0.23362405598163605
# 1.1176058053970337 0.2832114100456238
# 2it [00:00,  5.17it/s]
# 0.901634931564331 0.3951979875564575
# 3it [00:00,  5.13it/s]
# 0.7169666290283203 0.3986319601535797
# 6it [00:01,  5.57it/s]
# 1.2642074823379517 0.29686039686203003
# 0.844617486000061 0.2864203453063965
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([22, 30, 3]) torch.Size([22, 30, 3])
# Epoch 24/300: Training Loss = 0.291813, Validation Loss = 0.276106
# 1it [00:00,  5.30it/s]
# 0.904497504234314 0.254454642534256
# 1.1945927143096924 0.358413428068161
# 3it [00:00,  5.10it/s]
# 0.7792644500732422 0.36658552289009094
# 0.8957509398460388 0.2842882573604584
# 6it [00:01,  5.62it/s]
# 0.8700165748596191 0.2893858551979065
# 0.9464018940925598 0.3734588623046875
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([22, 30, 3]) torch.Size([22, 30, 3])
# Epoch 25/300: Training Loss = 0.265195, Validation Loss = 0.283564
# 1it [00:00,  5.12it/s]
# 0.7205309867858887 0.31176087260246277
# 0.624444305896759 0.40086600184440613
# 2it [00:00,  5.08it/s]
# 0.9209074974060059 0.24855390191078186
# 3it [00:00,  5.18it/s]
# 0.8605622053146362 0.2813943028450012
# 4it [00:00,  5.20it/s]
# 0.985836386680603 0.3168269395828247
# 6it [00:01,  5.59it/s]
# 0.6369770765304565 0.5728752613067627
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([22, 30, 3]) torch.Size([22, 30, 3])
# Epoch 26/300: Training Loss = 0.287249, Validation Loss = 0.286537
# 1it [00:00,  5.06it/s]
# 0.7694011926651001 0.2417525202035904
# 2it [00:00,  4.39it/s]
# 0.6534218788146973 0.3414117395877838
# 3it [00:00,  4.49it/s]
# 1.0226826667785645 0.33704501390457153
# 4it [00:00,  4.54it/s]
# 1.1000597476959229 0.3152865469455719
# 6it [00:01,  5.14it/s]
# 0.944780170917511 0.3227965831756592
# 0.5596718192100525 0.37144243717193604
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([22, 30, 3]) torch.Size([22, 30, 3])
# Epoch 27/300: Training Loss = 0.262286, Validation Loss = 0.284229
# 1it [00:00,  5.18it/s]
# 1.1812149286270142 0.2786267101764679
# 0.7936840057373047 0.33004236221313477
# 3it [00:00,  5.04it/s]
# 0.5692937970161438 0.28257644176483154
# 1.1456356048583984 0.31814876198768616
# 5it [00:01,  4.81it/s]
# 0.6395981907844543 0.2512889504432678
# 1.30949866771698 0.39651453495025635
# 6it [00:01,  5.37it/s]
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([22, 30, 3]) torch.Size([22, 30, 3])
# Epoch 28/300: Training Loss = 0.272226, Validation Loss = 0.280049
# 0it [00:00, ?it/s]
# 0.8804537653923035 0.2617836594581604
# 2it [00:00,  4.94it/s]
# 0.7571849822998047 0.3089403808116913
# 3it [00:00,  4.85it/s]
# 0.7597901225090027 0.31296873092651367
# 4it [00:00,  4.75it/s]
# 0.7365134954452515 0.3340708613395691
# 5it [00:01,  4.73it/s]
# 0.6753754019737244 0.3188781142234802
# 0.941564679145813 0.24385367333889008
# 6it [00:01,  5.15it/s]
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([22, 30, 3]) torch.Size([22, 30, 3])
# Epoch 29/300: Training Loss = 0.269714, Validation Loss = 0.271497
# 0it [00:00, ?it/s]
# 0.8260486721992493 0.2650849223136902
# 2it [00:00,  4.72it/s]
# 0.873131513595581 0.2196149230003357
# 3it [00:00,  4.72it/s]
# 1.0473750829696655 0.36254578828811646
# 4it [00:00,  4.72it/s]
# 0.7814415693283081 17.220136642456055
# 6it [00:01,  5.14it/s]
# 0.5275794863700867 0.2939727008342743
# 1.073984146118164 0.4006180763244629
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([22, 30, 3]) torch.Size([22, 30, 3])
# Epoch 30/300: Training Loss = 0.261413, Validation Loss = 0.267937
# 0it [00:00, ?it/s]
# 0.7761669754981995 0.3057582676410675
# 2it [00:00,  4.56it/s]
# 0.7988580465316772 0.26329317688941956
# 3it [00:00,  4.63it/s]
# 0.8294103145599365 0.4446868598461151
# 4it [00:00,  4.66it/s]
# 0.6723230481147766 0.30931904911994934
# 6it [00:01,  5.18it/s]
# 0.8316686153411865 0.30791357159614563
# 0.8161023259162903 0.37642982602119446
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([22, 30, 3]) torch.Size([22, 30, 3])
# Epoch 31/300: Training Loss = 0.269455, Validation Loss = 0.280279
# 0it [00:00, ?it/s]
# 0.7640215754508972 0.38288313150405884
# 2it [00:00,  4.81it/s]
# 0.6818541288375854 0.3691471815109253
# 3it [00:00,  4.74it/s]
# 1.0335825681686401 0.3483002185821533
# 4it [00:00,  4.83it/s]
# 0.7572139501571655 0.2691533863544464
# 5it [00:01,  4.00it/s]
# 0.9243311285972595 0.31435737013816833
# 0.5260500311851501 0.3358818590641022
# 6it [00:01,  4.63it/s]
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([64, 30, 3]) torch.Size([64, 30, 3])
# torch.Size([22, 30, 3]) torch.Size([22, 30, 3])
# Epoch 32/300: Training Loss = 0.258675, Validation Loss = 0.266079
# 0it [00:00, ?it/s]
# 0.7816033363342285 0.3574552536010742
# 2it [00:00,  4.81it/s]
# 0.7439929842948914 0.5071139335632324
# 1.0362271070480347 0.3527851104736328
# 3it [00:00,  4.75it/s]
# 2025-03-13 19:03:08 [WARNING]: ‼️ Training got interrupted by the user. Exist now ...
# 2025-03-13 19:03:08 [INFO]: Finished training. The best model is from epoch#31.

# %%
gpuae.gp.kernel_params_history[5]['e'][900]

# %%
import matplotlib.pyplot as plt

for j in gpuae.gp.kernel_params_history.keys():
    hist_j = gpuae.gp.kernel_params_history[j]
    fig, ax = plt.subplots(2, figsize=(18,8), sharex = True)
    for elt in ['a','b','c','d']:
        ax[0].plot(hist_j[elt], label = elt)
    ax[1].semilogy(hist_j['e'])
    fig.legend();
    plt.title(f'Latent dim {j}')
    plt.show();

# %%
# Model training. This is PyPOTS showtime.
from pypots.imputation import GP_VAE
from pypots.utils.metrics import calc_mae
from pypots.optim.adam import Adam
from torch.optim.lr_scheduler import LRScheduler

gpvae = GP_VAE(n_steps = dataset_train['X'].shape[1], 
            n_features = dataset_train['X'].shape[2], 
            latent_size = 10, 
            epochs = 300, 
            batch_size = 64,
            beta = 1., 
            K = 5,  
            encoder_sizes = (128,128), 
            decoder_sizes = (256,256),
            optimizer = Adam(weight_decay=0.001), #lr = 1e-4
            patience = 30
            )

gpvae.model.backbone.alpha = 1e0
gpvae.model.backbone.beta = 1e-2
gpvae.model.backbone.gamma = 5 * 1e-5
gpvae.model.backbone.sigma1 = 1e-3
gpvae.model.backbone.sigma2 = 1e-2

gpvae.model.backbone.sampling = True
gpvae.model.backbone.use_mean = True
gpvae.model.backbone.noise_std = 1e-2
gpvae.model.backbone.detach = True
gpvae.model.backbone.compensate = False
gpvae.use_gp = False
gpvae.train_gp = False
gpvae.gp.plot_while_training = True

gpvae.model.backbone.p = 0.3
gpvae.model.backbone.device = 'cpu'

import torch
with torch.autograd.set_detect_anomaly(True):
    gpvae.fit(dataset_train_nan, dataset_val_nan)  # train the model on the dataset

# %%
kernel_params.shape
# Out:
# torch.Size([2, 10, 5])

# %%
import numpy as np
ls = 10. ** np.arange(-3,2)
sigma = 10. ** np.arange(-3,2)
noise = 10. ** np.arange(-3,2)
vi = 10. ** np.arange(-3,2)
vi2 = 10. ** np.arange(-3,2)

errs = {}

from tqdm import tqdm

for a in tqdm(ls):
    for b in sigma:
        for c in noise:
            for d in vi:
                for e in vi2:
                    
                    with torch.no_grad():
                        X_ori = torch.tensor(dataset_val['X_ori'][0])
                        X = torch.tensor(dataset_val['X'][:2])
                        missing_mask = (X!=0)
                    
                        qz_x = gpuae.model.backbone.encode(X, missing_mask)
                        kernel_params = gpuae.gp.update_kernel_params(X)
                        q_star = gpuae.gp.correct_qz_x_with_gp(qz_x, X)

                        z_ = q_star.rsample((100,))

                        X_recon = gpuae.model.backbone.decode(z_).mean[:,0]

                        l2 = (X_ori.unsqueeze(0) - X_recon).pow(2).mean()

                        errs[(a, b, c, d, e)] = l2.item()
     
                    
                        #gpuae.gp.plot_latent_GP_regression(q_star, qz_x, X)
# Out:
# 100%|█████████████████████████████████████████████| 5/5 [00:21<00:00,  4.24s/it]

# %%
# Find the best hyperparameter combination (lowest L2 loss)
best_params = min(errs, key=errs.get)
print("Best hyperparameters:", best_params, "with loss:", errs[best_params])
# Out:
# Best hyperparameters: (1.0, 0.001, 0.1, 0.01, 0.001) with loss: 19.991010665893555

# %%
plt.plot(np.array(X_ori.detach().numpy()));
plt.gca().set_prop_cycle(None)
plt.plot(np.array(X_recon[0].detach().numpy()),'o');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[205], line 1
# ----> 1 plt.plot(np.array(X_ori.detach().numpy()));
#       2 plt.gca().set_prop_cycle(None)
#       3 plt.plot(np.array(X_recon[0].detach().numpy()),'o')
#
# NameError: name 'X_ori' is not defined

# %%
gpvae.use_gp = True
gpvae.train_gp = True
gpvae.gp.plot_while_training = True

gpvae.model.backbone.p = 0.3
gpvae.model.p = 0.3

gpvae.model.backbone.device = 'cpu'

import torch
with torch.autograd.set_detect_anomaly(True):
    gpvae.fit(dataset_train_nan, dataset_val_nan)  # train the model on the dataset

# %%
gpvae.fit(dataset_train_nan, dataset_val_nan)  # train the model on the dataset

# %%
gpvae.gp.plot_while_training = True
gpvae.gp.alpha = 0.01
gpvae.fit_kernel(dataset_train, dataset_val, training_iter = 50)  # train the model on the dataset

# %%
gpvae.gp.p

# %%
from pypots.utils.metrics import calc_mae
import numpy as np

results = gpuae_no_sampling.predict(dataset_val_nan, with_gp = True)
imputation = np.array(results['imputation'])
calc_mae(imputation, dataset_val_nan['X_ori'], (dataset_val_nan['X_ori']==dataset_val_nan['X_ori']))
# Out:
# 0.30107277036682933

# %%
from pypots.utils.metrics import calc_mae
import numpy as np

results = saits.predict(dataset_val_nan)
imputation = np.array(results['imputation'])
calc_mae(imputation, dataset_val_nan['X_ori'], (dataset_val_nan['X_ori']==dataset_val_nan['X_ori']))
# Out:
# 0.18951469160260762

# %%
from pypots.utils.metrics import calc_mae
import numpy as np

results = gp_vae.predict(dataset_val_nan)
imputation = np.array(results['imputation']).squeeze(1)
calc_mae(imputation, dataset_val_nan['X_ori'], (dataset_val_nan['X_ori']==dataset_val_nan['X_ori']))

# %%
import matplotlib.pyplot as plt
plt.plot(imputation[0],':');
plt.gca().set_prop_cycle(None)
plt.plot(dataset_val_nan['X_ori'][0],'+');
plt.gca().set_prop_cycle(None)
plt.plot(dataset_val_nan['X'][0],'o');

# %%
from pypots.imputation import CSDI

# initialize the model
csdi = CSDI(
    n_steps=30,
    n_features=5,
    n_layers=6,
    n_heads=2,
    n_channels=128,
    d_time_embedding=64,
    d_feature_embedding=32,
    d_diffusion_embedding=128,
    target_strategy="random",
    n_diffusion_steps=50,
    batch_size=32,
    # here we set epochs=10 for a quick demo, you can set it to 100 or more for better performance
    epochs=10,
    # here we set patience=3 to early stop the training if the evaluting loss doesn't decrease for 3 epoches.
    # You can leave it to defualt as None to disable early stopping.
    patience=3,
    # give the optimizer. Different from torch.optim.Optimizer, you don't have to specify model's parameters when
    # initializing pypots.optim.Optimizer. You can also leave it to default. It will initilize an Adam optimizer with lr=0.001.
    optimizer=Adam(lr=1e-3),
    # this num_workers argument is for torch.utils.data.Dataloader. It's the number of subprocesses to use for data loading.
    # Leaving it to default as 0 means data loading will be in the main process, i.e. there won't be subprocesses.
    # You can increase it to >1 if you think your dataloading is a bottleneck to your model training speed
    num_workers=0,
    # just leave it to default as None, PyPOTS will automatically assign the best device for you.
    # Set it as 'cpu' if you don't have CUDA devices. You can also set it to 'cuda:0' or 'cuda:1' if you have multiple CUDA devices, even parallelly on ['cuda:0', 'cuda:1']
    device=None,
    # set the path for saving tensorboard and trained model files 
    saving_path="tutorial_results/imputation/csdi",
    # only save the best model after training finished.
    # You can also set it as "better" to save models performing better ever during training.
    model_saving_strategy="best",
)

# %%
csdi.fit(dataset_train_nan, dataset_val_nan)  # train the model on the dataset

# %%
from pypots.imputation import GPVAE

gp_vae = GPVAE(
    n_steps=30,
    n_features=5,
    latent_size=37,
    encoder_sizes = (128,128), 
    decoder_sizes = (256,256),
    optimizer = Adam(weight_decay=0.001), #lr = 1e-4
    kernel="cauchy",
    beta=0.2,
    M=1,
    K=1,
    sigma=1.005,
    length_scale=7.0,
    kernel_scales=1,
    window_size=24,
    batch_size=32,
    # here we set epochs=10 for a quick demo, you can set it to 100 or more for better performance
    epochs=300,
    # here we set patience=3 to early stop the training if the evaluting loss doesn't decrease for 3 epoches.
    # You can leave it to default as None to disable early stopping.
    patience=3,
    # give the optimizer. Different from torch.optim.Optimizer, you don't have to specify model's parameters when
    # initializing pypots.optim.Optimizer. You can also leave it to default. It will initilize an Adam optimizer with lr=0.001.
    optimizer=Adam(lr=1e-3),
    # this num_workers argument is for torch.utils.data.Dataloader. It's the number of subprocesses to use for data loading.
    # Leaving it to default as 0 means data loading will be in the main process, i.e. there won't be subprocesses.
    # You can increase it to >1 if you think your dataloading is a bottleneck to your model training speed
    num_workers=0,
    # just leave it to default as None, PyPOTS will automatically assign the best device for you.
    # Set it as 'cpu' if you don't have CUDA devices. You can also set it to 'cuda:0' or 'cuda:1' if you have multiple CUDA devices, even parallelly on ['cuda:0', 'cuda:1']
    device=None,
    # set the path for saving tensorboard and trained model files 
    saving_path="tutorial_results/imputation/gp_vae",
    # only save the best model after training finished.
    # You can also set it as "better" to save models performing better ever during training.
    model_saving_strategy="best",
)

# %%
gp_vae.fit(dataset_train_nan, dataset_val_nan)  # train the model on the dataset

# %%
from pypots.optim import Adam
from pypots.imputation import SAITS

# initialize the model
saits = SAITS(
    n_steps=30,
    n_features=3,
    n_layers=2,
    d_model=256,
    d_ffn=128,
    n_heads=4,
    d_k=64,
    d_v=64,
    dropout=0.1,
    attn_dropout=0.1,
    diagonal_attention_mask=True,  # otherwise the original self-attention mechanism will be applied
    ORT_weight=1,  # you can adjust the weight values of arguments ORT_weight
    # and MIT_weight to make the SAITS model focus more on one task. Usually you can just leave them to the default values, i.e. 1.
    MIT_weight=1,
    batch_size=32,
    # here we set epochs=10 for a quick demo, you can set it to 100 or more for better performance
    epochs=300,
    # here we set patience=3 to early stop the training if the evaluting loss doesn't decrease for 3 epoches.
    # You can leave it to defualt as None to disable early stopping.
    patience=3,
    # give the optimizer. Different from torch.optim.Optimizer, you don't have to specify model's parameters when
    # initializing pypots.optim.Optimizer. You can also leave it to default. It will initilize an Adam optimizer with lr=0.001.
    optimizer=Adam(lr=1e-3),
    # this num_workers argument is for torch.utils.data.Dataloader. It's the number of subprocesses to use for data loading.
    # Leaving it to default as 0 means data loading will be in the main process, i.e. there won't be subprocesses.
    # You can increase it to >1 if you think your dataloading is a bottleneck to your model training speed
    num_workers=0,
    # just leave it to default as None, PyPOTS will automatically assign the best device for you.
    # Set it as 'cpu' if you don't have CUDA devices. You can also set it to 'cuda:0' or 'cuda:1' if you have multiple CUDA devices, even parallelly on ['cuda:0', 'cuda:1']
    device=None,  
    # set the path for saving tensorboard and trained model files 
    saving_path="tutorial_results/imputation/saits",
    # only save the best model after training finished.
    # You can also set it as "better" to save models performing better ever during training.
    model_saving_strategy="best",
)
# Out:
# 2025-03-10 20:20:48 [INFO]: No given device, using default device: cpu
# 2025-03-10 20:20:48 [INFO]: Model files will be saved to tutorial_results/imputation/saits/20250310_T202048
# 2025-03-10 20:20:48 [INFO]: Tensorboard file will be saved to tutorial_results/imputation/saits/20250310_T202048/tensorboard
# 2025-03-10 20:20:48 [INFO]: SAITS initialized with the given hyperparameters, the number of trainable parameters: 1,321,592

# %%
saits.fit(train_set=dataset_train_nan, val_set=dataset_val_nan)  # train the model on the dataset
# Out:
# 2025-03-10 20:20:50 [INFO]: Epoch 001 - training loss: 1.5474, validation loss: 0.7811
# 2025-03-10 20:20:51 [INFO]: Epoch 002 - training loss: 1.2454, validation loss: 0.6029
# 2025-03-10 20:20:51 [INFO]: Epoch 003 - training loss: 1.1401, validation loss: 0.4897
# 2025-03-10 20:20:52 [INFO]: Epoch 004 - training loss: 1.1056, validation loss: 0.3654
# 2025-03-10 20:20:52 [INFO]: Epoch 005 - training loss: 1.0134, validation loss: 0.2866
# 2025-03-10 20:20:53 [INFO]: Epoch 006 - training loss: 0.9215, validation loss: 0.2301
# 2025-03-10 20:20:53 [INFO]: Epoch 007 - training loss: 0.8778, validation loss: 0.1952
# 2025-03-10 20:20:54 [INFO]: Epoch 008 - training loss: 0.8450, validation loss: 0.1885
# 2025-03-10 20:20:55 [INFO]: Epoch 009 - training loss: 0.8495, validation loss: 0.1941
# 2025-03-10 20:20:55 [INFO]: Epoch 010 - training loss: 0.8067, validation loss: 0.1591
# 2025-03-10 20:20:56 [INFO]: Epoch 011 - training loss: 0.7945, validation loss: 0.1531
# 2025-03-10 20:20:56 [INFO]: Epoch 012 - training loss: 0.7796, validation loss: 0.1689
# 2025-03-10 20:20:57 [INFO]: Epoch 013 - training loss: 0.7693, validation loss: 0.1541
# 2025-03-10 20:20:57 [INFO]: Epoch 014 - training loss: 0.7547, validation loss: 0.1397
# 2025-03-10 20:20:58 [INFO]: Epoch 015 - training loss: 0.7499, validation loss: 0.1435
# 2025-03-10 20:20:58 [INFO]: Epoch 016 - training loss: 0.7482, validation loss: 0.1318
# 2025-03-10 20:20:59 [INFO]: Epoch 017 - training loss: 0.7522, validation loss: 0.1260
# 2025-03-10 20:20:59 [INFO]: Epoch 018 - training loss: 0.7315, validation loss: 0.1427
# 2025-03-10 20:21:00 [INFO]: Epoch 019 - training loss: 0.7340, validation loss: 0.1391
# 2025-03-10 20:21:01 [INFO]: Epoch 020 - training loss: 0.7316, validation loss: 0.1362
# 2025-03-10 20:21:01 [INFO]: Exceeded the training patience. Terminating the training procedure...
# 2025-03-10 20:21:01 [INFO]: Finished training. The best model is from epoch#17.
# 2025-03-10 20:21:01 [INFO]: Saved the model to tutorial_results/imputation/saits/20250310_T202048/SAITS.pypots

# %%
import matplotlib.pyplot as plt

i = 0
X_val_recon = saits.impute(dataset_val_nan)
plt.plot(X_val_recon[i]);
plt.gca().set_prop_cycle(None)
plt.plot(dataset_val_nan['X_ori'][i],'+')
plt.gca().set_prop_cycle(None)
plt.plot(dataset_val_nan['X'][i],'o');

# %%
dataset_val_nan_small = {'X' : dataset_val_nan['X'][:5], 'X_ori' : dataset_val_nan['X_ori'][:5]}

# %%
import matplotlib.pyplot as plt

i = 0
X_val_recon = gpuae.impute(dataset_val_nan_small, with_gp = True)
plt.plot(X_val_recon[i]);
plt.gca().set_prop_cycle(None)
plt.plot(dataset_val_nan['X_ori'][i],'+')
plt.gca().set_prop_cycle(None)
plt.plot(dataset_val_nan['X'][i],'o');

# %%
from GP_regression_helpers import *

mse_obs, mse_hidden = plot_reconstruction_with_GP(X[::5], X_normalized[::5], gpvae, i = 0)

# %%
plot_reconstruction_with_GP(torch.tensor(X[::5]).float(), torch.tensor(X_normalized[::5]).float(), gpvae, i = 0)
plot_reconstruction_with_GP(X[::5], X_normalized[::5], saits, i = 0)
