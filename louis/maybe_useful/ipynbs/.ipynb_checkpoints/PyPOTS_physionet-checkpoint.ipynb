# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")

# %%
from pypots.data.generating import gene_physionet2012
from pypots.utils.random import set_random_seed
# Out:
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/reformer/local_attention.py:31: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled=False)
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/reformer/local_attention.py:98: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled=False)
# ████████╗██╗███╗   ███╗███████╗    ███████╗███████╗██████╗ ██╗███████╗███████╗    █████╗ ██╗
# ╚══██╔══╝██║████╗ ████║██╔════╝    ██╔════╝██╔════╝██╔══██╗██║██╔════╝██╔════╝   ██╔══██╗██║
#    ██║   ██║██╔████╔██║█████╗█████╗███████╗█████╗  ██████╔╝██║█████╗  ███████╗   ███████║██║
#    ██║   ██║██║╚██╔╝██║██╔══╝╚════╝╚════██║██╔══╝  ██╔══██╗██║██╔══╝  ╚════██║   ██╔══██║██║
#    ██║   ██║██║ ╚═╝ ██║███████╗    ███████║███████╗██║  ██║██║███████╗███████║██╗██║  ██║██║
#    ╚═╝   ╚═╝╚═╝     ╚═╝╚══════╝    ╚══════╝╚══════╝╚═╝  ╚═╝╚═╝╚══════╝╚══════╝╚═╝╚═╝  ╚═╝╚═╝
# ai4ts v0.0.3 - building AI for unified time-series analysis, https://time-series.ai

# %%
import tsdb

# %%
data_ = tsdb.load('italy_air_quality')
# Out:
# 2025-03-19 18:37:19 [INFO]: You're using dataset italy_air_quality, please cite it properly in your work. You can find its reference information at the below link:
# https://github.com/WenjieDu/TSDB/tree/main/dataset_profiles/italy_air_quality
# 2025-03-19 18:37:19 [INFO]: Dataset italy_air_quality has already been downloaded. Processing directly...
# 2025-03-19 18:37:19 [INFO]: Dataset italy_air_quality has already been cached. Loading from cache directly...
# 2025-03-19 18:37:19 [INFO]: Loaded successfully!

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

df = data_['X']

# Combine 'Date' and 'Time' into a single datetime column.
# Adjust the format as needed (here the format is: day/month/year hour.minute.second)
df['Datetime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'], format='%d/%m/%Y %H.%M.%S')

# Optional: extract additional time features if they are useful for your ML model
df['Year'] = df['Datetime'].dt.year
df['Month'] = df['Datetime'].dt.month
df['Day'] = df['Datetime'].dt.day
df['Hour'] = df['Datetime'].dt.hour

# Drop the original 'Date' and 'Time' columns if they are no longer needed
#df.drop(['Date', 'Time'], axis=1, inplace=True)

# Replace error codes (e.g., -200) with NaN for cleaning
#df.replace(-200, np.nan, inplace=True)

# Identify the columns to normalize.
# If you want to normalize all numeric columns (excluding the datetime column), you can do:
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Initialize the scaler (here we use StandardScaler for z-score normalization)
scaler = StandardScaler()

# Fit and transform the numeric columns
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

df.sort_values(by = ['Date','Hour'], inplace = True)


# Your dataframe 'df' is now ready for machine learning, with a datetime feature and normalized numeric values.
df.head()
# Out:
#             Date      Time    CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 7110  01/01/2005  00.00.00 -2.135042    -0.009066  -0.29267  0.056414
# 7111  01/01/2005  01.00.00  0.461122     0.685263  -0.29267  0.167585
# 7112  01/01/2005  02.00.00  0.472712     0.375998  -0.29267  0.136167
# 7113  01/01/2005  03.00.00  0.475288     0.345678  -0.29267  0.138584
# 7114  01/01/2005  04.00.00  0.464985     0.015190  -0.29267  0.090249
#
#       PT08.S2(NMHC)   NOx(GT)  PT08.S3(NOx)   NO2(GT)  PT08.S4(NO2)  \
# 7110      -0.498358 -1.431966      0.164639 -2.033730     -1.056283
# 7111       0.103427  0.180184     -0.453419  0.376977     -0.786582
# 7112      -0.048480  0.510384     -0.177001  0.558174     -0.833673
# 7113      -0.039716 -1.431966     -0.145943 -2.033730     -0.835813
# 7114      -0.302631  0.327803      0.108734  0.534540     -0.908590
#
#       PT08.S5(O3)         T        RH        AH            Datetime      Year  \
# 7110     0.494465 -0.036534  0.012001  0.186663 2005-01-01 00:00:00  1.778825
# 7111     1.404921 -0.103661  0.218978  0.187148 2005-01-01 01:00:00  1.778825
# 7112     0.831509 -0.089773  0.205310  0.187468 2005-01-01 02:00:00  1.778825
# 7113     0.702382 -0.112920  0.281462  0.187479 2005-01-01 03:00:00  1.778825
# 7114     0.341263 -0.126809  0.308798  0.187368 2005-01-01 04:00:00  1.778825
#
#          Month       Day      Hour
# 7110 -1.544617 -1.688985 -1.660966
# 7111 -1.544617 -1.688985 -1.516516
# 7112 -1.544617 -1.688985 -1.372066
# 7113 -1.544617 -1.688985 -1.227616
# 7114 -1.544617 -1.688985 -1.083166

# %%
import pandas as pd
import numpy as np

# Assume df is your preprocessed DataFrame from before,
# and that it contains a 'Datetime' column.
# Define the relevant columns (d features) you wish to use:
relevant_columns = ['CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
                    'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)',
                    'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']

# Extract the day and hour from the Datetime column
df['Day'] = df['Datetime'].dt.date
df['Hour'] = df['Datetime'].dt.hour

# Group by day and reindex each day to ensure it has exactly 24 hours.
daily_arrays = []
for day, group in df.groupby('Day'):
    # Set the hour as index and sort by hour
    group = group.set_index('Hour').sort_index()
    # Reindex to ensure every hour from 0 to 23 is present; missing hours will be filled with NaN.
    group = group.reindex(range(24))
    # Extract the relevant columns and convert to a numpy array of shape (24, d)
    daily_array = group[relevant_columns].values
    daily_arrays.append(daily_array)

# Convert list of daily arrays into a single numpy array with shape (N, 24, d)
data_array = np.stack(daily_arrays, axis=0)
print("Shape of the reshaped data:", data_array.shape)
# Out:
# Shape of the reshaped data: (391, 24, 13)

# %%
import numpy as np
from pygrinder import mcar
import torch

X = data_array

## Normalize_data
mean, std = np.nanmean(X,axis=0)[None,:], np.nanstd(X, axis=0)[None,:]
std[std==0] = 1
X_normalized = (X - mean) / std
X_normalized = torch.tensor(X_normalized).clip(min=-2,max=2)

X = mcar(torch.clone(X_normalized), p = 0.5)

# %%
dataset = {'X' : X}
len_dataset = len(dataset['X'])
cut = int(len_dataset*0.7)
dataset_train, dataset_val = {'X':dataset['X'][:cut]}, {'X':dataset['X'][cut:], 'X_ori':X_normalized[cut:]}

# %%
# Model training. This is PyPOTS showtime.
from pypots.imputation import GP_UAE
from pypots.utils.metrics import calc_mae
from pypots.optim.adam import Adam
from torch.optim.lr_scheduler import LRScheduler

gpuae = GP_UAE(n_steps = dataset_train['X'].shape[1], 
            n_features = dataset_train['X'].shape[2], 
            latent_size = 66, 
            epochs = 500, 
            batch_size = 64,
            alpha = .1,
            beta = .1, 
            sigma = 1e-2,
            K = 1,  
            encoder_sizes = (32, 64,), 
            decoder_sizes = (64,32,),
            optimizer = Adam(weight_decay=0.001), #lr = 1e-4
            patience = 30,
            p = 0.3
            )

gpuae.use_gp = False
gpuae.train_gp = False
gpuae.gp.plot_while_training = True
gpuae.model.backbone.device = 'cpu'

from sklearn.impute import KNNImputer
X = np.array(dataset_train['X'].detach().numpy())
imputer = KNNImputer(n_neighbors=2)
imputer.fit(X.reshape(-1,X.shape[-1]))

gpuae.model.backbone.encoder.pre_imputer = imputer

import torch
with torch.autograd.set_detect_anomaly(True):
    gpuae.fit(dataset_train, dataset_val)  # train the model on the dataset
# Out:
# 2025-03-19 18:42:04 [INFO]: No given device, using default device: cpu
# 2025-03-19 18:42:04 [WARNING]: ‼️ saving_path not given. Model files and tensorboard file will not be saved.
# 2025-03-19 18:42:04 [INFO]: GP_UAE initialized with the given hyperparameters, the number of trainable parameters: 18,353
# Model dimensions is:
# GpvaeEncoder(
#   (net): Sequential(
#     (0): Linear(in_features=26, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=64, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#   )
#   (mu_layer): Linear(in_features=64, out_features=66, bias=True)
#   (logvar_layer): Linear(in_features=64, out_features=66, bias=True)
# )
# GpvaeDecoder(
#   (net): Sequential(
#     (0): Linear(in_features=66, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=13, bias=True)
#   )
# )
# 2025-03-19 18:42:04 [INFO]: Epoch 001 - training loss: 27.8690, validation loss: 27.8504
# 2025-03-19 18:42:04 [INFO]: Epoch 002 - training loss: 26.7629, validation loss: 29.2878
# 2025-03-19 18:42:05 [INFO]: Epoch 003 - training loss: 25.9479, validation loss: 30.5598
# 2025-03-19 18:42:05 [INFO]: Epoch 004 - training loss: 26.0487, validation loss: 31.4836
# 2025-03-19 18:42:05 [INFO]: Epoch 005 - training loss: 23.4579, validation loss: 32.5746
# 2025-03-19 18:42:06 [INFO]: Epoch 006 - training loss: 23.9244, validation loss: 33.0546
# 2025-03-19 18:42:06 [INFO]: Epoch 007 - training loss: 22.2391, validation loss: 32.5472
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:07 [INFO]: Epoch 008 - training loss: 21.9507, validation loss: 31.3735
# 2025-03-19 18:42:08 [INFO]: Epoch 009 - training loss: 19.7585, validation loss: 29.6445
# 2025-03-19 18:42:08 [INFO]: Epoch 010 - training loss: 17.6261, validation loss: 27.3253
# 2025-03-19 18:42:08 [INFO]: Epoch 011 - training loss: 15.6527, validation loss: 24.6330
# 2025-03-19 18:42:09 [INFO]: Epoch 012 - training loss: 15.3239, validation loss: 22.7946
# 2025-03-19 18:42:09 [INFO]: Epoch 013 - training loss: 12.8271, validation loss: 21.3161
# 2025-03-19 18:42:09 [INFO]: Epoch 014 - training loss: 12.8569, validation loss: 20.3590
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:10 [INFO]: Epoch 015 - training loss: 10.7258, validation loss: 18.8952
# 2025-03-19 18:42:11 [INFO]: Epoch 016 - training loss: 10.4876, validation loss: 17.6285
# 2025-03-19 18:42:11 [INFO]: Epoch 017 - training loss: 8.6882, validation loss: 16.3217
# 2025-03-19 18:42:11 [INFO]: Epoch 018 - training loss: 8.3277, validation loss: 15.2326
# 2025-03-19 18:42:12 [INFO]: Epoch 019 - training loss: 8.2364, validation loss: 14.0844
# 2025-03-19 18:42:12 [INFO]: Epoch 020 - training loss: 6.9053, validation loss: 13.0040
# 2025-03-19 18:42:12 [INFO]: Epoch 021 - training loss: 6.5103, validation loss: 11.6691
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:14 [INFO]: Epoch 022 - training loss: 5.8805, validation loss: 10.7592
# 2025-03-19 18:42:14 [INFO]: Epoch 023 - training loss: 5.5230, validation loss: 9.7470
# 2025-03-19 18:42:14 [INFO]: Epoch 024 - training loss: 5.2325, validation loss: 9.3323
# 2025-03-19 18:42:14 [INFO]: Epoch 025 - training loss: 5.0437, validation loss: 8.6252
# 2025-03-19 18:42:15 [INFO]: Epoch 026 - training loss: 4.7666, validation loss: 8.2473
# 2025-03-19 18:42:15 [INFO]: Epoch 027 - training loss: 4.5914, validation loss: 8.0886
# 2025-03-19 18:42:15 [INFO]: Epoch 028 - training loss: 4.6902, validation loss: 7.5547
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:17 [INFO]: Epoch 029 - training loss: 4.1567, validation loss: 7.2067
# 2025-03-19 18:42:17 [INFO]: Epoch 030 - training loss: 4.1100, validation loss: 7.3743
# 2025-03-19 18:42:17 [INFO]: Epoch 031 - training loss: 3.9398, validation loss: 7.4033
# 2025-03-19 18:42:17 [INFO]: Epoch 032 - training loss: 4.0099, validation loss: 7.0292
# 2025-03-19 18:42:18 [INFO]: Epoch 033 - training loss: 3.8707, validation loss: 6.9613
# 2025-03-19 18:42:18 [INFO]: Epoch 034 - training loss: 3.7146, validation loss: 7.1700
# 2025-03-19 18:42:18 [INFO]: Epoch 035 - training loss: 3.5603, validation loss: 6.8405
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:19 [INFO]: Epoch 036 - training loss: 3.6731, validation loss: 6.7867
# 2025-03-19 18:42:20 [INFO]: Epoch 037 - training loss: 3.6190, validation loss: 6.6370
# 2025-03-19 18:42:20 [INFO]: Epoch 038 - training loss: 3.5486, validation loss: 6.5571
# 2025-03-19 18:42:20 [INFO]: Epoch 039 - training loss: 3.3655, validation loss: 6.7074
# 2025-03-19 18:42:21 [INFO]: Epoch 040 - training loss: 3.2788, validation loss: 6.3423
# 2025-03-19 18:42:21 [INFO]: Epoch 041 - training loss: 3.3845, validation loss: 6.5084
# 2025-03-19 18:42:21 [INFO]: Epoch 042 - training loss: 3.2784, validation loss: 6.4442
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:23 [INFO]: Epoch 043 - training loss: 3.2566, validation loss: 6.2944
# 2025-03-19 18:42:23 [INFO]: Epoch 044 - training loss: 2.9942, validation loss: 6.2644
# 2025-03-19 18:42:23 [INFO]: Epoch 045 - training loss: 3.0409, validation loss: 6.1041
# 2025-03-19 18:42:23 [INFO]: Epoch 046 - training loss: 2.9872, validation loss: 6.2724
# 2025-03-19 18:42:24 [INFO]: Epoch 047 - training loss: 3.1247, validation loss: 6.0600
# 2025-03-19 18:42:24 [INFO]: Epoch 048 - training loss: 2.8583, validation loss: 6.0785
# 2025-03-19 18:42:24 [INFO]: Epoch 049 - training loss: 2.8472, validation loss: 6.0966
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:26 [INFO]: Epoch 050 - training loss: 2.7991, validation loss: 6.0993
# 2025-03-19 18:42:26 [INFO]: Epoch 051 - training loss: 2.8225, validation loss: 5.9532
# 2025-03-19 18:42:26 [INFO]: Epoch 052 - training loss: 2.7744, validation loss: 6.0520
# 2025-03-19 18:42:26 [INFO]: Epoch 053 - training loss: 2.8267, validation loss: 5.9024
# 2025-03-19 18:42:27 [INFO]: Epoch 054 - training loss: 2.6725, validation loss: 5.8686
# 2025-03-19 18:42:27 [INFO]: Epoch 055 - training loss: 2.7160, validation loss: 5.9328
# 2025-03-19 18:42:27 [INFO]: Epoch 056 - training loss: 2.6809, validation loss: 5.8600
# 2025-03-19 18:42:28 [INFO]: Epoch 057 - training loss: 2.6647, validation loss: 5.6592
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:29 [INFO]: Epoch 058 - training loss: 2.5988, validation loss: 5.7266
# 2025-03-19 18:42:29 [INFO]: Epoch 059 - training loss: 2.5746, validation loss: 5.6153
# 2025-03-19 18:42:30 [INFO]: Epoch 060 - training loss: 2.6138, validation loss: 5.6506
# 2025-03-19 18:42:30 [INFO]: Epoch 061 - training loss: 2.5388, validation loss: 5.6817
# 2025-03-19 18:42:30 [INFO]: Epoch 062 - training loss: 2.5373, validation loss: 5.6064
# 2025-03-19 18:42:30 [INFO]: Epoch 063 - training loss: 2.6267, validation loss: 5.4799
# 2025-03-19 18:42:31 [INFO]: Epoch 064 - training loss: 2.5100, validation loss: 5.5562
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:32 [INFO]: Epoch 065 - training loss: 2.5038, validation loss: 5.4310
# 2025-03-19 18:42:32 [INFO]: Epoch 066 - training loss: 2.4811, validation loss: 5.3137
# 2025-03-19 18:42:32 [INFO]: Epoch 067 - training loss: 2.5931, validation loss: 5.3831
# 2025-03-19 18:42:33 [INFO]: Epoch 068 - training loss: 2.5199, validation loss: 5.4890
# 2025-03-19 18:42:33 [INFO]: Epoch 069 - training loss: 2.3610, validation loss: 5.3273
# 2025-03-19 18:42:33 [INFO]: Epoch 070 - training loss: 2.3962, validation loss: 5.2935
# 2025-03-19 18:42:34 [INFO]: Epoch 071 - training loss: 2.3967, validation loss: 5.1938
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:35 [INFO]: Epoch 072 - training loss: 2.3811, validation loss: 5.2945
# 2025-03-19 18:42:36 [INFO]: Epoch 073 - training loss: 2.3185, validation loss: 5.3072
# 2025-03-19 18:42:36 [INFO]: Epoch 074 - training loss: 2.2923, validation loss: 5.3632
# 2025-03-19 18:42:36 [INFO]: Epoch 075 - training loss: 2.4102, validation loss: 4.9607
# 2025-03-19 18:42:36 [INFO]: Epoch 076 - training loss: 2.3610, validation loss: 5.2111
# 2025-03-19 18:42:37 [INFO]: Epoch 077 - training loss: 2.2798, validation loss: 4.9901
# 2025-03-19 18:42:37 [INFO]: Epoch 078 - training loss: 2.3267, validation loss: 5.0882
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:38 [INFO]: Epoch 079 - training loss: 2.3391, validation loss: 4.9298
# 2025-03-19 18:42:39 [INFO]: Epoch 080 - training loss: 2.2974, validation loss: 5.1330
# 2025-03-19 18:42:39 [INFO]: Epoch 081 - training loss: 2.2715, validation loss: 5.0603
# 2025-03-19 18:42:39 [INFO]: Epoch 082 - training loss: 2.2535, validation loss: 4.8699
# 2025-03-19 18:42:40 [INFO]: Epoch 083 - training loss: 2.1965, validation loss: 4.8742
# 2025-03-19 18:42:40 [INFO]: Epoch 084 - training loss: 2.1618, validation loss: 4.7833
# 2025-03-19 18:42:40 [INFO]: Epoch 085 - training loss: 2.1374, validation loss: 4.9394
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:41 [INFO]: Epoch 086 - training loss: 2.1904, validation loss: 4.4817
# 2025-03-19 18:42:42 [INFO]: Epoch 087 - training loss: 2.2031, validation loss: 4.6712
# 2025-03-19 18:42:42 [INFO]: Epoch 088 - training loss: 2.0958, validation loss: 4.6816
# 2025-03-19 18:42:42 [INFO]: Epoch 089 - training loss: 2.0683, validation loss: 4.8693
# 2025-03-19 18:42:42 [INFO]: Epoch 090 - training loss: 2.1641, validation loss: 4.6434
# 2025-03-19 18:42:43 [INFO]: Epoch 091 - training loss: 2.0599, validation loss: 4.4742
# 2025-03-19 18:42:43 [INFO]: Epoch 092 - training loss: 2.0860, validation loss: 4.6088
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:44 [INFO]: Epoch 093 - training loss: 2.0488, validation loss: 4.6243
# 2025-03-19 18:42:45 [INFO]: Epoch 094 - training loss: 2.0647, validation loss: 4.3753
# 2025-03-19 18:42:45 [INFO]: Epoch 095 - training loss: 2.0376, validation loss: 4.3833
# 2025-03-19 18:42:45 [INFO]: Epoch 096 - training loss: 1.9603, validation loss: 4.3872
# 2025-03-19 18:42:45 [INFO]: Epoch 097 - training loss: 1.9880, validation loss: 4.4053
# 2025-03-19 18:42:46 [INFO]: Epoch 098 - training loss: 1.9876, validation loss: 4.4415
# 2025-03-19 18:42:46 [INFO]: Epoch 099 - training loss: 1.9357, validation loss: 4.1362
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:47 [INFO]: Epoch 100 - training loss: 1.9781, validation loss: 4.2845
# 2025-03-19 18:42:47 [INFO]: Epoch 101 - training loss: 2.0576, validation loss: 4.1278
# 2025-03-19 18:42:48 [INFO]: Epoch 102 - training loss: 1.9597, validation loss: 4.0843
# 2025-03-19 18:42:48 [INFO]: Epoch 103 - training loss: 1.9748, validation loss: 4.2551
# 2025-03-19 18:42:48 [INFO]: Epoch 104 - training loss: 2.0523, validation loss: 4.0283
# 2025-03-19 18:42:49 [INFO]: Epoch 105 - training loss: 2.0305, validation loss: 4.0652
# 2025-03-19 18:42:49 [INFO]: Epoch 106 - training loss: 1.8699, validation loss: 4.2447
# 2025-03-19 18:42:49 [INFO]: Epoch 107 - training loss: 1.8794, validation loss: 4.1826
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:51 [INFO]: Epoch 108 - training loss: 1.8504, validation loss: 3.9965
# 2025-03-19 18:42:51 [INFO]: Epoch 109 - training loss: 1.8394, validation loss: 4.1414
# 2025-03-19 18:42:51 [INFO]: Epoch 110 - training loss: 1.8193, validation loss: 4.0025
# 2025-03-19 18:42:51 [INFO]: Epoch 111 - training loss: 1.8263, validation loss: 3.8781
# 2025-03-19 18:42:52 [INFO]: Epoch 112 - training loss: 1.8368, validation loss: 4.0410
# 2025-03-19 18:42:52 [INFO]: Epoch 113 - training loss: 1.7579, validation loss: 4.0921
# 2025-03-19 18:42:52 [INFO]: Epoch 114 - training loss: 1.8220, validation loss: 3.8517
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:53 [INFO]: Epoch 115 - training loss: 1.8254, validation loss: 4.0204
# 2025-03-19 18:42:54 [INFO]: Epoch 116 - training loss: 1.8272, validation loss: 3.8891
# 2025-03-19 18:42:54 [INFO]: Epoch 117 - training loss: 1.7441, validation loss: 3.9655
# 2025-03-19 18:42:54 [INFO]: Epoch 118 - training loss: 1.8537, validation loss: 3.9247
# 2025-03-19 18:42:55 [INFO]: Epoch 119 - training loss: 1.7503, validation loss: 3.9279
# 2025-03-19 18:42:55 [INFO]: Epoch 120 - training loss: 1.7740, validation loss: 3.7305
# 2025-03-19 18:42:55 [INFO]: Epoch 121 - training loss: 1.7640, validation loss: 3.9083
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:56 [INFO]: Epoch 122 - training loss: 1.7112, validation loss: 3.6884
# 2025-03-19 18:42:57 [INFO]: Epoch 123 - training loss: 1.7689, validation loss: 3.7112
# 2025-03-19 18:42:57 [INFO]: Epoch 124 - training loss: 1.6941, validation loss: 3.5719
# 2025-03-19 18:42:57 [INFO]: Epoch 125 - training loss: 1.6878, validation loss: 3.6884
# 2025-03-19 18:42:58 [INFO]: Epoch 126 - training loss: 1.6848, validation loss: 3.6847
# 2025-03-19 18:42:58 [INFO]: Epoch 127 - training loss: 1.7157, validation loss: 3.5134
# 2025-03-19 18:42:58 [INFO]: Epoch 128 - training loss: 1.6569, validation loss: 3.5651
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:42:59 [INFO]: Epoch 129 - training loss: 1.6735, validation loss: 3.6417
# 2025-03-19 18:43:00 [INFO]: Epoch 130 - training loss: 1.6962, validation loss: 3.5912
# 2025-03-19 18:43:00 [INFO]: Epoch 131 - training loss: 1.6496, validation loss: 3.5943
# 2025-03-19 18:43:00 [INFO]: Epoch 132 - training loss: 1.6675, validation loss: 3.6334
# 2025-03-19 18:43:00 [INFO]: Epoch 133 - training loss: 1.6789, validation loss: 3.3789
# 2025-03-19 18:43:01 [INFO]: Epoch 134 - training loss: 1.6346, validation loss: 3.5662
# 2025-03-19 18:43:01 [INFO]: Epoch 135 - training loss: 1.6356, validation loss: 3.5130
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:02 [INFO]: Epoch 136 - training loss: 1.6002, validation loss: 3.4269
# 2025-03-19 18:43:03 [INFO]: Epoch 137 - training loss: 1.6826, validation loss: 3.4382
# 2025-03-19 18:43:03 [INFO]: Epoch 138 - training loss: 1.6521, validation loss: 3.3504
# 2025-03-19 18:43:03 [INFO]: Epoch 139 - training loss: 1.6319, validation loss: 3.4496
# 2025-03-19 18:43:03 [INFO]: Epoch 140 - training loss: 1.6079, validation loss: 3.2483
# 2025-03-19 18:43:04 [INFO]: Epoch 141 - training loss: 1.5614, validation loss: 3.3096
# 2025-03-19 18:43:04 [INFO]: Epoch 142 - training loss: 1.5623, validation loss: 3.3963
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:05 [INFO]: Epoch 143 - training loss: 1.5693, validation loss: 3.3059
# 2025-03-19 18:43:06 [INFO]: Epoch 144 - training loss: 1.5571, validation loss: 3.4228
# 2025-03-19 18:43:06 [INFO]: Epoch 145 - training loss: 1.5375, validation loss: 3.2733
# 2025-03-19 18:43:06 [INFO]: Epoch 146 - training loss: 1.5373, validation loss: 3.1056
# 2025-03-19 18:43:06 [INFO]: Epoch 147 - training loss: 1.5079, validation loss: 3.2661
# 2025-03-19 18:43:07 [INFO]: Epoch 148 - training loss: 1.5265, validation loss: 3.2571
# 2025-03-19 18:43:07 [INFO]: Epoch 149 - training loss: 1.5289, validation loss: 3.1198
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:08 [INFO]: Epoch 150 - training loss: 1.5041, validation loss: 3.2924
# 2025-03-19 18:43:09 [INFO]: Epoch 151 - training loss: 1.5093, validation loss: 3.3119
# 2025-03-19 18:43:09 [INFO]: Epoch 152 - training loss: 1.4811, validation loss: 3.2131
# 2025-03-19 18:43:09 [INFO]: Epoch 153 - training loss: 1.4992, validation loss: 3.1686
# 2025-03-19 18:43:10 [INFO]: Epoch 154 - training loss: 1.4903, validation loss: 3.0258
# 2025-03-19 18:43:10 [INFO]: Epoch 155 - training loss: 1.4923, validation loss: 3.1363
# 2025-03-19 18:43:10 [INFO]: Epoch 156 - training loss: 1.4867, validation loss: 3.1188
# 2025-03-19 18:43:10 [INFO]: Epoch 157 - training loss: 1.4683, validation loss: 3.0687
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:12 [INFO]: Epoch 158 - training loss: 1.4932, validation loss: 3.0262
# 2025-03-19 18:43:12 [INFO]: Epoch 159 - training loss: 1.4659, validation loss: 3.1383
# 2025-03-19 18:43:12 [INFO]: Epoch 160 - training loss: 1.4547, validation loss: 3.0795
# 2025-03-19 18:43:13 [INFO]: Epoch 161 - training loss: 1.4484, validation loss: 2.9658
# 2025-03-19 18:43:13 [INFO]: Epoch 162 - training loss: 1.4164, validation loss: 3.0398
# 2025-03-19 18:43:13 [INFO]: Epoch 163 - training loss: 1.4052, validation loss: 3.0172
# 2025-03-19 18:43:13 [INFO]: Epoch 164 - training loss: 1.4025, validation loss: 3.0599
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:15 [INFO]: Epoch 165 - training loss: 1.4741, validation loss: 2.9378
# 2025-03-19 18:43:15 [INFO]: Epoch 166 - training loss: 1.3860, validation loss: 2.8734
# 2025-03-19 18:43:15 [INFO]: Epoch 167 - training loss: 1.3886, validation loss: 2.9428
# 2025-03-19 18:43:15 [INFO]: Epoch 168 - training loss: 1.3582, validation loss: 2.8557
# 2025-03-19 18:43:16 [INFO]: Epoch 169 - training loss: 1.3691, validation loss: 2.7863
# 2025-03-19 18:43:16 [INFO]: Epoch 170 - training loss: 1.3796, validation loss: 2.8601
# 2025-03-19 18:43:16 [INFO]: Epoch 171 - training loss: 1.3692, validation loss: 2.7216
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:18 [INFO]: Epoch 172 - training loss: 1.3877, validation loss: 2.7695
# 2025-03-19 18:43:18 [INFO]: Epoch 173 - training loss: 1.3823, validation loss: 2.7883
# 2025-03-19 18:43:18 [INFO]: Epoch 174 - training loss: 1.3744, validation loss: 2.7257
# 2025-03-19 18:43:18 [INFO]: Epoch 175 - training loss: 1.3795, validation loss: 2.6428
# 2025-03-19 18:43:19 [INFO]: Epoch 176 - training loss: 1.3405, validation loss: 2.6292
# 2025-03-19 18:43:19 [INFO]: Epoch 177 - training loss: 1.3165, validation loss: 2.7116
# 2025-03-19 18:43:19 [INFO]: Epoch 178 - training loss: 1.3201, validation loss: 2.8161
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:20 [INFO]: Epoch 179 - training loss: 1.2914, validation loss: 2.7384
# 2025-03-19 18:43:21 [INFO]: Epoch 180 - training loss: 1.3503, validation loss: 2.8231
# 2025-03-19 18:43:21 [INFO]: Epoch 181 - training loss: 1.3595, validation loss: 2.6154
# 2025-03-19 18:43:21 [INFO]: Epoch 182 - training loss: 1.3339, validation loss: 2.6524
# 2025-03-19 18:43:22 [INFO]: Epoch 183 - training loss: 1.3100, validation loss: 2.5724
# 2025-03-19 18:43:22 [INFO]: Epoch 184 - training loss: 1.2953, validation loss: 2.7197
# 2025-03-19 18:43:22 [INFO]: Epoch 185 - training loss: 1.3238, validation loss: 2.6580
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:23 [INFO]: Epoch 186 - training loss: 1.2904, validation loss: 2.6735
# 2025-03-19 18:43:24 [INFO]: Epoch 187 - training loss: 1.2801, validation loss: 2.6801
# 2025-03-19 18:43:24 [INFO]: Epoch 188 - training loss: 1.2654, validation loss: 2.6156
# 2025-03-19 18:43:24 [INFO]: Epoch 189 - training loss: 1.2623, validation loss: 2.6684
# 2025-03-19 18:43:24 [INFO]: Epoch 190 - training loss: 1.2638, validation loss: 2.4305
# 2025-03-19 18:43:25 [INFO]: Epoch 191 - training loss: 1.2732, validation loss: 2.6314
# 2025-03-19 18:43:25 [INFO]: Epoch 192 - training loss: 1.2649, validation loss: 2.4982
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:26 [INFO]: Epoch 193 - training loss: 1.3163, validation loss: 2.4789
# 2025-03-19 18:43:27 [INFO]: Epoch 194 - training loss: 1.2401, validation loss: 2.5255
# 2025-03-19 18:43:27 [INFO]: Epoch 195 - training loss: 1.2466, validation loss: 2.5476
# 2025-03-19 18:43:27 [INFO]: Epoch 196 - training loss: 1.2457, validation loss: 2.5059
# 2025-03-19 18:43:27 [INFO]: Epoch 197 - training loss: 1.2253, validation loss: 2.4989
# 2025-03-19 18:43:28 [INFO]: Epoch 198 - training loss: 1.2338, validation loss: 2.6190
# 2025-03-19 18:43:28 [INFO]: Epoch 199 - training loss: 1.2520, validation loss: 2.4096
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:30 [INFO]: Epoch 200 - training loss: 1.2304, validation loss: 2.4303
# 2025-03-19 18:43:30 [INFO]: Epoch 201 - training loss: 1.2190, validation loss: 2.5187
# 2025-03-19 18:43:30 [INFO]: Epoch 202 - training loss: 1.2224, validation loss: 2.5128
# 2025-03-19 18:43:30 [INFO]: Epoch 203 - training loss: 1.2374, validation loss: 2.4046
# 2025-03-19 18:43:31 [INFO]: Epoch 204 - training loss: 1.2088, validation loss: 2.3546
# 2025-03-19 18:43:31 [INFO]: Epoch 205 - training loss: 1.1999, validation loss: 2.4032
# 2025-03-19 18:43:31 [INFO]: Epoch 206 - training loss: 1.2027, validation loss: 2.3370
# 2025-03-19 18:43:32 [INFO]: Epoch 207 - training loss: 1.1884, validation loss: 2.3797
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:33 [INFO]: Epoch 208 - training loss: 1.2122, validation loss: 2.3568
# 2025-03-19 18:43:33 [INFO]: Epoch 209 - training loss: 1.1987, validation loss: 2.3171
# 2025-03-19 18:43:33 [INFO]: Epoch 210 - training loss: 1.2043, validation loss: 2.3942
# 2025-03-19 18:43:34 [INFO]: Epoch 211 - training loss: 1.2090, validation loss: 2.3238
# 2025-03-19 18:43:34 [INFO]: Epoch 212 - training loss: 1.2118, validation loss: 2.3286
# 2025-03-19 18:43:34 [INFO]: Epoch 213 - training loss: 1.1812, validation loss: 2.2401
# 2025-03-19 18:43:35 [INFO]: Epoch 214 - training loss: 1.1657, validation loss: 2.3477
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:36 [INFO]: Epoch 215 - training loss: 1.1840, validation loss: 2.3708
# 2025-03-19 18:43:36 [INFO]: Epoch 216 - training loss: 1.1624, validation loss: 2.3342
# 2025-03-19 18:43:36 [INFO]: Epoch 217 - training loss: 1.1716, validation loss: 2.3337
# 2025-03-19 18:43:37 [INFO]: Epoch 218 - training loss: 1.1578, validation loss: 2.2780
# 2025-03-19 18:43:37 [INFO]: Epoch 219 - training loss: 1.1703, validation loss: 2.3282
# 2025-03-19 18:43:37 [INFO]: Epoch 220 - training loss: 1.1644, validation loss: 2.3355
# 2025-03-19 18:43:37 [INFO]: Epoch 221 - training loss: 1.1514, validation loss: 2.3069
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:39 [INFO]: Epoch 222 - training loss: 1.1482, validation loss: 2.2917
# 2025-03-19 18:43:39 [INFO]: Epoch 223 - training loss: 1.2097, validation loss: 2.1328
# 2025-03-19 18:43:39 [INFO]: Epoch 224 - training loss: 1.1485, validation loss: 2.1589
# 2025-03-19 18:43:40 [INFO]: Epoch 225 - training loss: 1.1523, validation loss: 2.1355
# 2025-03-19 18:43:40 [INFO]: Epoch 226 - training loss: 1.1266, validation loss: 2.1819
# 2025-03-19 18:43:40 [INFO]: Epoch 227 - training loss: 1.1502, validation loss: 2.1959
# 2025-03-19 18:43:40 [INFO]: Epoch 228 - training loss: 1.1298, validation loss: 2.1235
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:42 [INFO]: Epoch 229 - training loss: 1.1535, validation loss: 2.1668
# 2025-03-19 18:43:42 [INFO]: Epoch 230 - training loss: 1.1305, validation loss: 2.0958
# 2025-03-19 18:43:42 [INFO]: Epoch 231 - training loss: 1.1340, validation loss: 2.1068
# 2025-03-19 18:43:43 [INFO]: Epoch 232 - training loss: 1.1369, validation loss: 2.1049
# 2025-03-19 18:43:43 [INFO]: Epoch 233 - training loss: 1.1267, validation loss: 2.1370
# 2025-03-19 18:43:43 [INFO]: Epoch 234 - training loss: 1.1029, validation loss: 2.1307
# 2025-03-19 18:43:43 [INFO]: Epoch 235 - training loss: 1.1074, validation loss: 2.1101
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:45 [INFO]: Epoch 236 - training loss: 1.1030, validation loss: 2.0734
# 2025-03-19 18:43:45 [INFO]: Epoch 237 - training loss: 1.1087, validation loss: 2.0610
# 2025-03-19 18:43:45 [INFO]: Epoch 238 - training loss: 1.1212, validation loss: 2.1093
# 2025-03-19 18:43:45 [INFO]: Epoch 239 - training loss: 1.1182, validation loss: 2.1668
# 2025-03-19 18:43:46 [INFO]: Epoch 240 - training loss: 1.0842, validation loss: 2.0856
# 2025-03-19 18:43:46 [INFO]: Epoch 241 - training loss: 1.0776, validation loss: 1.9555
# 2025-03-19 18:43:46 [INFO]: Epoch 242 - training loss: 1.0777, validation loss: 2.0349
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:48 [INFO]: Epoch 243 - training loss: 1.0854, validation loss: 1.9956
# 2025-03-19 18:43:48 [INFO]: Epoch 244 - training loss: 1.1029, validation loss: 2.0763
# 2025-03-19 18:43:48 [INFO]: Epoch 245 - training loss: 1.0671, validation loss: 1.9930
# 2025-03-19 18:43:48 [INFO]: Epoch 246 - training loss: 1.0773, validation loss: 2.0710
# 2025-03-19 18:43:49 [INFO]: Epoch 247 - training loss: 1.0587, validation loss: 2.0083
# 2025-03-19 18:43:49 [INFO]: Epoch 248 - training loss: 1.0652, validation loss: 1.9938
# 2025-03-19 18:43:49 [INFO]: Epoch 249 - training loss: 1.0527, validation loss: 1.9519
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:50 [INFO]: Epoch 250 - training loss: 1.0771, validation loss: 1.9954
# 2025-03-19 18:43:51 [INFO]: Epoch 251 - training loss: 1.0433, validation loss: 1.9693
# 2025-03-19 18:43:51 [INFO]: Epoch 252 - training loss: 1.0680, validation loss: 1.9610
# 2025-03-19 18:43:51 [INFO]: Epoch 253 - training loss: 1.0649, validation loss: 1.9412
# 2025-03-19 18:43:52 [INFO]: Epoch 254 - training loss: 1.0536, validation loss: 2.0296
# 2025-03-19 18:43:52 [INFO]: Epoch 255 - training loss: 1.0581, validation loss: 2.0505
# 2025-03-19 18:43:52 [INFO]: Epoch 256 - training loss: 1.0480, validation loss: 1.9481
# 2025-03-19 18:43:52 [INFO]: Epoch 257 - training loss: 1.0444, validation loss: 1.9400
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:54 [INFO]: Epoch 258 - training loss: 1.0457, validation loss: 1.8372
# 2025-03-19 18:43:54 [INFO]: Epoch 259 - training loss: 1.0370, validation loss: 1.8784
# 2025-03-19 18:43:54 [INFO]: Epoch 260 - training loss: 1.0282, validation loss: 1.9517
# 2025-03-19 18:43:54 [INFO]: Epoch 261 - training loss: 1.0204, validation loss: 1.9551
# 2025-03-19 18:43:55 [INFO]: Epoch 262 - training loss: 1.0404, validation loss: 1.9581
# 2025-03-19 18:43:55 [INFO]: Epoch 263 - training loss: 1.0197, validation loss: 1.9648
# 2025-03-19 18:43:55 [INFO]: Epoch 264 - training loss: 1.0235, validation loss: 1.9561
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:43:57 [INFO]: Epoch 265 - training loss: 1.0256, validation loss: 1.9138
# 2025-03-19 18:43:57 [INFO]: Epoch 266 - training loss: 1.0251, validation loss: 1.8980
# 2025-03-19 18:43:58 [INFO]: Epoch 267 - training loss: 1.0410, validation loss: 1.9056
# 2025-03-19 18:43:58 [INFO]: Epoch 268 - training loss: 0.9895, validation loss: 1.8629
# 2025-03-19 18:43:58 [INFO]: Epoch 269 - training loss: 1.0097, validation loss: 1.9351
# 2025-03-19 18:43:59 [INFO]: Epoch 270 - training loss: 1.0224, validation loss: 1.8089
# 2025-03-19 18:43:59 [INFO]: Epoch 271 - training loss: 0.9953, validation loss: 1.8517
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:00 [INFO]: Epoch 272 - training loss: 1.0471, validation loss: 1.7776
# 2025-03-19 18:44:00 [INFO]: Epoch 273 - training loss: 1.0099, validation loss: 1.8102
# 2025-03-19 18:44:01 [INFO]: Epoch 274 - training loss: 1.0102, validation loss: 1.8433
# 2025-03-19 18:44:01 [INFO]: Epoch 275 - training loss: 1.0147, validation loss: 1.7920
# 2025-03-19 18:44:01 [INFO]: Epoch 276 - training loss: 1.0056, validation loss: 1.7577
# 2025-03-19 18:44:02 [INFO]: Epoch 277 - training loss: 0.9937, validation loss: 1.8367
# 2025-03-19 18:44:02 [INFO]: Epoch 278 - training loss: 0.9810, validation loss: 1.8720
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:03 [INFO]: Epoch 279 - training loss: 0.9815, validation loss: 1.7889
# 2025-03-19 18:44:03 [INFO]: Epoch 280 - training loss: 0.9621, validation loss: 1.8191
# 2025-03-19 18:44:04 [INFO]: Epoch 281 - training loss: 0.9731, validation loss: 1.8188
# 2025-03-19 18:44:04 [INFO]: Epoch 282 - training loss: 0.9974, validation loss: 1.7586
# 2025-03-19 18:44:04 [INFO]: Epoch 283 - training loss: 0.9792, validation loss: 1.8129
# 2025-03-19 18:44:05 [INFO]: Epoch 284 - training loss: 0.9882, validation loss: 1.7318
# 2025-03-19 18:44:05 [INFO]: Epoch 285 - training loss: 0.9612, validation loss: 1.7607
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:06 [INFO]: Epoch 286 - training loss: 0.9823, validation loss: 1.7639
# 2025-03-19 18:44:06 [INFO]: Epoch 287 - training loss: 0.9800, validation loss: 1.7870
# 2025-03-19 18:44:07 [INFO]: Epoch 288 - training loss: 0.9728, validation loss: 1.7295
# 2025-03-19 18:44:07 [INFO]: Epoch 289 - training loss: 0.9769, validation loss: 1.7535
# 2025-03-19 18:44:07 [INFO]: Epoch 290 - training loss: 0.9779, validation loss: 1.7557
# 2025-03-19 18:44:07 [INFO]: Epoch 291 - training loss: 0.9742, validation loss: 1.7662
# 2025-03-19 18:44:08 [INFO]: Epoch 292 - training loss: 0.9863, validation loss: 1.7942
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:09 [INFO]: Epoch 293 - training loss: 0.9894, validation loss: 1.7268
# 2025-03-19 18:44:09 [INFO]: Epoch 294 - training loss: 0.9894, validation loss: 1.7268
# 2025-03-19 18:44:10 [INFO]: Epoch 295 - training loss: 0.9886, validation loss: 1.7129
# 2025-03-19 18:44:10 [INFO]: Epoch 296 - training loss: 0.9497, validation loss: 1.8000
# 2025-03-19 18:44:10 [INFO]: Epoch 297 - training loss: 0.9649, validation loss: 1.6638
# 2025-03-19 18:44:10 [INFO]: Epoch 298 - training loss: 0.9723, validation loss: 1.7034
# 2025-03-19 18:44:11 [INFO]: Epoch 299 - training loss: 0.9591, validation loss: 1.6907
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:12 [INFO]: Epoch 300 - training loss: 0.9510, validation loss: 1.7196
# 2025-03-19 18:44:12 [INFO]: Epoch 301 - training loss: 0.9656, validation loss: 1.6484
# 2025-03-19 18:44:12 [INFO]: Epoch 302 - training loss: 0.9469, validation loss: 1.7171
# 2025-03-19 18:44:13 [INFO]: Epoch 303 - training loss: 0.9616, validation loss: 1.6648
# 2025-03-19 18:44:13 [INFO]: Epoch 304 - training loss: 0.9481, validation loss: 1.7088
# 2025-03-19 18:44:13 [INFO]: Epoch 305 - training loss: 0.9627, validation loss: 1.6981
# 2025-03-19 18:44:14 [INFO]: Epoch 306 - training loss: 0.9477, validation loss: 1.7497
# 2025-03-19 18:44:14 [INFO]: Epoch 307 - training loss: 0.9401, validation loss: 1.6887
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:15 [INFO]: Epoch 308 - training loss: 0.9551, validation loss: 1.6589
# 2025-03-19 18:44:15 [INFO]: Epoch 309 - training loss: 0.9511, validation loss: 1.7346
# 2025-03-19 18:44:16 [INFO]: Epoch 310 - training loss: 0.9323, validation loss: 1.7551
# 2025-03-19 18:44:16 [INFO]: Epoch 311 - training loss: 0.9188, validation loss: 1.7181
# 2025-03-19 18:44:16 [INFO]: Epoch 312 - training loss: 0.9451, validation loss: 1.7236
# 2025-03-19 18:44:17 [INFO]: Epoch 313 - training loss: 0.9566, validation loss: 1.6586
# 2025-03-19 18:44:17 [INFO]: Epoch 314 - training loss: 0.9620, validation loss: 1.6734
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:18 [INFO]: Epoch 315 - training loss: 0.9474, validation loss: 1.6425
# 2025-03-19 18:44:18 [INFO]: Epoch 316 - training loss: 0.9371, validation loss: 1.6671
# 2025-03-19 18:44:19 [INFO]: Epoch 317 - training loss: 0.9527, validation loss: 1.6205
# 2025-03-19 18:44:19 [INFO]: Epoch 318 - training loss: 0.9321, validation loss: 1.6643
# 2025-03-19 18:44:19 [INFO]: Epoch 319 - training loss: 0.9520, validation loss: 1.6551
# 2025-03-19 18:44:20 [INFO]: Epoch 320 - training loss: 0.9376, validation loss: 1.7579
# 2025-03-19 18:44:20 [INFO]: Epoch 321 - training loss: 0.9278, validation loss: 1.6345
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:21 [INFO]: Epoch 322 - training loss: 0.9381, validation loss: 1.6096
# 2025-03-19 18:44:21 [INFO]: Epoch 323 - training loss: 0.9612, validation loss: 1.6146
# 2025-03-19 18:44:22 [INFO]: Epoch 324 - training loss: 0.9211, validation loss: 1.5930
# 2025-03-19 18:44:22 [INFO]: Epoch 325 - training loss: 0.9615, validation loss: 1.6425
# 2025-03-19 18:44:22 [INFO]: Epoch 326 - training loss: 0.9305, validation loss: 1.6401
# 2025-03-19 18:44:22 [INFO]: Epoch 327 - training loss: 0.9304, validation loss: 1.6716
# 2025-03-19 18:44:23 [INFO]: Epoch 328 - training loss: 0.9243, validation loss: 1.5866
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:24 [INFO]: Epoch 329 - training loss: 0.9073, validation loss: 1.5927
# 2025-03-19 18:44:24 [INFO]: Epoch 330 - training loss: 0.9234, validation loss: 1.6075
# 2025-03-19 18:44:25 [INFO]: Epoch 331 - training loss: 0.9078, validation loss: 1.6187
# 2025-03-19 18:44:25 [INFO]: Epoch 332 - training loss: 0.9207, validation loss: 1.5931
# 2025-03-19 18:44:25 [INFO]: Epoch 333 - training loss: 0.9018, validation loss: 1.5871
# 2025-03-19 18:44:25 [INFO]: Epoch 334 - training loss: 0.8983, validation loss: 1.5810
# 2025-03-19 18:44:26 [INFO]: Epoch 335 - training loss: 0.8970, validation loss: 1.5814
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:28 [INFO]: Epoch 336 - training loss: 0.9226, validation loss: 1.6178
# 2025-03-19 18:44:28 [INFO]: Epoch 337 - training loss: 0.9180, validation loss: 1.6052
# 2025-03-19 18:44:28 [INFO]: Epoch 338 - training loss: 0.9014, validation loss: 1.6182
# 2025-03-19 18:44:29 [INFO]: Epoch 339 - training loss: 0.9099, validation loss: 1.5608
# 2025-03-19 18:44:29 [INFO]: Epoch 340 - training loss: 0.9074, validation loss: 1.5560
# 2025-03-19 18:44:29 [INFO]: Epoch 341 - training loss: 0.8968, validation loss: 1.6369
# 2025-03-19 18:44:29 [INFO]: Epoch 342 - training loss: 0.8899, validation loss: 1.5778
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:31 [INFO]: Epoch 343 - training loss: 0.9074, validation loss: 1.5905
# 2025-03-19 18:44:31 [INFO]: Epoch 344 - training loss: 0.8971, validation loss: 1.5833
# 2025-03-19 18:44:31 [INFO]: Epoch 345 - training loss: 0.9083, validation loss: 1.6378
# 2025-03-19 18:44:31 [INFO]: Epoch 346 - training loss: 0.9212, validation loss: 1.5652
# 2025-03-19 18:44:32 [INFO]: Epoch 347 - training loss: 0.8959, validation loss: 1.6839
# 2025-03-19 18:44:32 [INFO]: Epoch 348 - training loss: 0.9189, validation loss: 1.5906
# 2025-03-19 18:44:32 [INFO]: Epoch 349 - training loss: 0.9238, validation loss: 1.6150
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:34 [INFO]: Epoch 350 - training loss: 0.9117, validation loss: 1.6102
# 2025-03-19 18:44:34 [INFO]: Epoch 351 - training loss: 0.9004, validation loss: 1.6478
# 2025-03-19 18:44:34 [INFO]: Epoch 352 - training loss: 0.9011, validation loss: 1.5616
# 2025-03-19 18:44:34 [INFO]: Epoch 353 - training loss: 0.8893, validation loss: 1.5743
# 2025-03-19 18:44:35 [INFO]: Epoch 354 - training loss: 0.8882, validation loss: 1.6266
# 2025-03-19 18:44:35 [INFO]: Epoch 355 - training loss: 0.8680, validation loss: 1.5223
# 2025-03-19 18:44:35 [INFO]: Epoch 356 - training loss: 0.9398, validation loss: 1.5774
# 2025-03-19 18:44:36 [INFO]: Epoch 357 - training loss: 0.8864, validation loss: 1.5587
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:37 [INFO]: Epoch 358 - training loss: 0.8979, validation loss: 1.5724
# 2025-03-19 18:44:37 [INFO]: Epoch 359 - training loss: 0.8872, validation loss: 1.5662
# 2025-03-19 18:44:37 [INFO]: Epoch 360 - training loss: 0.9004, validation loss: 1.4829
# 2025-03-19 18:44:38 [INFO]: Epoch 361 - training loss: 0.8817, validation loss: 1.5086
# 2025-03-19 18:44:38 [INFO]: Epoch 362 - training loss: 0.8811, validation loss: 1.5684
# 2025-03-19 18:44:38 [INFO]: Epoch 363 - training loss: 0.9009, validation loss: 1.5352
# 2025-03-19 18:44:39 [INFO]: Epoch 364 - training loss: 0.8792, validation loss: 1.4896
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:40 [INFO]: Epoch 365 - training loss: 0.8776, validation loss: 1.5885
# 2025-03-19 18:44:40 [INFO]: Epoch 366 - training loss: 0.8694, validation loss: 1.5802
# 2025-03-19 18:44:41 [INFO]: Epoch 367 - training loss: 0.8821, validation loss: 1.4933
# 2025-03-19 18:44:41 [INFO]: Epoch 368 - training loss: 0.8725, validation loss: 1.5249
# 2025-03-19 18:44:41 [INFO]: Epoch 369 - training loss: 0.8637, validation loss: 1.5486
# 2025-03-19 18:44:41 [INFO]: Epoch 370 - training loss: 0.8652, validation loss: 1.5284
# 2025-03-19 18:44:42 [INFO]: Epoch 371 - training loss: 0.8654, validation loss: 1.5078
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:43 [INFO]: Epoch 372 - training loss: 0.8622, validation loss: 1.4753
# 2025-03-19 18:44:43 [INFO]: Epoch 373 - training loss: 0.8587, validation loss: 1.5350
# 2025-03-19 18:44:44 [INFO]: Epoch 374 - training loss: 0.8833, validation loss: 1.5359
# 2025-03-19 18:44:44 [INFO]: Epoch 375 - training loss: 0.8517, validation loss: 1.5137
# 2025-03-19 18:44:44 [INFO]: Epoch 376 - training loss: 0.8650, validation loss: 1.4844
# 2025-03-19 18:44:44 [INFO]: Epoch 377 - training loss: 0.8677, validation loss: 1.4519
# 2025-03-19 18:44:45 [INFO]: Epoch 378 - training loss: 0.8430, validation loss: 1.5200
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:46 [INFO]: Epoch 379 - training loss: 0.8554, validation loss: 1.4669
# 2025-03-19 18:44:46 [INFO]: Epoch 380 - training loss: 0.8566, validation loss: 1.5075
# 2025-03-19 18:44:46 [INFO]: Epoch 381 - training loss: 0.8912, validation loss: 1.5548
# 2025-03-19 18:44:47 [INFO]: Epoch 382 - training loss: 0.8601, validation loss: 1.5423
# 2025-03-19 18:44:47 [INFO]: Epoch 383 - training loss: 0.8517, validation loss: 1.5320
# 2025-03-19 18:44:47 [INFO]: Epoch 384 - training loss: 0.8433, validation loss: 1.5403
# 2025-03-19 18:44:48 [INFO]: Epoch 385 - training loss: 0.8563, validation loss: 1.5291
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:49 [INFO]: Epoch 386 - training loss: 0.8461, validation loss: 1.4909
# 2025-03-19 18:44:49 [INFO]: Epoch 387 - training loss: 0.8515, validation loss: 1.5324
# 2025-03-19 18:44:49 [INFO]: Epoch 388 - training loss: 0.8425, validation loss: 1.4688
# 2025-03-19 18:44:50 [INFO]: Epoch 389 - training loss: 0.8401, validation loss: 1.4794
# 2025-03-19 18:44:50 [INFO]: Epoch 390 - training loss: 0.8377, validation loss: 1.4848
# 2025-03-19 18:44:50 [INFO]: Epoch 391 - training loss: 0.8374, validation loss: 1.5040
# 2025-03-19 18:44:51 [INFO]: Epoch 392 - training loss: 0.8450, validation loss: 1.4735
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:52 [INFO]: Epoch 393 - training loss: 0.8442, validation loss: 1.4796
# 2025-03-19 18:44:52 [INFO]: Epoch 394 - training loss: 0.8429, validation loss: 1.4989
# 2025-03-19 18:44:52 [INFO]: Epoch 395 - training loss: 0.8490, validation loss: 1.4907
# 2025-03-19 18:44:53 [INFO]: Epoch 396 - training loss: 0.8363, validation loss: 1.4757
# 2025-03-19 18:44:53 [INFO]: Epoch 397 - training loss: 0.8449, validation loss: 1.4574
# 2025-03-19 18:44:53 [INFO]: Epoch 398 - training loss: 0.8530, validation loss: 1.4421
# 2025-03-19 18:44:54 [INFO]: Epoch 399 - training loss: 0.8339, validation loss: 1.4545
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:55 [INFO]: Epoch 400 - training loss: 0.8378, validation loss: 1.4256
# 2025-03-19 18:44:55 [INFO]: Epoch 401 - training loss: 0.8800, validation loss: 1.4521
# 2025-03-19 18:44:55 [INFO]: Epoch 402 - training loss: 0.8413, validation loss: 1.4658
# 2025-03-19 18:44:56 [INFO]: Epoch 403 - training loss: 0.8497, validation loss: 1.4788
# 2025-03-19 18:44:56 [INFO]: Epoch 404 - training loss: 0.8308, validation loss: 1.4238
# 2025-03-19 18:44:56 [INFO]: Epoch 405 - training loss: 0.8111, validation loss: 1.3871
# 2025-03-19 18:44:57 [INFO]: Epoch 406 - training loss: 0.8313, validation loss: 1.4460
# 2025-03-19 18:44:57 [INFO]: Epoch 407 - training loss: 0.8342, validation loss: 1.4373
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:44:58 [INFO]: Epoch 408 - training loss: 0.8340, validation loss: 1.3792
# 2025-03-19 18:44:58 [INFO]: Epoch 409 - training loss: 0.8184, validation loss: 1.3752
# 2025-03-19 18:44:59 [INFO]: Epoch 410 - training loss: 0.8195, validation loss: 1.4637
# 2025-03-19 18:44:59 [INFO]: Epoch 411 - training loss: 0.8170, validation loss: 1.3790
# 2025-03-19 18:44:59 [INFO]: Epoch 412 - training loss: 0.8207, validation loss: 1.4358
# 2025-03-19 18:45:00 [INFO]: Epoch 413 - training loss: 0.8218, validation loss: 1.4415
# 2025-03-19 18:45:00 [INFO]: Epoch 414 - training loss: 0.8213, validation loss: 1.4650
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:45:01 [INFO]: Epoch 415 - training loss: 0.8242, validation loss: 1.5002
# 2025-03-19 18:45:02 [INFO]: Epoch 416 - training loss: 0.8247, validation loss: 1.4388
# 2025-03-19 18:45:02 [INFO]: Epoch 417 - training loss: 0.8097, validation loss: 1.3837
# 2025-03-19 18:45:02 [INFO]: Epoch 418 - training loss: 0.8562, validation loss: 1.4230
# 2025-03-19 18:45:02 [INFO]: Epoch 419 - training loss: 0.8120, validation loss: 1.3356
# 2025-03-19 18:45:03 [INFO]: Epoch 420 - training loss: 0.8220, validation loss: 1.3972
# 2025-03-19 18:45:03 [INFO]: Epoch 421 - training loss: 0.8136, validation loss: 1.4340
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:45:04 [INFO]: Epoch 422 - training loss: 0.8149, validation loss: 1.3362
# 2025-03-19 18:45:05 [INFO]: Epoch 423 - training loss: 0.8174, validation loss: 1.4361
# 2025-03-19 18:45:05 [INFO]: Epoch 424 - training loss: 0.8077, validation loss: 1.3639
# 2025-03-19 18:45:05 [INFO]: Epoch 425 - training loss: 0.8255, validation loss: 1.3820
# 2025-03-19 18:45:05 [INFO]: Epoch 426 - training loss: 0.8104, validation loss: 1.4066
# 2025-03-19 18:45:06 [INFO]: Epoch 427 - training loss: 0.8189, validation loss: 1.3663
# 2025-03-19 18:45:06 [INFO]: Epoch 428 - training loss: 0.8190, validation loss: 1.4289
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:45:07 [INFO]: Epoch 429 - training loss: 0.8152, validation loss: 1.3968
# 2025-03-19 18:45:08 [INFO]: Epoch 430 - training loss: 0.8093, validation loss: 1.3973
# 2025-03-19 18:45:08 [INFO]: Epoch 431 - training loss: 0.8172, validation loss: 1.4392
# 2025-03-19 18:45:08 [INFO]: Epoch 432 - training loss: 0.8153, validation loss: 1.3926
# 2025-03-19 18:45:08 [INFO]: Epoch 433 - training loss: 0.8199, validation loss: 1.4397
# 2025-03-19 18:45:09 [INFO]: Epoch 434 - training loss: 0.8137, validation loss: 1.4355
# 2025-03-19 18:45:09 [INFO]: Epoch 435 - training loss: 0.8069, validation loss: 1.4132
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:45:11 [INFO]: Epoch 436 - training loss: 0.8144, validation loss: 1.4110
# 2025-03-19 18:45:11 [INFO]: Epoch 437 - training loss: 0.8154, validation loss: 1.3900
# 2025-03-19 18:45:12 [INFO]: Epoch 438 - training loss: 0.8165, validation loss: 1.3779
# 2025-03-19 18:45:12 [INFO]: Epoch 439 - training loss: 0.8057, validation loss: 1.4249
# 2025-03-19 18:45:12 [INFO]: Epoch 440 - training loss: 0.8042, validation loss: 1.4319
# 2025-03-19 18:45:13 [INFO]: Epoch 441 - training loss: 0.8020, validation loss: 1.3988
# 2025-03-19 18:45:13 [INFO]: Epoch 442 - training loss: 0.7973, validation loss: 1.3891
# /Users/louis/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/nn/modules/gp_uae/plotting_utils.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-03-19 18:45:14 [INFO]: Epoch 443 - training loss: 0.8036, validation loss: 1.3711
# 2025-03-19 18:45:14 [INFO]: Epoch 444 - training loss: 0.8299, validation loss: 1.3903
# 2025-03-19 18:45:15 [INFO]: Epoch 445 - training loss: 0.8097, validation loss: 1.3833
# 2025-03-19 18:45:15 [INFO]: Epoch 446 - training loss: 0.7907, validation loss: 1.3887
# 2025-03-19 18:45:15 [INFO]: Epoch 447 - training loss: 0.7922, validation loss: 1.3788
# 2025-03-19 18:45:16 [INFO]: Epoch 448 - training loss: 0.7992, validation loss: 1.3661
# 2025-03-19 18:45:16 [INFO]: Epoch 449 - training loss: 0.8087, validation loss: 1.4116
# 2025-03-19 18:45:16 [INFO]: Exceeded the training patience. Terminating the training procedure...
# 2025-03-19 18:45:16 [INFO]: Finished training. The best model is from epoch#419.

# %%
#with torch.autograd.set_detect_anomaly(True):
gpuae.fit(dataset_train, dataset_val, train_kernel_only=True)
# Out:
# training kernel
# 0it [00:00, ?it/s]
# 0.1399977058172226 0.29601243138313293
# 1it [00:04,  4.09s/it]
# 0.1514521688222885 0.2915320098400116
# 2it [00:08,  4.21s/it]
# 0.1372428685426712 0.2548181116580963
# 3it [00:12,  4.28s/it]
# 0.14825443923473358 0.28931960463523865
# 4it [00:17,  4.32s/it]
# 0.14222443103790283 0.24273714423179626
# 5it [00:17,  3.59s/it]
# torch.Size([64, 24, 13]) torch.Size([64, 24, 13])
# torch.Size([54, 24, 13]) torch.Size([54, 24, 13])
# Epoch 2/500: Training Loss = 0.339490, Validation Loss = 0.235303
# 0it [00:00, ?it/s]
# 0.13589945435523987 0.26518574357032776
# 1it [00:04,  4.65s/it]
# 0.13497698307037354 0.25657814741134644
# 2it [00:09,  4.55s/it]
# 0.13473379611968994 0.24341033399105072
# 3it [00:13,  4.47s/it]
# 0.11101354658603668 0.21317271888256073
# 4it [00:17,  4.41s/it]
# 0.13644203543663025 0.2679484784603119
# 5it [00:18,  3.76s/it]
# torch.Size([64, 24, 13]) torch.Size([64, 24, 13])
# torch.Size([54, 24, 13]) torch.Size([54, 24, 13])
# Epoch 3/500: Training Loss = 0.309493, Validation Loss = 0.226935
# 0it [00:00, ?it/s]
# 0.12491675466299057 0.21295671164989471
# 1it [00:04,  4.67s/it]
# 0.11820995062589645 0.19635866582393646
# 2it [00:09,  4.76s/it]
# 0.09825914353132248 0.18969197571277618
# 3it [00:14,  4.67s/it]
# 0.10736867785453796 0.20012222230434418
# 4it [00:18,  4.61s/it]
# 0.11249212920665741 0.22832055389881134
# 5it [00:19,  3.88s/it]
# torch.Size([64, 24, 13]) torch.Size([64, 24, 13])
# torch.Size([54, 24, 13]) torch.Size([54, 24, 13])
# Epoch 4/500: Training Loss = 0.262156, Validation Loss = 0.222452
# 0it [00:00, ?it/s]
# 0.10090920329093933 0.19894275069236755
# 1it [00:04,  4.69s/it]
# 0.0874522477388382 0.19467349350452423
# 2it [00:09,  4.70s/it]
# 0.09400369226932526 0.18077734112739563
# 3it [00:14,  4.68s/it]
# 0.0884929671883583 0.18845707178115845
# 4it [00:18,  4.64s/it]
# 0.09842516481876373 0.227897047996521
# 5it [00:19,  3.91s/it]
# torch.Size([64, 24, 13]) torch.Size([64, 24, 13])
# torch.Size([54, 24, 13]) torch.Size([54, 24, 13])
# Epoch 5/500: Training Loss = 0.217091, Validation Loss = 0.223648
# 0it [00:00, ?it/s]
# 0.07597341388463974 0.18001513183116913
# 1it [00:04,  4.54s/it]
# 0.06827125698328018 0.19430433213710785
# 2it [00:08,  4.44s/it]
# 0.07277356833219528 0.20841965079307556
# 3it [00:13,  4.58s/it]
# 0.0690125823020935 0.20843522250652313
# 4it [00:18,  4.59s/it]
# 0.06016436219215393 0.16372480988502502
# 5it [00:19,  3.82s/it]
# torch.Size([64, 24, 13]) torch.Size([64, 24, 13])
# torch.Size([54, 24, 13]) torch.Size([54, 24, 13])
# Epoch 6/500: Training Loss = 0.165713, Validation Loss = 0.262515
# 0it [00:00, ?it/s]
# 0.06351082026958466 0.2284637689590454
# 1it [00:04,  4.48s/it]
# 0.07008977234363556 0.25684311985969543
# 2it [00:08,  4.36s/it]
# 0.06458993256092072 0.22135430574417114
# 3it [00:13,  4.37s/it]
# 0.05568179860711098 0.23042607307434082
# 4it [00:17,  4.40s/it]
# 0.06493325531482697 0.25794821977615356
# 5it [00:18,  3.68s/it]
# torch.Size([64, 24, 13]) torch.Size([64, 24, 13])
# torch.Size([54, 24, 13]) torch.Size([54, 24, 13])
# Epoch 7/500: Training Loss = 0.151099, Validation Loss = 0.303883
# 0it [00:00, ?it/s]
# 0.05906235799193382 0.245760977268219
# 1it [00:04,  4.30s/it]
# 0.05171512812376022 0.2463606745004654
# 2it [00:08,  4.36s/it]
# 0.045942917466163635 0.226925328373909
# 3it [00:13,  4.43s/it]
# 0.05037973076105118 0.24936096370220184
# 4it [00:17,  4.43s/it]
# 0.04692221060395241 0.2894517481327057
# 5it [00:18,  3.69s/it]
# torch.Size([64, 24, 13]) torch.Size([64, 24, 13])
# torch.Size([54, 24, 13]) torch.Size([54, 24, 13])
# Epoch 8/500: Training Loss = 0.142935, Validation Loss = 0.297559
# 0it [00:00, ?it/s]
# 0.038834065198898315 0.21908381581306458
# 1it [00:04,  4.54s/it]
# 0.03858551010489464 0.26158472895622253
# 2it [00:09,  4.52s/it]
# 0.03792208433151245 0.21245382726192474
# 3it [00:13,  4.41s/it]
# 0.03448536992073059 0.23869845271110535
# 4it [00:17,  4.48s/it]
# 0.043888188898563385 0.26832807064056396
# 5it [00:18,  3.75s/it]
# torch.Size([64, 24, 13]) torch.Size([64, 24, 13])
# torch.Size([54, 24, 13]) torch.Size([54, 24, 13])
# Epoch 9/500: Training Loss = 0.134851, Validation Loss = 0.293857
# 0it [00:00, ?it/s]
# 0.03708460554480553 0.25434398651123047
# 1it [00:04,  4.46s/it]
# 0.03082648105919361 0.219109445810318
# 2it [00:08,  4.37s/it]
# 0.0312223918735981 0.22320623695850372
# 3it [00:13,  4.33s/it]
# 0.03224914148449898 0.22987885773181915
# 4it [00:17,  4.39s/it]
# 0.03324496001005173 0.22246065735816956
# 5it [00:18,  3.67s/it]
# torch.Size([64, 24, 13]) torch.Size([64, 24, 13])
# torch.Size([54, 24, 13]) torch.Size([54, 24, 13])
# Epoch 10/500: Training Loss = 0.133981, Validation Loss = 0.283003
# 0it [00:00, ?it/s]
# 0.02982255443930626 0.22448810935020447
# 1it [00:04,  4.18s/it]
# 0.035898562520742416 0.23914121091365814
# 2it [00:08,  4.41s/it]
# 0.032918814569711685 0.24583034217357635
# 3it [00:13,  4.37s/it]
# 0.031170876696705818 0.235177144408226
# 4it [00:17,  4.45s/it]
# 0.027819322422146797 0.20368172228336334
# 5it [00:18,  3.69s/it]
# torch.Size([64, 24, 13]) torch.Size([64, 24, 13])
# torch.Size([54, 24, 13]) torch.Size([54, 24, 13])
# Epoch 11/500: Training Loss = 0.131330, Validation Loss = 0.283675
# 0it [00:00, ?it/s]
# 0.033336710184812546 0.2249716967344284
# 1it [00:04,  4.53s/it]
# 0.030659638345241547 0.22059528529644012
# 2it [00:09,  4.50s/it]
# 0.03311377763748169 0.23078936338424683
# 3it [00:13,  4.38s/it]
# 0.032705239951610565 0.22790326178073883
# 4it [00:18,  4.55s/it]
# 0.03290247172117233 0.1813460737466812
# 5it [00:18,  3.78s/it]
# torch.Size([64, 24, 13]) torch.Size([64, 24, 13])
# torch.Size([54, 24, 13]) torch.Size([54, 24, 13])
# Epoch 12/500: Training Loss = 0.125482, Validation Loss = 0.291142
# 0it [00:00, ?it/s]
# 0.03937934339046478 0.25464677810668945
# 1it [00:04,  4.32s/it]
# 0.030964961275458336 0.19947412610054016
# 2it [00:08,  4.42s/it]
# 0.031634896993637085 0.21481767296791077
# 3it [00:13,  4.35s/it]
# 0.03457619622349739 0.23007656633853912
# 4it [00:17,  4.36s/it]
# 0.036029037088155746 0.24673378467559814
# 5it [00:18,  3.66s/it]
# torch.Size([64, 24, 13]) torch.Size([64, 24, 13])
# torch.Size([54, 24, 13]) torch.Size([54, 24, 13])
# Epoch 13/500: Training Loss = 0.128459, Validation Loss = 0.290605
# 0it [00:00, ?it/s]
# 0.032620057463645935 0.20603328943252563
# 1it [00:04,  4.18s/it]
# 0.03949778154492378 0.2071792483329773
# 2it [00:08,  4.43s/it]
# 0.03822316601872444 0.22996732592582703
# 3it [00:13,  4.53s/it]
# 0.033048901706933975 0.21424414217472076
# 4it [00:17,  4.54s/it]
# 0.03158634155988693 0.2309744656085968
# 5it [00:18,  3.77s/it]
# torch.Size([64, 24, 13]) torch.Size([64, 24, 13])
# torch.Size([54, 24, 13]) torch.Size([54, 24, 13])
# Epoch 14/500: Training Loss = 0.123193, Validation Loss = 0.287566
# 0it [00:00, ?it/s]
# 0.038362402468919754 0.24946057796478271
# 0it [00:04, ?it/s]
# 2025-03-19 18:54:33 [WARNING]: ‼️ Training got interrupted by the user. Exist now ...
# 2025-03-19 18:54:33 [INFO]: Finished training. The best model is from epoch#3.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 2
#       1 #with torch.autograd.set_detect_anomaly(True):
# ----> 2 gpuae.fit(dataset_train, dataset_val, train_kernel_only=True)
#
# File ~/Documents/Phd/Code_pour_manuscript/PyPOTS/ipynbs/../pypots/imputation/gpuae/model.py:574, in GP_UAE.fit(self, train_set, val_set, file_type, train_kernel_only)
#     571 # Step 2bis: learn the kernel
#     572 else:
#     573     print('training kernel')
# --> 574     self._train_kernel(training_loader, val_loader)
#
# KeyboardInterrupt:

# %%
gpvae.fit(dataset_train, dataset_val)

# %%
#gpvae.gp.plot_while_training = True
gpuae.fit_kernel(dataset_train, dataset_val, training_iter = 50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 2
#       1 #gpvae.gp.plot_while_training = True
# ----> 2 gpuae.fit_kernel(dataset_train, dataset_val, training_iter = 50)
#
# AttributeError: 'GP_UAE' object has no attribute 'fit_kernel'

# %%
torch.save(gpvae.model.backbone.encoder.state_dict().copy(), 'encoder')
torch.save(gpvae.model.backbone.decoder.state_dict().copy(), 'decoder')

# %%
state_dict = torch.load('encoder');
gpvae.model.backbone.encoder.load_state_dict(state_dict);
state_dict = torch.load('decoder');
gpvae.model.backbone.decoder.load_state_dict(state_dict);

# %%
X_val_imputed = gpvae.impute(dataset_val, with_gp = True)
plt.plot(X_val_imputed[0]);
plt.gca().set_prop_cycle(None)
plt.plot(dataset_val['X'][0],'o');
plt.gca().set_prop_cycle(None)
plt.plot(dataset_val['X_ori'][0],'+');

# %%
mse_obs, mse_hidden = plot_reconstruction_with_GP(X[::5], X_normalized[::5], gpvae, i = 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 mse_obs, mse_hidden = plot_reconstruction_with_GP(X[::5], X_normalized[::5], gpvae, i = 4)
#
# NameError: name 'plot_reconstruction_with_GP' is not defined
