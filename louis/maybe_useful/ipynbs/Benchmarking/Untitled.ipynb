# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("../..")

# %%
from pypots.data.generating import gene_physionet2012
from pypots.utils.random import set_random_seed
#from global_config import RANDOM_SEED
#set_random_seed(RANDOM_SEED)

import random
random.seed(9001)

# Load the PhysioNet-2012 dataset, disable artificially-missing values for evaluation
physionet2012_dataset = gene_physionet2012(artificially_missing_rate=0.3)
 
# Take a look at the generated PhysioNet-2012 dataset, you'll find that everything has been prepared for you, 
# data splitting, normalization, additional artificially-missing values for evaluation, etc.
print(physionet2012_dataset.keys())
# Out:
# 2025-03-24 09:23:31 [INFO]: You're using dataset physionet_2012, please cite it properly in your work. You can find its reference information at the below link:
# https://github.com/WenjieDu/TSDB/tree/main/dataset_profiles/physionet_2012
# 2025-03-24 09:23:31 [INFO]: Dataset physionet_2012 has already been downloaded. Processing directly...
# 2025-03-24 09:23:31 [INFO]: Dataset physionet_2012 has already been cached. Loading from cache directly...
# 2025-03-24 09:23:31 [INFO]: Loaded successfully!
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 10
#       7 random.seed(9001)
#       9 # Load the PhysioNet-2012 dataset, disable artificially-missing values for evaluation
# ---> 10 physionet2012_dataset = gene_physionet2012(artificially_missing_rate=0.3)
# ...

# %%
import tsdb
physionet2012_dataset = tsdb.load('physionet_2012')
# Out:
# 2025-03-24 09:34:54 [INFO]: You're using dataset physionet_2012, please cite it properly in your work. You can find its reference information at the below link:
# https://github.com/WenjieDu/TSDB/tree/main/dataset_profiles/physionet_2012
# 2025-03-24 09:34:54 [INFO]: Dataset physionet_2012 has already been downloaded. Processing directly...
# 2025-03-24 09:34:54 [INFO]: Dataset physionet_2012 has already been cached. Loading from cache directly...
# 2025-03-24 09:34:54 [INFO]: Loaded successfully!

# %%
physionet2012_dataset['X']
# Out:
# Parameter  ALP  ALT  AST   Age  Albumin   BUN  Bilirubin  Cholesterol  \
# 0          NaN  NaN  NaN  35.0      NaN   NaN        NaN          NaN
# 1          NaN  NaN  NaN  35.0      NaN   NaN        NaN          NaN
# 2          NaN  NaN  NaN  35.0      NaN  68.0        NaN          NaN
# 3          NaN  NaN  NaN  35.0      NaN   NaN        NaN          NaN
# 4          NaN  NaN  NaN  35.0      NaN   NaN        NaN          NaN
# ...        ...  ...  ...   ...      ...   ...        ...          ...
# 541986     NaN  NaN  NaN  50.0      NaN   NaN        NaN          NaN
# 541987     NaN  NaN  NaN  50.0      NaN  46.0        NaN          NaN
# 541988     NaN  NaN  NaN  50.0      NaN   NaN        NaN          NaN
# 541989     NaN  NaN  NaN  50.0      NaN   NaN        NaN          NaN
# 541990     NaN  NaN  NaN  50.0      NaN   NaN        NaN          NaN
#
# Parameter  Creatinine  DiasABP  ...  SaO2  SysABP  Temp  Time  TroponinI  \
# ...

# %%
physionet2012_dataset['X']
# Out:
# Parameter  ALP  ALT  AST   Age  Albumin   BUN  Bilirubin  Cholesterol  \
# 0          NaN  NaN  NaN  35.0      NaN   NaN        NaN          NaN
# 1          NaN  NaN  NaN  35.0      NaN   NaN        NaN          NaN
# 2          NaN  NaN  NaN  35.0      NaN  68.0        NaN          NaN
# 3          NaN  NaN  NaN  35.0      NaN   NaN        NaN          NaN
# 4          NaN  NaN  NaN  35.0      NaN   NaN        NaN          NaN
# ...        ...  ...  ...   ...      ...   ...        ...          ...
# 541986     NaN  NaN  NaN  50.0      NaN   NaN        NaN          NaN
# 541987     NaN  NaN  NaN  50.0      NaN  46.0        NaN          NaN
# 541988     NaN  NaN  NaN  50.0      NaN   NaN        NaN          NaN
# 541989     NaN  NaN  NaN  50.0      NaN   NaN        NaN          NaN
# 541990     NaN  NaN  NaN  50.0      NaN   NaN        NaN          NaN
#
# Parameter  Creatinine  DiasABP  ...  SaO2  SysABP  Temp  Time  TroponinI  \
# ...

# %%
physionet2012_dataset['X'].shape, physionet2012_dataset['y'].shape, len(physionet2012_dataset['static_features'])
# Out:
# ((541991, 43), (11988, 1), 4)

# %%
for dataset_name in chosen_classes:
    dataset = tsdb.load(dataset_name)
    print(dataset_name, dataset.keys())
    for key in dataset.keys():
        try:
            print(key, dataset[key].shape)
        except:
            print(key, len(dataset[key]))
    
    #try:
    #    X, y = physionet2012_dataset['X'], physionet2012_dataset['y']
# Out:
# 2025-03-19 18:27:11 [INFO]: You're using dataset ucr_uea_GunPoint, please cite it properly in your work. You can find its reference information at the below link:
# https://github.com/WenjieDu/TSDB/tree/main/dataset_profiles/ucr_uea_datasets
# 2025-03-19 18:27:11 [INFO]: Start downloading...
# ...
# 2025-03-19 18:27:11 [INFO]: Successfully downloaded data to /var/folders/7s/75p3d4f145qfrrzfq5vskssc0000gn/T/tmpwxy77g95/GunPoint.zip
# 2025-03-19 18:27:11 [INFO]: Successfully extracted data to /Users/louis/.pypots/tsdb/ucr_uea_GunPoint
# 2025-03-19 18:27:11 [INFO]: Successfully saved to /Users/louis/.pypots/tsdb/ucr_uea_GunPoint/ucr_uea_GunPoint_cache.pkl
# 2025-03-19 18:27:11 [INFO]: Loaded successfully!
# ucr_uea_GunPoint dict_keys(['X_train', 'y_train', 'X_test', 'y_test'])
# X_train (50, 1, 150)
# y_train (50,)
# X_test (150, 1, 150)
# y_test (150,)

# %%
X.shape, y.shape
# Out:
# ((541991, 43), (11988, 1))

# %%
from sklearn.model_selection import train_test_split

X, y = physionet2012_dataset['X'], physionet2012_dataset['y']

X_train, X_test, y_train, y_test = train_test_split(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 5
#       1 from sklearn.model_selection import train_test_split
#       3 X, y = physionet2012_dataset['X'], physionet2012_dataset['y']
# ----> 5 X_train, X_test, y_train, y_test = train_test_split(X, y)
#
# File ~/miniforge3/envs/pypots-env/lib/python3.9/site-packages/sklearn/model_selection/_split.py:2559, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2556 if n_arrays == 0:
#    2557     raise ValueError("At least one array required as input")
# -> 2559 arrays = indexable(*arrays)
#    2561 n_samples = _num_samples(arrays[0])
#    2562 n_train, n_test = _validate_shuffle_split(
#    2563     n_samples, test_size, train_size, default_test_size=0.25
#    2564 )
#
# ...
