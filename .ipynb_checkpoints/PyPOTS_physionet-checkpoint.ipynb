# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pypots.data.generating import gene_physionet2012
from pypots.utils.random import set_random_seed

# %%
tsdb.list()
# Out:
# ['physionet_2012',
#  'physionet_2019',
#  'electricity_load_diagrams',
#  'beijing_multisite_air_quality',
#  'italy_air_quality',
#  'vessel_ais',
#  'electricity_transformer_temperature',
#  'pems_traffic',
#  'solar_alabama',
#  'ucr_uea_ACSF1',
#  'ucr_uea_Adiac',
#  'ucr_uea_AllGestureWiimoteX',
#  'ucr_uea_AllGestureWiimoteY',
#  'ucr_uea_AllGestureWiimoteZ',
#  'ucr_uea_ArrowHead',
#  'ucr_uea_Beef',
#  'ucr_uea_BeetleFly',
#  'ucr_uea_BirdChicken',
#  'ucr_uea_BME',
#  'ucr_uea_Car',
#  'ucr_uea_CBF',
#  'ucr_uea_Chinatown',
#  'ucr_uea_ChlorineConcentration',
#  'ucr_uea_CinCECGTorso',
#  'ucr_uea_Coffee',
#  'ucr_uea_Computers',
#  'ucr_uea_CricketX',
#  'ucr_uea_CricketY',
#  'ucr_uea_CricketZ',
#  'ucr_uea_Crop',
#  'ucr_uea_DiatomSizeReduction',
#  'ucr_uea_DistalPhalanxOutlineCorrect',
#  'ucr_uea_DistalPhalanxOutlineAgeGroup',
#  'ucr_uea_DistalPhalanxTW',
#  'ucr_uea_DodgerLoopDay',
#  'ucr_uea_DodgerLoopGame',
#  'ucr_uea_DodgerLoopWeekend',
#  'ucr_uea_Earthquakes',
#  'ucr_uea_ECG200',
#  'ucr_uea_ECG5000',
#  'ucr_uea_ECGFiveDays',
#  'ucr_uea_ElectricDevices',
#  'ucr_uea_EOGHorizontalSignal',
#  'ucr_uea_EOGVerticalSignal',
#  'ucr_uea_EthanolLevel',
#  'ucr_uea_FaceAll',
#  'ucr_uea_FaceFour',
#  'ucr_uea_FacesUCR',
#  'ucr_uea_FiftyWords',
#  'ucr_uea_Fish',
#  'ucr_uea_FordA',
#  'ucr_uea_FordB',
#  'ucr_uea_FreezerRegularTrain',
#  'ucr_uea_FreezerSmallTrain',
#  'ucr_uea_Fungi',
#  'ucr_uea_GestureMidAirD1',
#  'ucr_uea_GestureMidAirD2',
#  'ucr_uea_GestureMidAirD3',
#  'ucr_uea_GesturePebbleZ1',
#  'ucr_uea_GesturePebbleZ2',
#  'ucr_uea_GunPoint',
#  'ucr_uea_GunPointAgeSpan',
#  'ucr_uea_GunPointMaleVersusFemale',
#  'ucr_uea_GunPointOldVersusYoung',
#  'ucr_uea_Ham',
#  'ucr_uea_HandOutlines',
#  'ucr_uea_Haptics',
#  'ucr_uea_Herring',
#  'ucr_uea_HouseTwenty',
#  'ucr_uea_InlineSkate',
#  'ucr_uea_InsectEPGRegularTrain',
#  'ucr_uea_InsectEPGSmallTrain',
#  'ucr_uea_InsectWingbeatSound',
#  'ucr_uea_ItalyPowerDemand',
#  'ucr_uea_LargeKitchenAppliances',
#  'ucr_uea_Lightning2',
#  'ucr_uea_Lightning7',
#  'ucr_uea_Mallat',
#  'ucr_uea_Meat',
#  'ucr_uea_MedicalImages',
#  'ucr_uea_MelbournePedestrian',
#  'ucr_uea_MiddlePhalanxOutlineCorrect',
#  'ucr_uea_MiddlePhalanxOutlineAgeGroup',
#  'ucr_uea_MiddlePhalanxTW',
#  'ucr_uea_MixedShapesRegularTrain',
#  'ucr_uea_MixedShapesSmallTrain',
#  'ucr_uea_MoteStrain',
#  'ucr_uea_NonInvasiveFetalECGThorax1',
#  'ucr_uea_NonInvasiveFetalECGThorax2',
#  'ucr_uea_OliveOil',
#  'ucr_uea_OSULeaf',
#  'ucr_uea_PhalangesOutlinesCorrect',
#  'ucr_uea_Phoneme',
#  'ucr_uea_PickupGestureWiimoteZ',
#  'ucr_uea_PigAirwayPressure',
#  'ucr_uea_PigArtPressure',
#  'ucr_uea_PigCVP',
#  'ucr_uea_PLAID',
#  'ucr_uea_Plane',
#  'ucr_uea_PowerCons',
#  'ucr_uea_ProximalPhalanxOutlineCorrect',
#  'ucr_uea_ProximalPhalanxOutlineAgeGroup',
#  'ucr_uea_ProximalPhalanxTW',
#  'ucr_uea_RefrigerationDevices',
#  'ucr_uea_Rock',
#  'ucr_uea_ScreenType',
#  'ucr_uea_SemgHandGenderCh2',
#  'ucr_uea_SemgHandMovementCh2',
#  'ucr_uea_SemgHandSubjectCh2',
#  'ucr_uea_ShakeGestureWiimoteZ',
#  'ucr_uea_ShapeletSim',
#  'ucr_uea_ShapesAll',
#  'ucr_uea_SmallKitchenAppliances',
#  'ucr_uea_SmoothSubspace',
#  'ucr_uea_SonyAIBORobotSurface1',
#  'ucr_uea_SonyAIBORobotSurface2',
#  'ucr_uea_StarLightCurves',
#  'ucr_uea_Strawberry',
#  'ucr_uea_SwedishLeaf',
#  'ucr_uea_Symbols',
#  'ucr_uea_SyntheticControl',
#  'ucr_uea_ToeSegmentation1',
#  'ucr_uea_ToeSegmentation2',
#  'ucr_uea_Trace',
#  'ucr_uea_TwoLeadECG',
#  'ucr_uea_TwoPatterns',
#  'ucr_uea_UMD',
#  'ucr_uea_UWaveGestureLibraryAll',
#  'ucr_uea_UWaveGestureLibraryX',
#  'ucr_uea_UWaveGestureLibraryY',
#  'ucr_uea_UWaveGestureLibraryZ',
#  'ucr_uea_Wafer',
#  'ucr_uea_Wine',
#  'ucr_uea_WordSynonyms',
#  'ucr_uea_Worms',
#  'ucr_uea_WormsTwoClass',
#  'ucr_uea_Yoga',
#  'ucr_uea_ArticularyWordRecognition',
#  'ucr_uea_AsphaltObstaclesCoordinates',
#  'ucr_uea_AsphaltPavementTypeCoordinates',
#  'ucr_uea_AsphaltRegularityCoordinates',
#  'ucr_uea_AtrialFibrillation',
#  'ucr_uea_BasicMotions',
#  'ucr_uea_CharacterTrajectories',
#  'ucr_uea_Cricket',
#  'ucr_uea_DuckDuckGeese',
#  'ucr_uea_EigenWorms',
#  'ucr_uea_Epilepsy',
#  'ucr_uea_EthanolConcentration',
#  'ucr_uea_ERing',
#  'ucr_uea_FaceDetection',
#  'ucr_uea_FingerMovements',
#  'ucr_uea_HandMovementDirection',
#  'ucr_uea_Handwriting',
#  'ucr_uea_Heartbeat',
#  'ucr_uea_InsectWingbeat',
#  'ucr_uea_JapaneseVowels',
#  'ucr_uea_Libras',
#  'ucr_uea_LSST',
#  'ucr_uea_MotorImagery',
#  'ucr_uea_NATOPS',
#  'ucr_uea_PenDigits',
#  'ucr_uea_PEMS-SF',
#  'ucr_uea_PhonemeSpectra',
#  'ucr_uea_RacketSports',
#  'ucr_uea_SelfRegulationSCP1',
#  'ucr_uea_SelfRegulationSCP2',
#  'ucr_uea_SpokenArabicDigits',
#  'ucr_uea_StandWalkJump',
#  'ucr_uea_UWaveGestureLibrary',
#  'ucr_uea_NonInvasiveFatalECGThorax1',
#  'ucr_uea_NonInvasiveFatalECGThorax2']

# %%
data_ = tsdb.load('italy_air_quality')
# Out:
# 2025-02-28 14:15:20 [INFO]: You're using dataset italy_air_quality, please cite it properly in your work. You can find its reference information at the below link:
# https://github.com/WenjieDu/TSDB/tree/main/dataset_profiles/italy_air_quality
# 2025-02-28 14:15:20 [INFO]: Start downloading...
# Downloading air+quality.zip: 1.47MB [00:01, 1.21MB/s]
# 2025-02-28 14:15:29 [INFO]: Successfully downloaded data to /var/folders/7s/75p3d4f145qfrrzfq5vskssc0000gn/T/tmpi7hqh6f3/air+quality.zip
# 2025-02-28 14:15:29 [INFO]: Successfully extracted data to /Users/louis/.pypots/tsdb/italy_air_quality
# 2025-02-28 14:15:29 [INFO]: Successfully saved to /Users/louis/.pypots/tsdb/italy_air_quality/italy_air_quality_cache.pkl
# 2025-02-28 14:15:29 [INFO]: Loaded successfully!

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

df = data_['X']

# Combine 'Date' and 'Time' into a single datetime column.
# Adjust the format as needed (here the format is: day/month/year hour.minute.second)
df['Datetime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'], format='%d/%m/%Y %H.%M.%S')

# Optional: extract additional time features if they are useful for your ML model
df['Year'] = df['Datetime'].dt.year
df['Month'] = df['Datetime'].dt.month
df['Day'] = df['Datetime'].dt.day
df['Hour'] = df['Datetime'].dt.hour

# Drop the original 'Date' and 'Time' columns if they are no longer needed
#df.drop(['Date', 'Time'], axis=1, inplace=True)

# Replace error codes (e.g., -200) with NaN for cleaning
#df.replace(-200, np.nan, inplace=True)

# Identify the columns to normalize.
# If you want to normalize all numeric columns (excluding the datetime column), you can do:
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Initialize the scaler (here we use StandardScaler for z-score normalization)
scaler = StandardScaler()

# Fit and transform the numeric columns
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

df.sort_values(by = ['Date','Hour'], inplace = True)


# Your dataframe 'df' is now ready for machine learning, with a datetime feature and normalized numeric values.
df.head()
# Out:
#             Date      Time    CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 7110  01/01/2005  00.00.00 -2.135042    -0.009066  -0.29267  0.056414
# 7111  01/01/2005  01.00.00  0.461122     0.685263  -0.29267  0.167585
# 7112  01/01/2005  02.00.00  0.472712     0.375998  -0.29267  0.136167
# 7113  01/01/2005  03.00.00  0.475288     0.345678  -0.29267  0.138584
# 7114  01/01/2005  04.00.00  0.464985     0.015190  -0.29267  0.090249
#
#       PT08.S2(NMHC)   NOx(GT)  PT08.S3(NOx)   NO2(GT)  PT08.S4(NO2)  \
# 7110      -0.498358 -1.431966      0.164639 -2.033730     -1.056283
# 7111       0.103427  0.180184     -0.453419  0.376977     -0.786582
# 7112      -0.048480  0.510384     -0.177001  0.558174     -0.833673
# 7113      -0.039716 -1.431966     -0.145943 -2.033730     -0.835813
# 7114      -0.302631  0.327803      0.108734  0.534540     -0.908590
#
#       PT08.S5(O3)         T        RH        AH            Datetime  Year  \
# 7110     0.494465 -0.036534  0.012001  0.186663 2005-01-01 00:00:00  2005
# 7111     1.404921 -0.103661  0.218978  0.187148 2005-01-01 01:00:00  2005
# 7112     0.831509 -0.089773  0.205310  0.187468 2005-01-01 02:00:00  2005
# 7113     0.702382 -0.112920  0.281462  0.187479 2005-01-01 03:00:00  2005
# 7114     0.341263 -0.126809  0.308798  0.187368 2005-01-01 04:00:00  2005
#
#       Month  Day  Hour
# 7110      1    1     0
# 7111      1    1     1
# 7112      1    1     2
# 7113      1    1     3
# 7114      1    1     4

# %%
import pandas as pd
import numpy as np

# Assume df is your preprocessed DataFrame from before,
# and that it contains a 'Datetime' column.
# Define the relevant columns (d features) you wish to use:
relevant_columns = ['CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
                    'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)',
                    'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']

# Extract the day and hour from the Datetime column
df['Day'] = df['Datetime'].dt.date
df['Hour'] = df['Datetime'].dt.hour

# Group by day and reindex each day to ensure it has exactly 24 hours.
daily_arrays = []
for day, group in df.groupby('Day'):
    # Set the hour as index and sort by hour
    group = group.set_index('Hour').sort_index()
    # Reindex to ensure every hour from 0 to 23 is present; missing hours will be filled with NaN.
    group = group.reindex(range(24))
    # Extract the relevant columns and convert to a numpy array of shape (24, d)
    daily_array = group[relevant_columns].values
    daily_arrays.append(daily_array)

# Convert list of daily arrays into a single numpy array with shape (N, 24, d)
data_array = np.stack(daily_arrays, axis=0)
print("Shape of the reshaped data:", data_array.shape)
# Out:
# Shape of the reshaped data: (391, 24, 13)

# %%
import numpy as np
from pygrinder import mcar
import torch

X = torch.tensor(data_array).float()

## Normalize_data
mean, std = np.nanmean(X,axis=0)[None,:], np.nanstd(X, axis=0)[None,:]
std[std==0] = 1
X_normalized = (X - mean) / std
X_normalized = X_normalized.clip(min=-2,max=2)

X = mcar(torch.clone(X_normalized), p = 0.5)

# %%
dataset = {'X' : X}
len_dataset = len(dataset['X'])
cut = int(len_dataset*0.7)
dataset_train, dataset_val = {'X':dataset['X'][:cut]}, {'X':dataset['X'][cut:], 'X_ori':X_normalized[cut:]}

# %%
X.shape
# Out:
# torch.Size([391, 24, 13])

# %%
from pypots.optim.adam import Adam
from torch.optim.lr_scheduler import LRScheduler

from pypots.imputation import GP_VAE

gpvae = GP_VAE(n_steps = dataset_train['X'].shape[1], 
            n_features = dataset_train['X'].shape[2], 
            latent_size = 16, 
            epochs = 500, 
            batch_size = 32,
            beta = 1., 
            K = 10,  
            encoder_sizes = (128), 
            decoder_sizes = (128),
            optimizer = Adam(weight_decay=0.001), #lr = 1e-4
            patience = 30
            )

gpvae.model.backbone.alpha = 1e0
gpvae.model.backbone.beta = 1e-2
gpvae.model.backbone.gamma = 5 * 1e-5
gpvae.model.backbone.noise_sigma = 1e-3
gpvae.model.backbone.sampling = True
gpvae.model.backbone.use_mean = True
gpvae.model.backbone.noise_std = 1e-2
gpvae.model.backbone.detach = True
gpvae.model.backbone.compensate = False
gpvae.use_gp = False
gpvae.train_gp = False
gpvae.gp.plot_while_training = True

gpvae.model.backbone.p = 0.3
gpvae.model.backbone.device = 'cpu'
# Out:
# 2025-02-28 14:39:22 [INFO]: No given device, using default device: cpu
# 2025-02-28 14:39:22 [WARNING]: ‼️ saving_path not given. Model files and tensorboard file will not be saved.
# 2025-02-28 14:39:22 [INFO]: GP_VAE initialized with the given hyperparameters, the number of trainable parameters: 27,789
# Model dimensions is:
# GpvaeEncoder(
#   (net): Sequential(
#     (0): Linear(in_features=26, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): LeakyReLU(negative_slope=0.01)
#   )
#   (mu_layer): Linear(in_features=32, out_features=16, bias=True)
#   (logvar_layer): Linear(in_features=32, out_features=16, bias=True)
# )
# GpvaeDecoder(
#   (net): Sequential(
#     (0): Linear(in_features=16, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=32, out_features=13, bias=True)
#   )
# )

# %%
gpvae.fit(dataset_train, dataset_val)
# Out:
# 2025-02-28 14:39:25 [INFO]: Epoch 001 - training loss: 288.9821, validation loss: 342.9190
# 2025-02-28 14:39:26 [INFO]: Epoch 002 - training loss: 282.7379, validation loss: 356.0945
# 2025-02-28 14:39:26 [INFO]: Epoch 003 - training loss: 274.6732, validation loss: 372.4263
# 2025-02-28 14:39:27 [INFO]: Epoch 004 - training loss: 271.5275, validation loss: 369.4067
# 2025-02-28 14:39:27 [INFO]: Epoch 005 - training loss: 227.5678, validation loss: 349.9717
# 2025-02-28 14:39:28 [INFO]: Epoch 006 - training loss: 190.6530, validation loss: 292.4326
# 2025-02-28 14:39:28 [INFO]: Epoch 007 - training loss: 171.8771, validation loss: 277.8923
# 2025-02-28 14:39:29 [INFO]: Epoch 008 - training loss: 160.7271, validation loss: 260.1255
# 2025-02-28 14:39:30 [INFO]: Epoch 009 - training loss: 153.8254, validation loss: 255.5712
# 2025-02-28 14:39:30 [INFO]: Epoch 010 - training loss: 138.2024, validation loss: 245.6749
# 2025-02-28 14:39:30 [INFO]: Epoch 011 - training loss: 131.1156, validation loss: 238.6424
# 2025-02-28 14:39:31 [INFO]: Epoch 012 - training loss: 116.8213, validation loss: 228.5732
# 2025-02-28 14:39:32 [INFO]: Epoch 013 - training loss: 107.3939, validation loss: 222.8121
# 2025-02-28 14:41:12 [INFO]: Epoch 228 - training loss: 21.5053, validation loss: 37.1996
# 2025-02-28 14:41:13 [INFO]: Epoch 229 - training loss: 21.4511, validation loss: 37.4760
# 2025-02-28 14:41:13 [INFO]: Epoch 230 - training loss: 21.4111, validation loss: 36.9058
# 2025-02-28 14:41:14 [INFO]: Epoch 231 - training loss: 21.3132, validation loss: 36.9935
# 2025-02-28 14:41:14 [INFO]: Epoch 232 - training loss: 21.1842, validation loss: 36.3202
# 2025-02-28 14:41:14 [INFO]: Epoch 233 - training loss: 21.2064, validation loss: 37.1443
# 2025-02-28 14:41:15 [INFO]: Epoch 234 - training loss: 21.2274, validation loss: 37.0506
# 2025-02-28 14:41:15 [INFO]: Epoch 235 - training loss: 21.2172, validation loss: 37.4214
# 2025-02-28 14:41:16 [INFO]: Epoch 236 - training loss: 21.1648, validation loss: 37.3524
# 2025-02-28 14:41:16 [INFO]: Epoch 237 - training loss: 21.0717, validation loss: 36.6672
# 2025-02-28 14:41:16 [INFO]: Epoch 238 - training loss: 21.1025, validation loss: 36.8668
# 2025-02-28 14:41:17 [INFO]: Epoch 239 - training loss: 21.0897, validation loss: 37.2256
# 2025-02-28 14:41:17 [INFO]: Epoch 240 - training loss: 20.9521, validation loss: 36.4885
# 2025-02-28 14:41:18 [INFO]: Epoch 241 - training loss: 21.0070, validation loss: 36.9539
# 2025-02-28 14:41:18 [INFO]: Epoch 242 - training loss: 20.7918, validation loss: 35.7874
# 2025-02-28 14:41:19 [INFO]: Epoch 243 - training loss: 20.8412, validation loss: 36.4136
# 2025-02-28 14:41:19 [INFO]: Epoch 244 - training loss: 20.6405, validation loss: 36.5705
# 2025-02-28 14:41:19 [INFO]: Epoch 245 - training loss: 20.7054, validation loss: 36.0773
# 2025-02-28 14:41:20 [INFO]: Epoch 246 - training loss: 20.6164, validation loss: 36.1394
# Plotting latent series and reconstruction...
# 2025-02-28 14:41:21 [INFO]: Epoch 247 - training loss: 20.6943, validation loss: 36.3444
# 2025-02-28 14:41:22 [INFO]: Epoch 248 - training loss: 20.8313, validation loss: 36.9421
# 2025-02-28 14:41:22 [INFO]: Epoch 249 - training loss: 20.6261, validation loss: 35.9343
# 2025-02-28 14:41:23 [INFO]: Epoch 250 - training loss: 20.5440, validation loss: 35.9874
# 2025-02-28 14:41:23 [WARNING]: ‼️ Training got interrupted by the user. Exist now ...
# 2025-02-28 14:41:23 [INFO]: Finished training. The best model is from epoch#242.
# fitting kernel
# Epoch 1/50: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 gpvae.fit(dataset_train, dataset_val)
#
# File ~/Documents/Phd/Code_pour_manuscript/PyPOTS/pypots/imputation/gp_ae/model.py:604, in GP_VAE.fit(self, train_set, val_set, file_type)
#     602 # Step 2bis: learn the kernel
#     603 print('fitting kernel')
# --> 604 self._fit_kernel(training_loader, val_loader, training_iter = 50)
#
# File ~/Documents/Phd/Code_pour_manuscript/PyPOTS/pypots/imputation/gp_ae/model.py:728, in GP_VAE._fit_kernel(self, training_loader, val_loader, training_iter)
#     723 def _fit_kernel(
#     724     self,
#     725     training_loader,
#     726     val_loader = None,
#     727     training_iter = 1) -> None:
# --> 728     self.gp.fit_kernel(training_loader, val_loader = val_loader, training_iter = training_iter)
#
# File ~/Documents/Phd/Code_pour_manuscript/PyPOTS/pypots/imputation/gp_ae/gp_model_BETTER.py:391, in ProbabilisticGP.fit_kernel(self, training_loader, val_loader, training_iter)
#     388 assert not torch.isnan(loss), print(x_recon)
#     390 # Backpropagation
# --> 391 loss.clip(min=0,max=10).backward()
#     392 self.optimizer.step()
#     394 # Gradient Clipping
#
# File ~/miniforge3/envs/pypots3/lib/python3.8/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~/miniforge3/envs/pypots3/lib/python3.8/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~/miniforge3/envs/pypots3/lib/python3.8/site-packages/torch/autograd/graph.py:769, in _engine_run_backward(t_outputs, *args, **kwargs)
#     767     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768 try:
# --> 769     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770         t_outputs, *args, **kwargs
#     771     )  # Calls into the C++ engine to run the backward pass
#     772 finally:
#     773     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
gpvae.fit(dataset_train, dataset_val)

# %%
gpvae.gp.plot_while_training = True
gpvae.fit_kernel(dataset_train, dataset_val, training_iter = 50)
# Out:
# fitting kernel
# Epoch 1/50: 9it [00:02,  3.74it/s]
# Epoch 1/50: Training Loss = 0.151888, Validation Loss = 0.123749
# latent_scatterplot_1740749680.png
# Epoch 2/50: 9it [00:02,  4.09it/s]
# Epoch 2/50: Training Loss = 0.140481, Validation Loss = 0.123565
# latent_scatterplot_1740749683.png
# Epoch 3/50: 9it [00:02,  4.12it/s]
# Epoch 3/50: Training Loss = 0.136111, Validation Loss = 0.122462
# latent_scatterplot_1740749686.png
# Epoch 4/50: 9it [00:02,  4.03it/s]
# Epoch 4/50: Training Loss = 0.126974, Validation Loss = 0.116246
# latent_scatterplot_1740749689.png
# Epoch 5/50: 9it [00:02,  4.12it/s]
# Epoch 5/50: Training Loss = 0.108479, Validation Loss = 0.094290
# latent_scatterplot_1740749692.png
# Epoch 6/50: 9it [00:02,  4.01it/s]
# Epoch 6/50: Training Loss = 0.091667, Validation Loss = 0.084230
# latent_scatterplot_1740749694.png
# Epoch 7/50: 9it [00:03,  2.46it/s]
# Epoch 7/50: Training Loss = 0.080701, Validation Loss = 0.084572
# latent_scatterplot_1740749699.png
# Epoch 8/50: 9it [00:02,  4.06it/s]
# Epoch 8/50: Training Loss = 0.072879, Validation Loss = 0.081770
# latent_scatterplot_1740749701.png
# Epoch 9/50: 9it [00:02,  3.70it/s]
# Epoch 9/50: Training Loss = 0.068080, Validation Loss = 0.080361
# latent_scatterplot_1740749705.png
# Epoch 10/50: 9it [00:02,  4.10it/s]
# Epoch 10/50: Training Loss = 0.065176, Validation Loss = 0.082638
# latent_scatterplot_1740749707.png
# Epoch 11/50: 9it [00:02,  4.13it/s]
# Epoch 11/50: Training Loss = 0.060726, Validation Loss = 0.076643
# latent_scatterplot_1740749710.png
# Epoch 12/50: 9it [00:02,  3.75it/s]
# Epoch 12/50: Training Loss = 0.059424, Validation Loss = 0.073751
# latent_scatterplot_1740749713.png
# Epoch 13/50: 9it [00:02,  4.02it/s]
# Epoch 13/50: Training Loss = 0.056540, Validation Loss = 0.074199
# latent_scatterplot_1740749716.png
# Epoch 14/50: 9it [00:02,  4.10it/s]
# Epoch 14/50: Training Loss = 0.056558, Validation Loss = 0.075832
# latent_scatterplot_1740749719.png
# Epoch 15/50: 9it [00:02,  4.07it/s]
# Epoch 15/50: Training Loss = 0.054813, Validation Loss = 0.076352
# latent_scatterplot_1740749722.png
# Epoch 16/50: 9it [00:02,  3.99it/s]
# Epoch 16/50: Training Loss = 0.053745, Validation Loss = 0.073524
# latent_scatterplot_1740749724.png
# Epoch 17/50: 9it [00:02,  3.34it/s]
# Epoch 17/50: Training Loss = 0.054324, Validation Loss = 0.078306
# latent_scatterplot_1740749728.png
# Epoch 18/50: 9it [00:02,  4.09it/s]
# Epoch 18/50: Training Loss = 0.051010, Validation Loss = 0.074586
# latent_scatterplot_1740749730.png
# Epoch 19/50: 9it [00:02,  3.99it/s]
# Epoch 19/50: Training Loss = 0.054013, Validation Loss = 0.071085
# latent_scatterplot_1740749733.png
# Epoch 20/50: 9it [00:02,  4.01it/s]
# Epoch 20/50: Training Loss = 0.053357, Validation Loss = 0.077178
# latent_scatterplot_1740749736.png
# Epoch 21/50: 9it [00:02,  4.04it/s]
# Epoch 21/50: Training Loss = 0.055530, Validation Loss = 0.079232
# latent_scatterplot_1740749739.png
# Epoch 22/50: 9it [00:02,  3.57it/s]
# Epoch 22/50: Training Loss = 0.052537, Validation Loss = 0.073830
# latent_scatterplot_1740749742.png
# Epoch 23/50: 9it [00:02,  4.06it/s]
# Epoch 23/50: Training Loss = 0.051390, Validation Loss = 0.076757
# latent_scatterplot_1740749745.png
# Epoch 24/50: 9it [00:02,  4.12it/s]
# Epoch 24/50: Training Loss = 0.052220, Validation Loss = 0.069323
# latent_scatterplot_1740749748.png
# Epoch 25/50: 9it [00:02,  4.08it/s]
# Epoch 25/50: Training Loss = 0.052887, Validation Loss = 0.072008
# latent_scatterplot_1740749751.png
# Epoch 26/50: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[102], line 2
#       1 gpvae.gp.plot_while_training = True
# ----> 2 gpvae.fit_kernel(dataset_train, dataset_val, training_iter = 50)
#
# File ~/Documents/Phd/Code_pour_manuscript/PyPOTS/pypots/imputation/gp_ae/model.py:759, in GP_VAE.fit_kernel(self, train_set, val_set, training_iter, file_type)
#     757 # Step 2bis: learn the kernel
#     758 print('fitting kernel')
# --> 759 self._fit_kernel(training_loader, val_loader = val_loader, training_iter = training_iter)
#     761 # Step 3: save the model if necessary
#     762 self._auto_save_model_if_necessary(confirm_saving=self.model_saving_strategy == "best")
#
# File ~/Documents/Phd/Code_pour_manuscript/PyPOTS/pypots/imputation/gp_ae/model.py:728, in GP_VAE._fit_kernel(self, training_loader, val_loader, training_iter)
#     723 def _fit_kernel(
#     724     self,
#     725     training_loader,
#     726     val_loader = None,
#     727     training_iter = 1) -> None:
# --> 728     self.gp.fit_kernel(training_loader, val_loader = val_loader, training_iter = training_iter)
#
# File ~/Documents/Phd/Code_pour_manuscript/PyPOTS/pypots/imputation/gp_ae/gp_model_BETTER.py:391, in ProbabilisticGP.fit_kernel(self, training_loader, val_loader, training_iter)
#     388 assert not torch.isnan(loss), print(x_recon)
#     390 # Backpropagation
# --> 391 loss.clip(min=0,max=10).backward()
#     392 self.optimizer.step()
#     394 # Gradient Clipping
#
# File ~/miniforge3/envs/pypots3/lib/python3.8/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~/miniforge3/envs/pypots3/lib/python3.8/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~/miniforge3/envs/pypots3/lib/python3.8/site-packages/torch/autograd/graph.py:769, in _engine_run_backward(t_outputs, *args, **kwargs)
#     767     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768 try:
# --> 769     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770         t_outputs, *args, **kwargs
#     771     )  # Calls into the C++ engine to run the backward pass
#     772 finally:
#     773     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
torch.save(gpvae.model.backbone.encoder.state_dict().copy(), 'encoder')
torch.save(gpvae.model.backbone.decoder.state_dict().copy(), 'decoder')

# %%
state_dict = torch.load('encoder');
gpvae.model.backbone.encoder.load_state_dict(state_dict);
state_dict = torch.load('decoder');
gpvae.model.backbone.decoder.load_state_dict(state_dict);

# %%
X_val_imputed = gpvae.impute(dataset_val, with_gp = True)
plt.plot(X_val_imputed[0]);
plt.gca().set_prop_cycle(None)
plt.plot(dataset_val['X'][0],'o');
plt.gca().set_prop_cycle(None)
plt.plot(dataset_val['X_ori'][0],'+');

# %%
mse_obs, mse_hidden = plot_reconstruction_with_GP(X[::5], X_normalized[::5], gpvae, i = 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 mse_obs, mse_hidden = plot_reconstruction_with_GP(X[::5], X_normalized[::5], gpvae, i = 4)
#
# NameError: name 'plot_reconstruction_with_GP' is not defined
